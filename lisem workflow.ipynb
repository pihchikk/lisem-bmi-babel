# %% [markdown]
# # Настройка репозитория

# %%
# !sudo apt-get update || true
# !sudo apt-get install -y software-properties-common || true

# включаем universe + multiverse
# !sudo add-apt-repository -y universe || true
# !sudo add-apt-repository -y multiverse || true
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease [1 581 B]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease [17,8 kB]
# Get:3 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease [24,4 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble/main amd64 Packages [40,6 kB]
# Get:5 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 Packages [63,9 kB]
# Get:6 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease [3 631 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ Packages [55,0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [3 780 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  Packages [1 548 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:13 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [2 138 kB]
# Get:14 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1 513 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [48,4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/restricted amd64 Packages [117 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [331 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/universe amd64 Packages [19,3 MB]
# Get:20 http://archive.ubuntu.com/ubuntu noble/main amd64 Packages [1 808 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2 515 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [54,6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [2 156 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [4 016 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [35,9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Packages [49,0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Packages [671 B]
# Fetched 40,3 MB in 6s (7 192 kB/s)
# Reading package lists... Done
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   appstream distro-info-data gir1.2-girepository-2.0 gir1.2-glib-2.0
#   gir1.2-packagekitglib-1.0 iso-codes libappstream5 libcap2 libcap2-bin
#   libduktape207 libdw1t64 libelf1t64 libgirepository-1.0-1 libglib2.0-0t64
#   libglib2.0-bin libglib2.0-data libgstreamer1.0-0 libpackagekit-glib2-18
#   libpam-cap libpolkit-agent-1-0 libpolkit-gobject-1-0 libstemmer0d libunwind8
#   libxmlb2 libyaml-0-2 lsb-release packagekit packagekit-tools polkitd
#   python-apt-common python3-apt python3-blinker python3-cffi-backend
#   python3-cryptography python3-dbus python3-distro python3-distro-info
#   python3-gi python3-httplib2 python3-jwt python3-launchpadlib
#   python3-lazr.restfulclient python3-lazr.uri python3-oauthlib
#   python3-pyparsing python3-software-properties python3-wadllib sgml-base
#   unattended-upgrades xml-core
# Suggested packages:
#   apt-config-icons isoquery low-memory-monitor gstreamer1.0-tools polkitd-pkla
#   python-apt-doc python-blinker-doc python-cryptography-doc
#   python3-cryptography-vectors python-dbus-doc python3-crypto python3-keyring
#   python3-testresources python-pyparsing-doc sgml-base-doc bsd-mailx
#   default-mta | mail-transport-agent needrestart powermgmt-base debhelper
# Recommended packages:
#   xdg-user-dirs
# The following NEW packages will be installed:
#   appstream distro-info-data gir1.2-girepository-2.0 gir1.2-glib-2.0
#   gir1.2-packagekitglib-1.0 iso-codes libappstream5 libcap2-bin libduktape207
#   libdw1t64 libgirepository-1.0-1 libglib2.0-bin libglib2.0-data
#   libgstreamer1.0-0 libpackagekit-glib2-18 libpam-cap libpolkit-agent-1-0
#   libpolkit-gobject-1-0 libstemmer0d libunwind8 libxmlb2 libyaml-0-2
#   lsb-release packagekit packagekit-tools polkitd python-apt-common
#   python3-apt python3-blinker python3-cffi-backend python3-cryptography
#   python3-dbus python3-distro python3-distro-info python3-gi python3-httplib2
#   python3-jwt python3-launchpadlib python3-lazr.restfulclient python3-lazr.uri
#   python3-oauthlib python3-pyparsing python3-software-properties
#   python3-wadllib sgml-base software-properties-common unattended-upgrades
#   xml-core
# The following packages will be upgraded:
#   libcap2 libelf1t64 libglib2.0-0t64
# 3 upgraded, 48 newly installed, 0 to remove and 192 not upgraded.
# Need to get 10,6 MB of archives.
# After this operation, 43,3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/main amd64 sgml-base all 1.31 [11,4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libcap2 amd64 1:2.66-5ubuntu2.4 [30,5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 distro-info-data all 0.60ubuntu0.6 [7 036 B]
# Get:4 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libglib2.0-0t64 amd64 2.80.0-6ubuntu3.8 [1 545 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gir1.2-glib-2.0 amd64 2.80.0-6ubuntu3.8 [183 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/main amd64 libgirepository-1.0-1 amd64 1.80.1-1 [81,9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/main amd64 gir1.2-girepository-2.0 amd64 1.80.1-1 [24,5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/main amd64 iso-codes all 4.16.0-1 [3 492 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libcap2-bin amd64 1:2.66-5ubuntu2.4 [34,1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libelf1t64 amd64 0.190-1.1ubuntu0.1 [57,8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libglib2.0-data all 2.80.0-6ubuntu3.8 [49,6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpam-cap amd64 1:2.66-5ubuntu2.4 [12,5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/main amd64 libyaml-0-2 amd64 0.2.5-1build1 [51,5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/main amd64 lsb-release all 12.0-2 [6 564 B]
# Get:15 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python-apt-common all 2.7.7ubuntu5.2 [20,6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-apt amd64 2.7.7ubuntu5.2 [169 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-cffi-backend amd64 1.16.0-2build1 [77,3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-dbus amd64 1.3.2-5build3 [100 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-gi amd64 3.48.2-1 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-distro-info all 1.7build1 [7 076 B]
# Get:21 http://archive.ubuntu.com/ubuntu noble/main amd64 libstemmer0d amd64 2.2.0-4build1 [161 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble/main amd64 libxmlb2 amd64 0.3.18-1 [67,7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble/main amd64 libappstream5 amd64 1.0.2-1build6 [238 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble/main amd64 appstream amd64 1.0.2-1build6 [69,4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpackagekit-glib2-18 amd64 1.2.8-2ubuntu1.5 [120 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gir1.2-packagekitglib-1.0 amd64 1.2.8-2ubuntu1.5 [25,6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble/main amd64 libduktape207 amd64 2.7.0+tests-0ubuntu3 [143 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdw1t64 amd64 0.190-1.1ubuntu0.1 [261 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libglib2.0-bin amd64 2.80.0-6ubuntu3.8 [97,9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libunwind8 amd64 1.6.2-3build1.1 [55,3 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer1.0-0 amd64 1.24.2-1ubuntu0.1 [1 165 kB]
# Get:32 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpolkit-gobject-1-0 amd64 124-2ubuntu1.24.04.3 [49,5 kB]
# Get:33 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpolkit-agent-1-0 amd64 124-2ubuntu1.24.04.3 [17,4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu noble/main amd64 xml-core all 0.19 [20,3 kB]
# Get:35 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 polkitd amd64 124-2ubuntu1.24.04.3 [95,4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit amd64 1.2.8-2ubuntu1.5 [434 kB]
# Get:37 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit-tools amd64 1.2.8-2ubuntu1.5 [28,2 kB]
# Get:38 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-blinker all 1.7.0-1 [14,3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-cryptography amd64 41.0.7-4ubuntu0.4 [815 kB]
# Get:40 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-pyparsing all 3.1.1-1 [86,2 kB]
# Get:41 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-httplib2 all 0.20.4-3 [30,4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-jwt all 2.7.0-1ubuntu0.1 [20,2 kB]
# Get:43 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-lazr.uri all 1.0.6-3 [13,5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-wadllib all 1.3.6-5 [35,9 kB]
# Get:45 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-distro all 1.9.0-1 [19,0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-oauthlib all 3.2.2-1 [89,7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-lazr.restfulclient all 0.14.6-1 [50,8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu noble/main amd64 python3-launchpadlib all 1.11.0-6 [127 kB]
# Get:49 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-software-properties all 0.99.49.4 [30,0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 software-properties-common all 0.99.49.4 [14,4 kB]
# Get:51 http://archive.ubuntu.com/ubuntu noble/main amd64 unattended-upgrades all 2.9.1+nmu4ubuntu1 [51,2 kB]
# Fetched 10,6 MB in 4s (2 997 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package sgml-base.
# (Reading database ... 38814 files and directories currently installed.)
# Preparing to unpack .../sgml-base_1.31_all.deb ...
# Unpacking sgml-base (1.31) ...
# Preparing to unpack .../libcap2_1%3a2.66-5ubuntu2.4_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.66-5ubuntu2.4) over (1:2.66-5ubuntu2) ...
# Setting up libcap2:amd64 (1:2.66-5ubuntu2.4) ...
# Selecting previously unselected package distro-info-data.
# (Reading database ... 38841 files and directories currently installed.)
# Preparing to unpack .../00-distro-info-data_0.60ubuntu0.6_all.deb ...
# Unpacking distro-info-data (0.60ubuntu0.6) ...
# Preparing to unpack .../01-libglib2.0-0t64_2.80.0-6ubuntu3.8_amd64.deb ...
# Unpacking libglib2.0-0t64:amd64 (2.80.0-6ubuntu3.8) over (2.80.0-6ubuntu3.2) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../02-gir1.2-glib-2.0_2.80.0-6ubuntu3.8_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (2.80.0-6ubuntu3.8) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../03-libgirepository-1.0-1_1.80.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.80.1-1) ...
# Selecting previously unselected package gir1.2-girepository-2.0:amd64.
# Preparing to unpack .../04-gir1.2-girepository-2.0_1.80.1-1_amd64.deb ...
# Unpacking gir1.2-girepository-2.0:amd64 (1.80.1-1) ...
# Selecting previously unselected package iso-codes.
# Preparing to unpack .../05-iso-codes_4.16.0-1_all.deb ...
# Unpacking iso-codes (4.16.0-1) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../06-libcap2-bin_1%3a2.66-5ubuntu2.4_amd64.deb ...
# Unpacking libcap2-bin (1:2.66-5ubuntu2.4) ...
# Preparing to unpack .../07-libelf1t64_0.190-1.1ubuntu0.1_amd64.deb ...
# Unpacking libelf1t64:amd64 (0.190-1.1ubuntu0.1) over (0.190-1.1build4.1) ...
# Selecting previously unselected package libglib2.0-data.
# Preparing to unpack .../08-libglib2.0-data_2.80.0-6ubuntu3.8_all.deb ...
# Unpacking libglib2.0-data (2.80.0-6ubuntu3.8) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../09-libpam-cap_1%3a2.66-5ubuntu2.4_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.66-5ubuntu2.4) ...
# Selecting previously unselected package libyaml-0-2:amd64.
# Preparing to unpack .../10-libyaml-0-2_0.2.5-1build1_amd64.deb ...
# Unpacking libyaml-0-2:amd64 (0.2.5-1build1) ...
# Selecting previously unselected package lsb-release.
# Preparing to unpack .../11-lsb-release_12.0-2_all.deb ...
# Unpacking lsb-release (12.0-2) ...
# Selecting previously unselected package python-apt-common.
# Preparing to unpack .../12-python-apt-common_2.7.7ubuntu5.2_all.deb ...
# Unpacking python-apt-common (2.7.7ubuntu5.2) ...
# Selecting previously unselected package python3-apt.
# Preparing to unpack .../13-python3-apt_2.7.7ubuntu5.2_amd64.deb ...
# Unpacking python3-apt (2.7.7ubuntu5.2) ...
# Selecting previously unselected package python3-cffi-backend:amd64.
# Preparing to unpack .../14-python3-cffi-backend_1.16.0-2build1_amd64.deb ...
# Unpacking python3-cffi-backend:amd64 (1.16.0-2build1) ...
# Selecting previously unselected package python3-dbus.
# Preparing to unpack .../15-python3-dbus_1.3.2-5build3_amd64.deb ...
# Unpacking python3-dbus (1.3.2-5build3) ...
# Selecting previously unselected package python3-gi.
# Preparing to unpack .../16-python3-gi_3.48.2-1_amd64.deb ...
# Unpacking python3-gi (3.48.2-1) ...
# Selecting previously unselected package python3-distro-info.
# Preparing to unpack .../17-python3-distro-info_1.7build1_all.deb ...
# Unpacking python3-distro-info (1.7build1) ...
# Selecting previously unselected package libstemmer0d:amd64.
# Preparing to unpack .../18-libstemmer0d_2.2.0-4build1_amd64.deb ...
# Unpacking libstemmer0d:amd64 (2.2.0-4build1) ...
# Selecting previously unselected package libxmlb2:amd64.
# Preparing to unpack .../19-libxmlb2_0.3.18-1_amd64.deb ...
# Unpacking libxmlb2:amd64 (0.3.18-1) ...
# Selecting previously unselected package libappstream5:amd64.
# Preparing to unpack .../20-libappstream5_1.0.2-1build6_amd64.deb ...
# Unpacking libappstream5:amd64 (1.0.2-1build6) ...
# Selecting previously unselected package appstream.
# Preparing to unpack .../21-appstream_1.0.2-1build6_amd64.deb ...
# Unpacking appstream (1.0.2-1build6) ...
# Selecting previously unselected package libpackagekit-glib2-18:amd64.
# Preparing to unpack .../22-libpackagekit-glib2-18_1.2.8-2ubuntu1.5_amd64.deb ...
# Unpacking libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.5) ...
# Selecting previously unselected package gir1.2-packagekitglib-1.0.
# Preparing to unpack .../23-gir1.2-packagekitglib-1.0_1.2.8-2ubuntu1.5_amd64.deb ...
# Unpacking gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.5) ...
# Selecting previously unselected package libduktape207:amd64.
# Preparing to unpack .../24-libduktape207_2.7.0+tests-0ubuntu3_amd64.deb ...
# Unpacking libduktape207:amd64 (2.7.0+tests-0ubuntu3) ...
# Selecting previously unselected package libdw1t64:amd64.
# Preparing to unpack .../25-libdw1t64_0.190-1.1ubuntu0.1_amd64.deb ...
# Unpacking libdw1t64:amd64 (0.190-1.1ubuntu0.1) ...
# Selecting previously unselected package libglib2.0-bin.
# Preparing to unpack .../26-libglib2.0-bin_2.80.0-6ubuntu3.8_amd64.deb ...
# Unpacking libglib2.0-bin (2.80.0-6ubuntu3.8) ...
# Selecting previously unselected package libunwind8:amd64.
# Preparing to unpack .../27-libunwind8_1.6.2-3build1.1_amd64.deb ...
# Unpacking libunwind8:amd64 (1.6.2-3build1.1) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../28-libgstreamer1.0-0_1.24.2-1ubuntu0.1_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) ...
# Selecting previously unselected package libpolkit-gobject-1-0:amd64.
# Preparing to unpack .../29-libpolkit-gobject-1-0_124-2ubuntu1.24.04.3_amd64.deb ...
# Unpacking libpolkit-gobject-1-0:amd64 (124-2ubuntu1.24.04.3) ...
# Selecting previously unselected package libpolkit-agent-1-0:amd64.
# Preparing to unpack .../30-libpolkit-agent-1-0_124-2ubuntu1.24.04.3_amd64.deb ...
# Unpacking libpolkit-agent-1-0:amd64 (124-2ubuntu1.24.04.3) ...
# Selecting previously unselected package xml-core.
# Preparing to unpack .../31-xml-core_0.19_all.deb ...
# Unpacking xml-core (0.19) ...
# Selecting previously unselected package polkitd.
# Preparing to unpack .../32-polkitd_124-2ubuntu1.24.04.3_amd64.deb ...
# Unpacking polkitd (124-2ubuntu1.24.04.3) ...
# Selecting previously unselected package packagekit.
# Preparing to unpack .../33-packagekit_1.2.8-2ubuntu1.5_amd64.deb ...
# Unpacking packagekit (1.2.8-2ubuntu1.5) ...
# Selecting previously unselected package packagekit-tools.
# Preparing to unpack .../34-packagekit-tools_1.2.8-2ubuntu1.5_amd64.deb ...
# Unpacking packagekit-tools (1.2.8-2ubuntu1.5) ...
# Selecting previously unselected package python3-blinker.
# Preparing to unpack .../35-python3-blinker_1.7.0-1_all.deb ...
# Unpacking python3-blinker (1.7.0-1) ...
# Selecting previously unselected package python3-cryptography.
# Preparing to unpack .../36-python3-cryptography_41.0.7-4ubuntu0.4_amd64.deb ...
# Unpacking python3-cryptography (41.0.7-4ubuntu0.4) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../37-python3-pyparsing_3.1.1-1_all.deb ...
# Unpacking python3-pyparsing (3.1.1-1) ...
# Selecting previously unselected package python3-httplib2.
# Preparing to unpack .../38-python3-httplib2_0.20.4-3_all.deb ...
# Unpacking python3-httplib2 (0.20.4-3) ...
# Selecting previously unselected package python3-jwt.
# Preparing to unpack .../39-python3-jwt_2.7.0-1ubuntu0.1_all.deb ...
# Unpacking python3-jwt (2.7.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-lazr.uri.
# Preparing to unpack .../40-python3-lazr.uri_1.0.6-3_all.deb ...
# Unpacking python3-lazr.uri (1.0.6-3) ...
# Selecting previously unselected package python3-wadllib.
# Preparing to unpack .../41-python3-wadllib_1.3.6-5_all.deb ...
# Unpacking python3-wadllib (1.3.6-5) ...
# Selecting previously unselected package python3-distro.
# Preparing to unpack .../42-python3-distro_1.9.0-1_all.deb ...
# Unpacking python3-distro (1.9.0-1) ...
# Selecting previously unselected package python3-oauthlib.
# Preparing to unpack .../43-python3-oauthlib_3.2.2-1_all.deb ...
# Unpacking python3-oauthlib (3.2.2-1) ...
# Selecting previously unselected package python3-lazr.restfulclient.
# Preparing to unpack .../44-python3-lazr.restfulclient_0.14.6-1_all.deb ...
# Unpacking python3-lazr.restfulclient (0.14.6-1) ...
# Selecting previously unselected package python3-launchpadlib.
# Preparing to unpack .../45-python3-launchpadlib_1.11.0-6_all.deb ...
# Unpacking python3-launchpadlib (1.11.0-6) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../46-python3-software-properties_0.99.49.4_all.deb ...
# Unpacking python3-software-properties (0.99.49.4) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../47-software-properties-common_0.99.49.4_all.deb ...
# Unpacking software-properties-common (0.99.49.4) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../48-unattended-upgrades_2.9.1+nmu4ubuntu1_all.deb ...
# Unpacking unattended-upgrades (2.9.1+nmu4ubuntu1) ...
# Setting up python3-jwt (2.7.0-1ubuntu0.1) ...
# Setting up libyaml-0-2:amd64 (0.2.5-1build1) ...
# Setting up distro-info-data (0.60ubuntu0.6) ...
# Setting up python3-lazr.uri (1.0.6-3) ...
# Setting up libunwind8:amd64 (1.6.2-3build1.1) ...
# Setting up libelf1t64:amd64 (0.190-1.1ubuntu0.1) ...
# Setting up libdw1t64:amd64 (0.190-1.1ubuntu0.1) ...
# Setting up libcap2-bin (1:2.66-5ubuntu2.4) ...
# Setting up libglib2.0-0t64:amd64 (2.80.0-6ubuntu3.8) ...
# Setting up libglib2.0-data (2.80.0-6ubuntu3.8) ...
# Setting up python3-pyparsing (3.1.1-1) ...
# Setting up python3-wadllib (1.3.6-5) ...
# Setting up gir1.2-glib-2.0:amd64 (2.80.0-6ubuntu3.8) ...
# Setting up python-apt-common (2.7.7ubuntu5.2) ...
# Setting up libduktape207:amd64 (2.7.0+tests-0ubuntu3) ...
# Setting up python3-httplib2 (0.20.4-3) ...
# Setting up libgirepository-1.0-1:amd64 (1.80.1-1) ...
# Setting up sgml-base (1.31) ...
# Setting up libstemmer0d:amd64 (2.2.0-4build1) ...
# Setting up lsb-release (12.0-2) ...
# Setting up libpam-cap:amd64 (1:2.66-5ubuntu2.4) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 79.)
# debconf: falling back to frontend: Readline
# Setting up python3-distro-info (1.7build1) ...
# Setting up iso-codes (4.16.0-1) ...
# Setting up libpolkit-gobject-1-0:amd64 (124-2ubuntu1.24.04.3) ...
# Setting up libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up python3-cffi-backend:amd64 (1.16.0-2build1) ...
# Setting up python3-blinker (1.7.0-1) ...
# Setting up python3-dbus (1.3.2-5build3) ...
# Setting up python3-distro (1.9.0-1) ...
# Setting up python3-apt (2.7.7ubuntu5.2) ...
# Setting up libxmlb2:amd64 (0.3.18-1) ...
# Setting up libglib2.0-bin (2.80.0-6ubuntu3.8) ...
# Setting up libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.5) ...
# Setting up libappstream5:amd64 (1.0.2-1build6) ...
# Setting up gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.5) ...
# Setting up unattended-upgrades (2.9.1+nmu4ubuntu1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 79.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
#
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version
# Created symlink /etc/systemd/system/multi-user.target.wants/unattended-upgrades.service → /usr/lib/systemd/system/unattended-upgrades.service.
# Setting up appstream (1.0.2-1build6) ...
# ✔ Metadata cache was updated successfully.
# Setting up gir1.2-girepository-2.0:amd64 (1.80.1-1) ...
# Setting up python3-cryptography (41.0.7-4ubuntu0.4) ...
# Setting up python3-gi (3.48.2-1) ...
# Setting up xml-core (0.19) ...
# Setting up libpolkit-agent-1-0:amd64 (124-2ubuntu1.24.04.3) ...
# Setting up python3-oauthlib (3.2.2-1) ...
# Setting up python3-lazr.restfulclient (0.14.6-1) ...
# Setting up python3-launchpadlib (1.11.0-6) ...
# Created symlink /etc/systemd/user/timers.target.wants/launchpadlib-cache-clean.timer → /usr/lib/systemd/user/launchpadlib-cache-clean.timer.
# Setting up python3-software-properties (0.99.49.4) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.4) ...
# Processing triggers for dbus (1.14.10-4ubuntu4.1) ...
# Processing triggers for sgml-base (1.31) ...
# Setting up polkitd (124-2ubuntu1.24.04.3) ...
# Creating group 'polkitd' with GID 997.
# Creating user 'polkitd' (User for polkitd) with UID 997 and GID 997.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of reload.
# start-stop-daemon: unable to stat /usr/libexec/polkitd (No such file or directory)
# Setting up packagekit (1.2.8-2ubuntu1.5) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# Failed to open connection to "system" message bus: Failed to connect to socket /run/dbus/system_bus_socket: No such file or directory
# Created symlink /etc/systemd/user/sockets.target.wants/pk-debconf-helper.socket → /usr/lib/systemd/user/pk-debconf-helper.socket.
# Setting up packagekit-tools (1.2.8-2ubuntu1.5) ...
# Setting up software-properties-common (0.99.49.4) ...
# Processing triggers for dbus (1.14.10-4ubuntu4.1) ...
# Adding component(s) 'universe' to all repositories.
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:4 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease
# Hit:5 http://security.ubuntu.com/ubuntu noble-security InRelease
# Get:6 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [54,5 kB]
# Get:7 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [95,6 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu noble InRelease
# Get:9 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [157 B]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [158 B]
# Hit:11 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Get:13 http://archive.ubuntu.com/ubuntu noble/main amd64 Components [665 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/universe amd64 Components [5 943 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/multiverse amd64 Components [41,9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Components [237 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Components [532 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Components [159 B]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Components [887 B]
# Get:20 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Components [6 353 B]
# Get:21 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Components [11,3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble-backports/restricted amd64 Components [160 B]
# Get:23 http://archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Components [161 B]
# Fetched 7 588 kB in 4s (2 010 kB/s)
# Reading package lists... Done
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Adding component(s) 'multiverse' to all repositories.
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:4 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:6 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists... Done
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.

# %% [markdown]
# ## Установка зависимостей
#
# Установка инструментов разработки и библиотек для сборки проектов:
#
# - Компиляторы (gcc, g++)
# - Система сборки (CMake)
# - Графические библиотеки (Qt6, QWT)
# - Вспомогательные утилиты

# %%
# !sudo apt install cmake cmake-gui gcc g++ git libboost-all-dev libncurses5-dev libpython3-dev libxerces-c-dev libxml2 libxml2-utils libxslt1-dev python3-numpy qt6-base-dev python3-docopt openssl -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'cmake-qt-gui' instead of 'cmake-gui'
# Note, selecting 'libncurses-dev' instead of 'libncurses5-dev'
# gcc is already the newest version (4:13.2.0-7ubuntu1).
# gcc set to manually installed.
# g++ is already the newest version (4:13.2.0-7ubuntu1).
# g++ set to manually installed.
# python3-numpy is already the newest version (1:1.26.4+ds-6ubuntu1).
# python3-numpy set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libdrm-radeon1 libglapi-mesa libllvm19 libxcb-dri2-0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   autoconf automake autotools-dev cmake-data file git-man ibverbs-providers
#   javascript-common libamd-comgr2 libamdhip64-5 libarchive13t64 libb2-1
#   libboost-atomic-dev libboost-atomic1.83-dev libboost-atomic1.83.0
#   libboost-chrono-dev libboost-chrono1.83-dev libboost-chrono1.83.0t64
#   libboost-container-dev libboost-container1.83-dev libboost-container1.83.0
#   libboost-context-dev libboost-context1.83-dev libboost-context1.83.0
#   libboost-coroutine-dev libboost-coroutine1.83-dev libboost-coroutine1.83.0
#   libboost-date-time-dev libboost-date-time1.83-dev libboost-date-time1.83.0
#   libboost-dev libboost-exception-dev libboost-exception1.83-dev
#   libboost-fiber-dev libboost-fiber1.83-dev libboost-fiber1.83.0
#   libboost-filesystem-dev libboost-filesystem1.83-dev
#   libboost-filesystem1.83.0 libboost-graph-dev libboost-graph-parallel-dev
#   libboost-graph-parallel1.83-dev libboost-graph-parallel1.83.0
#   libboost-graph1.83-dev libboost-graph1.83.0 libboost-iostreams-dev
#   libboost-iostreams1.83-dev libboost-iostreams1.83.0 libboost-json-dev
#   libboost-json1.83-dev libboost-json1.83.0 libboost-locale-dev
#   libboost-locale1.83-dev libboost-locale1.83.0 libboost-log-dev
#   libboost-log1.83-dev libboost-log1.83.0 libboost-math-dev
#   libboost-math1.83-dev libboost-math1.83.0 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.83-dev
#   libboost-mpi-python1.83.0 libboost-mpi1.83-dev libboost-mpi1.83.0
#   libboost-nowide-dev libboost-nowide1.83-dev libboost-nowide1.83.0
#   libboost-numpy-dev libboost-numpy1.83-dev libboost-numpy1.83.0
#   libboost-program-options-dev libboost-program-options1.83-dev
#   libboost-program-options1.83.0 libboost-python-dev libboost-python1.83-dev
#   libboost-python1.83.0 libboost-random-dev libboost-random1.83-dev
#   libboost-random1.83.0 libboost-regex-dev libboost-regex1.83-dev
#   libboost-regex1.83.0 libboost-serialization-dev
#   libboost-serialization1.83-dev libboost-serialization1.83.0
#   libboost-stacktrace-dev libboost-stacktrace1.83-dev
#   libboost-stacktrace1.83.0 libboost-system-dev libboost-system1.83-dev
#   libboost-system1.83.0 libboost-test-dev libboost-test1.83-dev
#   libboost-test1.83.0 libboost-thread-dev libboost-thread1.83-dev
#   libboost-thread1.83.0 libboost-timer-dev libboost-timer1.83-dev
#   libboost-timer1.83.0 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.83-dev libboost-type-erasure1.83.0 libboost-url-dev
#   libboost-url1.83-dev libboost-url1.83.0 libboost-wave-dev
#   libboost-wave1.83-dev libboost-wave1.83.0 libboost1.83-dev
#   libboost1.83-tools-dev libcaf-openmpi-3t64 libcbor0.10 libcoarrays-dev
#   libcoarrays-openmpi-dev libdouble-conversion3 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-radeon1 libdrm2 libegl-mesa0 libegl1 libevdev2
#   libevent-2.1-7t64 libevent-core-2.1-7t64 libevent-dev
#   libevent-extra-2.1-7t64 libevent-openssl-2.1-7t64 libevent-pthreads-2.1-7t64
#   libexpat1 libexpat1-dev libfabric1 libfido2-1 libgbm1 libgl-dev
#   libgl1-mesa-dri libglx-dev libglx-mesa0 libgpm2 libgudev-1.0-0
#   libhsa-runtime64-1 libhsakmt1 libhwloc-dev libhwloc-plugins libhwloc15
#   libibverbs-dev libibverbs1 libinput-bin libinput10 libjs-jquery-ui
#   libjs-sphinxdoc libjs-underscore libjsoncpp25 libllvm17t64 libllvm20
#   libltdl-dev libmagic-mgc libmagic1t64 libmd4c0 libmtdev1t64 libmunge2
#   libncurses6 libnl-3-200 libnl-3-dev libnl-route-3-200 libnl-route-3-dev
#   libnuma-dev libnuma1 libopengl-dev libopenmpi-dev libopenmpi3t64
#   libpcre2-16-0 libpmix-dev libpmix2t64 libproxy1v5 libpsm-infinipath1
#   libpsm2-2 libpthread-stubs0-dev libpython3-stdlib libpython3.12-dev
#   libpython3.12-minimal libpython3.12-stdlib libpython3.12t64 libqt5core5t64
#   libqt5dbus5t64 libqt5gui5t64 libqt5network5t64 libqt5qml5 libqt5qmlmodels5
#   libqt5quick5 libqt5svg5 libqt5waylandclient5 libqt5waylandcompositor5
#   libqt5widgets5t64 libqt6concurrent6t64 libqt6core6t64 libqt6dbus6t64
#   libqt6gui6t64 libqt6network6t64 libqt6opengl6t64 libqt6openglwidgets6t64
#   libqt6printsupport6t64 libqt6qml6 libqt6qmlmodels6 libqt6quick6
#   libqt6sql6-sqlite libqt6sql6t64 libqt6test6t64 libqt6waylandclient6
#   libqt6waylandcompositor6 libqt6waylandeglclienthwintegration6
#   libqt6waylandeglcompositorhwintegration6 libqt6widgets6t64
#   libqt6wlshellintegration6 libqt6xml6t64 librdmacm1t64 librhash0 libssl-dev
#   libssl3t64 libtool libts0t64 libucx0 libuv1t64 libvulkan-dev libwacom-common
#   libwacom9 libx11-dev libxau-dev libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-shape0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcb1-dev libxdmcp-dev libxkbcommon-x11-0
#   libxml2-dev libxmuu1 libxnvctrl0 libxslt1.1 m4 mesa-libgallium
#   mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common openssh-client python3 python3-dev python3-minimal python3.12
#   python3.12-dev python3.12-minimal qmake6 qmake6-bin qt5-gtk-platformtheme
#   qt6-base-dev-tools qt6-gtk-platformtheme qt6-qpa-plugins
#   qt6-translations-l10n qt6-wayland qttranslations5-l10n qtwayland5
#   x11proto-dev xauth xorg-sgml-doctools xtrans-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc gettext cmake-doc cmake-format
#   elpa-cmake-mode ninja-build gettext-base git-daemon-run
#   | git-daemon-sysvinit git-doc git-email git-gui gitk gitweb git-cvs
#   git-mediawiki git-svn apache2 | lighttpd | httpd lrzip libboost-doc graphviz
#   libboost1.83-doc gccxml libboost-contract1.83-dev libmpfrc++-dev libntl-dev
#   xsltproc doxygen docbook-xml docbook-xsl default-jdk fop gpm
#   libhwloc-contrib-plugins libjs-jquery-ui-docs libtool-doc ncurses-doc
#   openmpi-doc qgnomeplatform-qt5 qt5-image-formats-plugins
#   qt5-qmltooling-plugins qt6-qmltooling-plugins libssl-doc gcj-jdk
#   libwacom-bin libx11-doc libxcb-doc libxerces-c-doc pkg-config m4-doc
#   opencl-icd keychain libpam-ssh monkeysphere ssh-askpass python3-doc
#   python3-tk python3-venv python3.12-venv python3.12-doc binfmt-support
# Recommended packages:
#   less
# The following NEW packages will be installed:
#   autoconf automake autotools-dev cmake cmake-data cmake-qt-gui file
#   ibverbs-providers javascript-common libamd-comgr2 libamdhip64-5
#   libarchive13t64 libb2-1 libboost-all-dev libboost-atomic-dev
#   libboost-atomic1.83-dev libboost-atomic1.83.0 libboost-chrono-dev
#   libboost-chrono1.83-dev libboost-chrono1.83.0t64 libboost-container-dev
#   libboost-container1.83-dev libboost-container1.83.0 libboost-context-dev
#   libboost-context1.83-dev libboost-context1.83.0 libboost-coroutine-dev
#   libboost-coroutine1.83-dev libboost-coroutine1.83.0 libboost-date-time-dev
#   libboost-date-time1.83-dev libboost-date-time1.83.0 libboost-dev
#   libboost-exception-dev libboost-exception1.83-dev libboost-fiber-dev
#   libboost-fiber1.83-dev libboost-fiber1.83.0 libboost-filesystem-dev
#   libboost-filesystem1.83-dev libboost-filesystem1.83.0 libboost-graph-dev
#   libboost-graph-parallel-dev libboost-graph-parallel1.83-dev
#   libboost-graph-parallel1.83.0 libboost-graph1.83-dev libboost-graph1.83.0
#   libboost-iostreams-dev libboost-iostreams1.83-dev libboost-iostreams1.83.0
#   libboost-json-dev libboost-json1.83-dev libboost-json1.83.0
#   libboost-locale-dev libboost-locale1.83-dev libboost-locale1.83.0
#   libboost-log-dev libboost-log1.83-dev libboost-log1.83.0 libboost-math-dev
#   libboost-math1.83-dev libboost-math1.83.0 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.83-dev
#   libboost-mpi-python1.83.0 libboost-mpi1.83-dev libboost-mpi1.83.0
#   libboost-nowide-dev libboost-nowide1.83-dev libboost-nowide1.83.0
#   libboost-numpy-dev libboost-numpy1.83-dev libboost-numpy1.83.0
#   libboost-program-options-dev libboost-program-options1.83-dev
#   libboost-program-options1.83.0 libboost-python-dev libboost-python1.83-dev
#   libboost-python1.83.0 libboost-random-dev libboost-random1.83-dev
#   libboost-random1.83.0 libboost-regex-dev libboost-regex1.83-dev
#   libboost-regex1.83.0 libboost-serialization-dev
#   libboost-serialization1.83-dev libboost-serialization1.83.0
#   libboost-stacktrace-dev libboost-stacktrace1.83-dev
#   libboost-stacktrace1.83.0 libboost-system-dev libboost-system1.83-dev
#   libboost-system1.83.0 libboost-test-dev libboost-test1.83-dev
#   libboost-test1.83.0 libboost-thread-dev libboost-thread1.83-dev
#   libboost-thread1.83.0 libboost-timer-dev libboost-timer1.83-dev
#   libboost-timer1.83.0 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.83-dev libboost-type-erasure1.83.0 libboost-url-dev
#   libboost-url1.83-dev libboost-url1.83.0 libboost-wave-dev
#   libboost-wave1.83-dev libboost-wave1.83.0 libboost1.83-dev
#   libboost1.83-tools-dev libcaf-openmpi-3t64 libcbor0.10 libcoarrays-dev
#   libcoarrays-openmpi-dev libdouble-conversion3 libegl-mesa0 libegl1 libevdev2
#   libevent-2.1-7t64 libevent-core-2.1-7t64 libevent-dev
#   libevent-extra-2.1-7t64 libevent-openssl-2.1-7t64 libevent-pthreads-2.1-7t64
#   libexpat1-dev libfabric1 libfido2-1 libgl-dev libglx-dev libgpm2
#   libgudev-1.0-0 libhsa-runtime64-1 libhsakmt1 libhwloc-dev libhwloc-plugins
#   libhwloc15 libibverbs-dev libibverbs1 libinput-bin libinput10
#   libjs-jquery-ui libjs-sphinxdoc libjs-underscore libjsoncpp25 libllvm17t64
#   libllvm20 libltdl-dev libmagic-mgc libmagic1t64 libmd4c0 libmtdev1t64
#   libmunge2 libncurses-dev libncurses6 libnl-3-200 libnl-3-dev
#   libnl-route-3-200 libnl-route-3-dev libnuma-dev libnuma1 libopengl-dev
#   libopenmpi-dev libopenmpi3t64 libpcre2-16-0 libpmix-dev libpmix2t64
#   libproxy1v5 libpsm-infinipath1 libpsm2-2 libpthread-stubs0-dev
#   libpython3-dev libpython3.12-dev libpython3.12t64 libqt5core5t64
#   libqt5dbus5t64 libqt5gui5t64 libqt5network5t64 libqt5qml5 libqt5qmlmodels5
#   libqt5quick5 libqt5svg5 libqt5waylandclient5 libqt5waylandcompositor5
#   libqt5widgets5t64 libqt6concurrent6t64 libqt6core6t64 libqt6dbus6t64
#   libqt6gui6t64 libqt6network6t64 libqt6opengl6t64 libqt6openglwidgets6t64
#   libqt6printsupport6t64 libqt6qml6 libqt6qmlmodels6 libqt6quick6
#   libqt6sql6-sqlite libqt6sql6t64 libqt6test6t64 libqt6waylandclient6
#   libqt6waylandcompositor6 libqt6waylandeglclienthwintegration6
#   libqt6waylandeglcompositorhwintegration6 libqt6widgets6t64
#   libqt6wlshellintegration6 libqt6xml6t64 librdmacm1t64 librhash0 libtool
#   libts0t64 libucx0 libuv1t64 libvulkan-dev libwacom-common libwacom9
#   libx11-dev libxau-dev libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-shape0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcb1-dev libxdmcp-dev libxerces-c-dev
#   libxkbcommon-x11-0 libxml2-utils libxmuu1 libxnvctrl0 libxslt1-dev
#   libxslt1.1 m4 mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common openssh-client python3-dev python3-docopt python3.12-dev
#   qmake6 qmake6-bin qt5-gtk-platformtheme qt6-base-dev qt6-base-dev-tools
#   qt6-gtk-platformtheme qt6-qpa-plugins qt6-translations-l10n qt6-wayland
#   qttranslations5-l10n qtwayland5 x11proto-dev xauth xorg-sgml-doctools
#   xtrans-dev
# The following packages will be upgraded:
#   git git-man libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-radeon1
#   libdrm2 libexpat1 libgbm1 libgl1-mesa-dri libglx-mesa0 libpython3-stdlib
#   libpython3.12-minimal libpython3.12-stdlib libssl-dev libssl3t64 libxml2
#   libxml2-dev mesa-libgallium openssl python3 python3-minimal python3.12
#   python3.12-minimal
# 24 upgraded, 265 newly installed, 0 to remove and 168 not upgraded.
# Need to get 230 MB of archives.
# After this operation, 1 107 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-minimal amd64 3.12.3-0ubuntu2.1 [27,4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3 amd64 3.12.3-0ubuntu2.1 [23,0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3.12 amd64 3.12.3-1ubuntu0.13 [662 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libxnvctrl0 610.43.02-1ubuntu1 [11,2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3.12-stdlib amd64 3.12.3-1ubuntu0.13 [2 068 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libssl-dev amd64 3.0.13-0ubuntu3.9 [2 407 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libssl3t64 amd64 3.0.13-0ubuntu3.9 [1 941 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3.12-minimal amd64 3.12.3-1ubuntu0.13 [2 346 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3.12-minimal amd64 3.12.3-1ubuntu0.13 [837 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libexpat1 amd64 2.6.1-2ubuntu0.4 [88,2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3-stdlib amd64 3.12.3-0ubuntu2.1 [10,1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libxml2-dev amd64 2.9.14+dfsg-1.3ubuntu3.7 [782 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libxml2 amd64 2.9.14+dfsg-1.3ubuntu3.7 [764 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 openssl amd64 3.0.13-0ubuntu3.9 [1 002 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/main amd64 libmagic-mgc amd64 1:5.45-3build1 [307 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble/main amd64 libmagic1t64 amd64 1:5.45-3build1 [87,2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/main amd64 file amd64 1:5.45-3build1 [22,0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-3-200 amd64 3.7.0-0.3build1.1 [55,7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-route-3-200 amd64 3.7.0-0.3build1.1 [189 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libibverbs1 amd64 50.0-2ubuntu0.2 [68,0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 ibverbs-providers amd64 50.0-2ubuntu0.2 [381 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble/main amd64 libcbor0.10 amd64 0.10.2-1.2ubuntu2 [25,8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-common all 2.4.125-1ubuntu0.1~24.04.1 [9 174 B]
# Get:24 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm2 amd64 2.4.125-1ubuntu0.1~24.04.1 [41,3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble/main amd64 libevdev2 amd64 1.13.1+dfsg-1build1 [37,8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble/main amd64 libfido2-1 amd64 1.14.0-1build3 [83,5 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble/main amd64 libgpm2 amd64 1.20.7-11 [14,1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble/main amd64 libncurses6 amd64 6.4+20240113-1ubuntu2 [112 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnuma1 amd64 2.0.18-1ubuntu0.24.04.1 [23,4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu noble/main amd64 libuv1t64 amd64 1.48.0-1.1build1 [97,3 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble/main amd64 libxmuu1 amd64 2:1.1.3-3build2 [8 958 B]
# Get:32 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 git-man all 1:2.43.0-1ubuntu7.3 [1 100 kB]
# Get:33 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 git amd64 1:2.43.0-1ubuntu7.3 [3 680 kB]
# Get:34 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 openssh-client amd64 1:9.6p1-3ubuntu13.16 [907 kB]
# Get:35 http://archive.ubuntu.com/ubuntu noble/main amd64 xauth amd64 1:1.1.2-1build1 [25,6 kB]
# Get:36 http://archive.ubuntu.com/ubuntu noble/main amd64 m4 amd64 1.4.19-4build1 [244 kB]
# Get:37 http://archive.ubuntu.com/ubuntu noble/main amd64 autoconf all 2.71-3 [339 kB]
# Get:38 http://archive.ubuntu.com/ubuntu noble/main amd64 autotools-dev all 20220109.1 [44,9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu noble/main amd64 automake all 1:1.16.5-1.3ubuntu1 [558 kB]
# Get:40 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libarchive13t64 amd64 3.7.2-2ubuntu0.7 [382 kB]
# Get:41 http://archive.ubuntu.com/ubuntu noble/main amd64 libjsoncpp25 amd64 1.9.5-6build1 [82,8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu noble/main amd64 librhash0 amd64 1.4.3-3build1 [129 kB]
# Get:43 http://archive.ubuntu.com/ubuntu noble/main amd64 cmake-data all 3.28.3-1build7 [2 155 kB]
# Get:44 http://archive.ubuntu.com/ubuntu noble/main amd64 cmake amd64 3.28.3-1build7 [11,2 MB]
# Get:45 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdouble-conversion3 amd64 3.3.0-1build1 [40,3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpcre2-16-0 amd64 10.42-4ubuntu2.1 [210 kB]
# Get:47 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5core5t64 amd64 5.15.13+dfsg-1ubuntu1 [2 011 kB]
# Get:48 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgl1-mesa-dri amd64 25.2.8-0ubuntu0.24.04.1 [37,9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libglx-mesa0 amd64 25.2.8-0ubuntu0.24.04.1 [110 kB]
# Get:50 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-amdgpu1 amd64 2.4.125-1ubuntu0.1~24.04.1 [21,4 kB]
# Get:51 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-intel1 amd64 2.4.125-1ubuntu0.1~24.04.1 [63,8 kB]
# Get:52 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libllvm20 amd64 1:20.1.2-0ubuntu1~24.04.2 [30,6 MB]
# Get:53 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgbm1 amd64 25.2.8-0ubuntu0.24.04.1 [34,2 kB]
# Get:54 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 mesa-libgallium amd64 25.2.8-0ubuntu0.24.04.1 [10,8 MB]
# Get:55 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libegl-mesa0 amd64 25.2.8-0ubuntu0.24.04.1 [117 kB]
# Get:56 http://archive.ubuntu.com/ubuntu noble/main amd64 libegl1 amd64 1.7.0-1build1 [28,7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu noble/main amd64 libmtdev1t64 amd64 1.1.6-1.1build1 [14,4 kB]
# Get:58 http://archive.ubuntu.com/ubuntu noble/main amd64 libgudev-1.0-0 amd64 1:238-5ubuntu1 [15,9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu noble/main amd64 libwacom-common all 2.10.0-2 [63,4 kB]
# Get:60 http://archive.ubuntu.com/ubuntu noble/main amd64 libwacom9 amd64 2.10.0-2 [23,9 kB]
# Get:61 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libinput-bin amd64 1.25.0-1ubuntu3.4 [23,1 kB]
# Get:62 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libinput10 amd64 1.25.0-1ubuntu3.4 [133 kB]
# Get:63 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmd4c0 amd64 0.4.8-1build1 [42,3 kB]
# Get:64 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5dbus5t64 amd64 5.15.13+dfsg-1ubuntu1 [220 kB]
# Get:65 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5network5t64 amd64 5.15.13+dfsg-1ubuntu1 [723 kB]
# Get:66 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build3 [10,8 kB]
# Get:67 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-util1 amd64 0.4.0-1build3 [10,7 kB]
# Get:68 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-image0 amd64 0.4.0-2build1 [10,8 kB]
# Get:69 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-keysyms1 amd64 0.4.0-1build4 [7 956 B]
# Get:70 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-render-util0 amd64 0.3.9-1build4 [9 608 B]
# Get:71 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-shape0 amd64 1.15-1ubuntu2 [6 100 B]
# Get:72 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xinerama0 amd64 1.15-1ubuntu2 [5 410 B]
# Get:73 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xinput0 amd64 1.15-1ubuntu2 [33,2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xkb1 amd64 1.15-1ubuntu2 [32,3 kB]
# Get:75 http://archive.ubuntu.com/ubuntu noble/main amd64 libxkbcommon-x11-0 amd64 1.6.0-1build1 [14,5 kB]
# Get:76 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5gui5t64 amd64 5.15.13+dfsg-1ubuntu1 [3 748 kB]
# Get:77 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5widgets5t64 amd64 5.15.13+dfsg-1ubuntu1 [2 561 kB]
# Get:78 http://archive.ubuntu.com/ubuntu noble/universe amd64 cmake-qt-gui amd64 3.28.3-1build7 [3 644 kB]
# Get:79 http://archive.ubuntu.com/ubuntu noble/main amd64 javascript-common all 11+nmu1 [5 936 B]
# Get:80 http://archive.ubuntu.com/ubuntu noble/main amd64 libllvm17t64 amd64 1:17.0.6-9ubuntu1 [26,2 MB]
# Get:81 http://archive.ubuntu.com/ubuntu noble/universe amd64 libamd-comgr2 amd64 6.0+git20231212.4510c28+dfsg-3build2 [14,4 MB]
# Get:82 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhsakmt1 amd64 5.7.0-1build1 [62,9 kB]
# Get:83 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhsa-runtime64-1 amd64 5.7.1-2build1 [491 kB]
# Get:84 http://archive.ubuntu.com/ubuntu noble/universe amd64 libamdhip64-5 amd64 5.7.1-3 [9 621 kB]
# Get:85 http://archive.ubuntu.com/ubuntu noble/universe amd64 libb2-1 amd64 0.98.1-1.1build1 [45,0 kB]
# Get:86 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost1.83-dev amd64 1.83.0-2.1ubuntu3.2 [10,7 MB]
# Get:87 http://archive.ubuntu.com/ubuntu noble/main amd64 libboost-dev amd64 1.83.0.1ubuntu2 [4 308 B]
# Get:88 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost1.83-tools-dev amd64 1.83.0-2.1ubuntu3.2 [1 402 kB]
# Get:89 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-tools-dev amd64 1.83.0.1ubuntu2 [4 238 B]
# Get:90 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-atomic1.83.0 amd64 1.83.0-2.1ubuntu3.2 [240 kB]
# Get:91 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-atomic1.83-dev amd64 1.83.0-2.1ubuntu3.2 [235 kB]
# Get:92 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-atomic-dev amd64 1.83.0.1ubuntu2 [4 360 B]
# Get:93 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-chrono1.83.0t64 amd64 1.83.0-2.1ubuntu3.2 [245 kB]
# Get:94 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-chrono1.83-dev amd64 1.83.0-2.1ubuntu3.2 [246 kB]
# Get:95 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-chrono-dev amd64 1.83.0.1ubuntu2 [4 672 B]
# Get:96 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-container1.83.0 amd64 1.83.0-2.1ubuntu3.2 [261 kB]
# Get:97 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-container1.83-dev amd64 1.83.0-2.1ubuntu3.2 [267 kB]
# Get:98 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-container-dev amd64 1.83.0.1ubuntu2 [4 530 B]
# Get:99 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-date-time1.83.0 amd64 1.83.0-2.1ubuntu3.2 [236 kB]
# Get:100 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-serialization1.83.0 amd64 1.83.0-2.1ubuntu3.2 [341 kB]
# Get:101 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-serialization1.83-dev amd64 1.83.0-2.1ubuntu3.2 [387 kB]
# Get:102 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-date-time1.83-dev amd64 1.83.0-2.1ubuntu3.2 [239 kB]
# Get:103 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-system1.83.0 amd64 1.83.0-2.1ubuntu3.2 [236 kB]
# Get:104 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-system1.83-dev amd64 1.83.0-2.1ubuntu3.2 [231 kB]
# Get:105 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-thread1.83.0 amd64 1.83.0-2.1ubuntu3.2 [276 kB]
# Get:106 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-thread1.83-dev amd64 1.83.0-2.1ubuntu3.2 [282 kB]
# Get:107 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-context1.83.0 amd64 1.83.0-2.1ubuntu3.2 [237 kB]
# Get:108 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-context1.83-dev amd64 1.83.0-2.1ubuntu3.2 [232 kB]
# Get:109 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-context-dev amd64 1.83.0.1ubuntu2 [4 276 B]
# Get:110 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-coroutine1.83.0 amd64 1.83.0-2.1ubuntu3.2 [234 kB]
# Get:111 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-coroutine1.83-dev amd64 1.83.0-2.1ubuntu3.2 [237 kB]
# Get:112 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-coroutine-dev amd64 1.83.0.1ubuntu2 [4 344 B]
# Get:113 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-date-time-dev amd64 1.83.0.1ubuntu2 [4 058 B]
# Get:114 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-exception1.83-dev amd64 1.83.0-2.1ubuntu3.2 [229 kB]
# Get:115 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-exception-dev amd64 1.83.0.1ubuntu2 [4 058 B]
# Get:116 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-filesystem1.83.0 amd64 1.83.0-2.1ubuntu3.2 [284 kB]
# Get:117 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-filesystem1.83-dev amd64 1.83.0-2.1ubuntu3.2 [301 kB]
# Get:118 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-fiber1.83.0 amd64 1.83.0-2.1ubuntu3.2 [255 kB]
# Get:119 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-fiber1.83-dev amd64 1.83.0-2.1ubuntu3.2 [268 kB]
# Get:120 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-fiber-dev amd64 1.83.0.1ubuntu2 [4 486 B]
# Get:121 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-filesystem-dev amd64 1.83.0.1ubuntu2 [4 096 B]
# Get:122 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-graph1.83.0 amd64 1.83.0-2.1ubuntu3.2 [361 kB]
# Get:123 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-regex1.83.0 amd64 1.83.0-2.1ubuntu3.2 [340 kB]
# Get:124 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-regex1.83-dev amd64 1.83.0-2.1ubuntu3.2 [355 kB]
# Get:125 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-test1.83.0 amd64 1.83.0-2.1ubuntu3.2 [454 kB]
# Get:126 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-test1.83-dev amd64 1.83.0-2.1ubuntu3.2 [566 kB]
# Get:127 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-graph1.83-dev amd64 1.83.0-2.1ubuntu3.2 [399 kB]
# Get:128 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-graph-dev amd64 1.83.0.1ubuntu2 [4 160 B]
# Get:129 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-core-2.1-7t64 amd64 2.1.12-stable-9ubuntu2 [91,3 kB]
# Get:130 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-pthreads-2.1-7t64 amd64 2.1.12-stable-9ubuntu2 [7 982 B]
# Get:131 http://archive.ubuntu.com/ubuntu noble/universe amd64 libpsm-infinipath1 amd64 3.3+20.604758e7-6.3build1 [178 kB]
# Get:132 http://archive.ubuntu.com/ubuntu noble/universe amd64 libpsm2-2 amd64 11.2.185-2build1 [194 kB]
# Get:133 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 librdmacm1t64 amd64 50.0-2ubuntu0.2 [70,7 kB]
# Get:134 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfabric1 amd64 1.17.0-3build2 [657 kB]
# Get:135 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwloc15 amd64 2.10.0-1build1 [172 kB]
# Get:136 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libmunge2 amd64 0.5.15-4ubuntu0.1 [14,8 kB]
# Get:137 http://archive.ubuntu.com/ubuntu noble/universe amd64 ocl-icd-libopencl1 amd64 2.3.2-1build1 [38,5 kB]
# Get:138 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwloc-plugins amd64 2.10.0-1build1 [15,7 kB]
# Get:139 http://archive.ubuntu.com/ubuntu noble/universe amd64 libpmix2t64 amd64 5.0.1-4.1build1 [697 kB]
# Get:140 http://archive.ubuntu.com/ubuntu noble/universe amd64 libucx0 amd64 1.16.0+ds-5ubuntu1 [1 140 kB]
# Get:141 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopenmpi3t64 amd64 4.1.6-7ubuntu2 [2 563 kB]
# Get:142 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-mpi1.83.0 amd64 1.83.0-2.1ubuntu3.2 [271 kB]
# Get:143 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-graph-parallel1.83.0 amd64 1.83.0-2.1ubuntu3.2 [278 kB]
# Get:144 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-graph-parallel1.83-dev amd64 1.83.0-2.1ubuntu3.2 [288 kB]
# Get:145 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-graph-parallel-dev amd64 1.83.0.1ubuntu2 [4 192 B]
# Get:146 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-iostreams1.83.0 amd64 1.83.0-2.1ubuntu3.2 [260 kB]
# Get:147 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-iostreams1.83-dev amd64 1.83.0-2.1ubuntu3.2 [264 kB]
# Get:148 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-iostreams-dev amd64 1.83.0.1ubuntu2 [4 046 B]
# Get:149 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-json1.83.0 amd64 1.83.0-2.1ubuntu3.2 [365 kB]
# Get:150 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-json1.83-dev amd64 1.83.0-2.1ubuntu3.2 [380 kB]
# Get:151 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-json-dev amd64 1.83.0.1ubuntu2 [4 172 B]
# Get:152 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-locale1.83.0 amd64 1.83.0-2.1ubuntu3.2 [413 kB]
# Get:153 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-locale1.83-dev amd64 1.83.0-2.1ubuntu3.2 [582 kB]
# Get:154 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-locale-dev amd64 1.83.0.1ubuntu2 [4 378 B]
# Get:155 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-log1.83.0 amd64 1.83.0-2.1ubuntu3.2 [679 kB]
# Get:156 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-log1.83-dev amd64 1.83.0-2.1ubuntu3.2 [937 kB]
# Get:157 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-log-dev amd64 1.83.0.1ubuntu2 [4 260 B]
# Get:158 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-math1.83.0 amd64 1.83.0-2.1ubuntu3.2 [440 kB]
# Get:159 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-math1.83-dev amd64 1.83.0-2.1ubuntu3.2 [586 kB]
# Get:160 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-math-dev amd64 1.83.0.1ubuntu2 [4 264 B]
# Get:161 http://archive.ubuntu.com/ubuntu noble/universe amd64 openmpi-common all 4.1.6-7ubuntu2 [170 kB]
# Get:162 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-3-dev amd64 3.7.0-0.3build1.1 [99,5 kB]
# Get:163 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-route-3-dev amd64 3.7.0-0.3build1.1 [216 kB]
# Get:164 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libibverbs-dev amd64 50.0-2ubuntu0.2 [686 kB]
# Get:165 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnuma-dev amd64 2.0.18-1ubuntu0.24.04.1 [37,0 kB]
# Get:166 http://archive.ubuntu.com/ubuntu noble/main amd64 libltdl-dev amd64 2.4.7-7build1 [168 kB]
# Get:167 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwloc-dev amd64 2.10.0-1build1 [268 kB]
# Get:168 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-2.1-7t64 amd64 2.1.12-stable-9ubuntu2 [145 kB]
# Get:169 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-extra-2.1-7t64 amd64 2.1.12-stable-9ubuntu2 [64,2 kB]
# Get:170 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-openssl-2.1-7t64 amd64 2.1.12-stable-9ubuntu2 [15,7 kB]
# Get:171 http://archive.ubuntu.com/ubuntu noble/main amd64 libevent-dev amd64 2.1.12-stable-9ubuntu2 [274 kB]
# Get:172 http://archive.ubuntu.com/ubuntu noble/universe amd64 libpmix-dev amd64 5.0.1-4.1build1 [4 018 kB]
# Get:173 http://archive.ubuntu.com/ubuntu noble/universe amd64 libjs-jquery-ui all 1.13.2+dfsg-1 [252 kB]
# Get:174 http://archive.ubuntu.com/ubuntu noble/universe amd64 openmpi-bin amd64 4.1.6-7ubuntu2 [114 kB]
# Get:175 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopenmpi-dev amd64 4.1.6-7ubuntu2 [864 kB]
# Get:176 http://archive.ubuntu.com/ubuntu noble/universe amd64 mpi-default-dev amd64 1.15build1 [3 154 B]
# Get:177 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-mpi1.83-dev amd64 1.83.0-2.1ubuntu3.2 [296 kB]
# Get:178 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-mpi-dev amd64 1.83.0.1ubuntu2 [4 144 B]
# Get:179 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-python1.83.0 amd64 1.83.0-2.1ubuntu3.2 [312 kB]
# Get:180 http://archive.ubuntu.com/ubuntu noble/universe amd64 mpi-default-bin amd64 1.15build1 [2 376 B]
# Get:181 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-mpi-python1.83.0 amd64 1.83.0-2.1ubuntu3.2 [362 kB]
# Get:182 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-mpi-python1.83-dev amd64 1.83.0-2.1ubuntu3.2 [237 kB]
# Get:183 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-mpi-python-dev amd64 1.83.0.1ubuntu2 [4 196 B]
# Get:184 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-numpy1.83.0 amd64 1.83.0-2.1ubuntu3.2 [242 kB]
# Get:185 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-numpy1.83-dev amd64 1.83.0-2.1ubuntu3.2 [247 kB]
# Get:186 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-numpy-dev amd64 1.83.0.1ubuntu2 [4 100 B]
# Get:187 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-program-options1.83.0 amd64 1.83.0-2.1ubuntu3.2 [321 kB]
# Get:188 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-program-options1.83-dev amd64 1.83.0-2.1ubuntu3.2 [388 kB]
# Get:189 http://archive.ubuntu.com/ubuntu noble/main amd64 libboost-program-options-dev amd64 1.83.0.1ubuntu2 [4 086 B]
# Get:190 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3.12t64 amd64 3.12.3-1ubuntu0.13 [2 338 kB]
# Get:191 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libexpat1-dev amd64 2.6.1-2ubuntu0.4 [140 kB]
# Get:192 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3.12-dev amd64 3.12.3-1ubuntu0.13 [5 682 kB]
# Get:193 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpython3-dev amd64 3.12.3-0ubuntu2.1 [10,3 kB]
# Get:194 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3.12-dev amd64 3.12.3-1ubuntu0.13 [498 kB]
# Get:195 http://archive.ubuntu.com/ubuntu noble/main amd64 libjs-underscore all 1.13.4~dfsg+~1.11.4-3 [118 kB]
# Get:196 http://archive.ubuntu.com/ubuntu noble/main amd64 libjs-sphinxdoc all 7.2.6-6 [149 kB]
# Get:197 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-dev amd64 3.12.3-0ubuntu2.1 [26,7 kB]
# Get:198 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-python1.83-dev amd64 1.83.0-2.1ubuntu3.2 [337 kB]
# Get:199 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-python-dev amd64 1.83.0.1ubuntu2 [4 344 B]
# Get:200 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-random1.83.0 amd64 1.83.0-2.1ubuntu3.2 [242 kB]
# Get:201 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-random1.83-dev amd64 1.83.0-2.1ubuntu3.2 [241 kB]
# Get:202 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-random-dev amd64 1.83.0.1ubuntu2 [4 062 B]
# Get:203 http://archive.ubuntu.com/ubuntu noble/main amd64 libboost-regex-dev amd64 1.83.0.1ubuntu2 [4 324 B]
# Get:204 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-serialization-dev amd64 1.83.0.1ubuntu2 [4 280 B]
# Get:205 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-stacktrace1.83.0 amd64 1.83.0-2.1ubuntu3.2 [290 kB]
# Get:206 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-stacktrace1.83-dev amd64 1.83.0-2.1ubuntu3.2 [247 kB]
# Get:207 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-stacktrace-dev amd64 1.83.0.1ubuntu2 [4 068 B]
# Get:208 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-system-dev amd64 1.83.0.1ubuntu2 [4 206 B]
# Get:209 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-test-dev amd64 1.83.0.1ubuntu2 [4 090 B]
# Get:210 http://archive.ubuntu.com/ubuntu noble/main amd64 libboost-thread-dev amd64 1.83.0.1ubuntu2 [4 088 B]
# Get:211 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-timer1.83.0 amd64 1.83.0-2.1ubuntu3.2 [241 kB]
# Get:212 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-timer1.83-dev amd64 1.83.0-2.1ubuntu3.2 [237 kB]
# Get:213 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-timer-dev amd64 1.83.0.1ubuntu2 [4 190 B]
# Get:214 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-type-erasure1.83.0 amd64 1.83.0-2.1ubuntu3.2 [246 kB]
# Get:215 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-type-erasure1.83-dev amd64 1.83.0-2.1ubuntu3.2 [250 kB]
# Get:216 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-type-erasure-dev amd64 1.83.0.1ubuntu2 [4 162 B]
# Get:217 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libboost-url1.83.0 amd64 1.83.0-2.1ubuntu3.2 [343 kB]
# Get:218 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-url1.83-dev amd64 1.83.0-2.1ubuntu3.2 [444 kB]
# Get:219 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-url-dev amd64 1.83.0.1ubuntu2 [4 192 B]
# Get:220 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-wave1.83.0 amd64 1.83.0-2.1ubuntu3.2 [454 kB]
# Get:221 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-wave1.83-dev amd64 1.83.0-2.1ubuntu3.2 [499 kB]
# Get:222 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-wave-dev amd64 1.83.0.1ubuntu2 [4 096 B]
# Get:223 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-nowide1.83.0 amd64 1.83.0-2.1ubuntu3.2 [240 kB]
# Get:224 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libboost-nowide1.83-dev amd64 1.83.0-2.1ubuntu3.2 [236 kB]
# Get:225 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-nowide-dev amd64 1.83.0.1ubuntu2 [4 136 B]
# Get:226 http://archive.ubuntu.com/ubuntu noble/universe amd64 libboost-all-dev amd64 1.83.0.1ubuntu2 [2 286 B]
# Get:227 http://archive.ubuntu.com/ubuntu noble/universe amd64 libcaf-openmpi-3t64 amd64 2.10.2+ds-2.1build2 [39,1 kB]
# Get:228 http://archive.ubuntu.com/ubuntu noble/universe amd64 libcoarrays-dev amd64 2.10.2+ds-2.1build2 [37,5 kB]
# Get:229 http://archive.ubuntu.com/ubuntu noble/universe amd64 libcoarrays-openmpi-dev amd64 2.10.2+ds-2.1build2 [372 kB]
# Get:230 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-radeon1 amd64 2.4.125-1ubuntu0.1~24.04.1 [20,8 kB]
# Get:231 http://archive.ubuntu.com/ubuntu noble/main amd64 xorg-sgml-doctools all 1:1.11-1.1 [10,9 kB]
# Get:232 http://archive.ubuntu.com/ubuntu noble/main amd64 x11proto-dev all 2023.2-1 [602 kB]
# Get:233 http://archive.ubuntu.com/ubuntu noble/main amd64 libxau-dev amd64 1:1.0.9-1build6 [9 570 B]
# Get:234 http://archive.ubuntu.com/ubuntu noble/main amd64 libxdmcp-dev amd64 1:1.1.3-0ubuntu6 [26,5 kB]
# Get:235 http://archive.ubuntu.com/ubuntu noble/main amd64 xtrans-dev all 1.4.0-1 [68,9 kB]
# Get:236 http://archive.ubuntu.com/ubuntu noble/main amd64 libpthread-stubs0-dev amd64 0.4-1build3 [4 746 B]
# Get:237 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcb1-dev amd64 1.15-1ubuntu2 [85,8 kB]
# Get:238 http://archive.ubuntu.com/ubuntu noble/main amd64 libx11-dev amd64 2:1.8.7-1build1 [732 kB]
# Get:239 http://archive.ubuntu.com/ubuntu noble/main amd64 libglx-dev amd64 1.7.0-1build1 [14,2 kB]
# Get:240 http://archive.ubuntu.com/ubuntu noble/main amd64 libgl-dev amd64 1.7.0-1build1 [102 kB]
# Get:241 http://archive.ubuntu.com/ubuntu noble/main amd64 libncurses-dev amd64 6.4+20240113-1ubuntu2 [384 kB]
# Get:242 http://archive.ubuntu.com/ubuntu noble/main amd64 libopengl-dev amd64 1.7.0-1build1 [3 454 B]
# Get:243 http://archive.ubuntu.com/ubuntu noble/main amd64 libproxy1v5 amd64 0.5.4-4build1 [26,5 kB]
# Get:244 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libqt5qml5 amd64 5.15.13+dfsg-1ubuntu0.1 [1 482 kB]
# Get:245 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libqt5qmlmodels5 amd64 5.15.13+dfsg-1ubuntu0.1 [203 kB]
# Get:246 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libqt5quick5 amd64 5.15.13+dfsg-1ubuntu0.1 [1 733 kB]
# Get:247 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5svg5 amd64 5.15.13-1 [146 kB]
# Get:248 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5waylandclient5 amd64 5.15.13-1 [405 kB]
# Get:249 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt5waylandcompositor5 amd64 5.15.13-1 [396 kB]
# Get:250 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6core6t64 amd64 6.4.2+dfsg-21.1build5 [1 789 kB]
# Get:251 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6concurrent6t64 amd64 6.4.2+dfsg-21.1build5 [33,4 kB]
# Get:252 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6dbus6t64 amd64 6.4.2+dfsg-21.1build5 [267 kB]
# Get:253 http://archive.ubuntu.com/ubuntu noble/universe amd64 libts0t64 amd64 1.22-1.1build1 [63,8 kB]
# Get:254 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6gui6t64 amd64 6.4.2+dfsg-21.1build5 [3 119 kB]
# Get:255 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6network6t64 amd64 6.4.2+dfsg-21.1build5 [740 kB]
# Get:256 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6opengl6t64 amd64 6.4.2+dfsg-21.1build5 [420 kB]
# Get:257 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6widgets6t64 amd64 6.4.2+dfsg-21.1build5 [2 648 kB]
# Get:258 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6openglwidgets6t64 amd64 6.4.2+dfsg-21.1build5 [40,4 kB]
# Get:259 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6printsupport6t64 amd64 6.4.2+dfsg-21.1build5 [222 kB]
# Get:260 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6qml6 amd64 6.4.2+dfsg-4build3 [1 619 kB]
# Get:261 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6qmlmodels6 amd64 6.4.2+dfsg-4build3 [267 kB]
# Get:262 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6quick6 amd64 6.4.2+dfsg-4build3 [2 001 kB]
# Get:263 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6sql6t64 amd64 6.4.2+dfsg-21.1build5 [141 kB]
# Get:264 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6sql6-sqlite amd64 6.4.2+dfsg-21.1build5 [57,8 kB]
# Get:265 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6test6t64 amd64 6.4.2+dfsg-21.1build5 [167 kB]
# Get:266 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6waylandclient6 amd64 6.4.2-5build3 [251 kB]
# Get:267 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6waylandcompositor6 amd64 6.4.2-5build3 [427 kB]
# Get:268 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6waylandeglclienthwintegration6 amd64 6.4.2-5build3 [19,5 kB]
# Get:269 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6waylandeglcompositorhwintegration6 amd64 6.4.2-5build3 [15,2 kB]
# Get:270 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6wlshellintegration6 amd64 6.4.2-5build3 [38,0 kB]
# Get:271 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6xml6t64 amd64 6.4.2+dfsg-21.1build5 [75,9 kB]
# Get:272 http://archive.ubuntu.com/ubuntu noble/main amd64 libtool all 2.4.7-7build1 [166 kB]
# Get:273 http://archive.ubuntu.com/ubuntu noble/main amd64 libvulkan-dev amd64 1.3.275.0-1build1 [1 239 kB]
# Get:274 http://archive.ubuntu.com/ubuntu noble/universe amd64 libxerces-c-dev amd64 3.2.4+debian-1.2ubuntu2 [1 815 kB]
# Get:275 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libxml2-utils amd64 2.9.14+dfsg-1.3ubuntu3.7 [39,4 kB]
# Get:276 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libxslt1.1 amd64 1.1.39-0exp1ubuntu0.24.04.3 [168 kB]
# Get:277 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libxslt1-dev amd64 1.1.39-0exp1ubuntu0.24.04.3 [91,9 kB]
# Get:278 http://archive.ubuntu.com/ubuntu noble/universe amd64 python3-docopt all 0.6.2-6 [26,1 kB]
# Get:279 http://archive.ubuntu.com/ubuntu noble/universe amd64 qmake6-bin amd64 6.4.2+dfsg-21.1build5 [624 kB]
# Get:280 http://archive.ubuntu.com/ubuntu noble/universe amd64 qmake6 amd64 6.4.2+dfsg-21.1build5 [178 kB]
# Get:281 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt5-gtk-platformtheme amd64 5.15.13+dfsg-1ubuntu1 [125 kB]
# Get:282 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-base-dev-tools amd64 6.4.2+dfsg-21.1build5 [970 kB]
# Get:283 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-qpa-plugins amd64 6.4.2+dfsg-21.1build5 [89,3 kB]
# Get:284 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-base-dev amd64 6.4.2+dfsg-21.1build5 [1 458 kB]
# Get:285 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-gtk-platformtheme amd64 6.4.2+dfsg-21.1build5 [55,1 kB]
# Get:286 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-translations-l10n all 6.4.2-1 [1 761 kB]
# Get:287 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-wayland amd64 6.4.2-5build3 [127 kB]
# Get:288 http://archive.ubuntu.com/ubuntu noble/universe amd64 qttranslations5-l10n all 5.15.13-1 [1 964 kB]
# Get:289 http://archive.ubuntu.com/ubuntu noble/universe amd64 qtwayland5 amd64 5.15.13-1 [223 kB]
# Fetched 230 MB in 23s (10,2 MB/s)                                              0m
# debconf: delaying package configuration, since apt-utils is not installed
#
# (Reading database ... 41197 files and directories currently installed.)
# Preparing to unpack .../python3-minimal_3.12.3-0ubuntu2.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking python3-minimal (3.12.3-0ubuntu2.1) over (3.12.3-0ubuntu2) ...
# Setting up python3-minimal (3.12.3-0ubuntu2.1) ...
# (Reading database ... 41197 files and directories currently installed.)
# Preparing to unpack .../python3_3.12.3-0ubuntu2.1_amd64.deb ...
# running python pre-rtupdate hooks for python3.12...
# Unpacking python3 (3.12.3-0ubuntu2.1) over (3.12.3-0ubuntu2) ...
# Preparing to unpack .../python3.12_3.12.3-1ubuntu0.13_amd64.deb ...
# Unpacking python3.12 (3.12.3-1ubuntu0.13) over (3.12.3-1ubuntu0.4) ...
# Preparing to unpack .../libpython3.12-stdlib_3.12.3-1ubuntu0.13_amd64.deb ...
# Unpacking libpython3.12-stdlib:amd64 (3.12.3-1ubuntu0.13) over (3.12.3-1ubuntu0.4) ...
# Preparing to unpack .../libssl-dev_3.0.13-0ubuntu3.9_amd64.deb ...
# Unpacking libssl-dev:amd64 (3.0.13-0ubuntu3.9) over (3.0.13-0ubuntu3.4) ...
# 7Progress: [  1%] [..........................................................] 8Preparing to unpack .../libssl3t64_3.0.13-0ubuntu3.9_amd64.deb ...
# Unpacking libssl3t64:amd64 (3.0.13-0ubuntu3.9) over (3.0.13-0ubuntu3.4) ...
# Setting up libssl3t64:amd64 (3.0.13-0ubuntu3.9) ...
# (Reading database ... 41197 files and directories currently installed.)
# Preparing to unpack .../000-python3.12-minimal_3.12.3-1ubuntu0.13_amd64.deb ...
# Unpacking python3.12-minimal (3.12.3-1ubuntu0.13) over (3.12.3-1ubuntu0.4) ...
# Preparing to unpack .../001-libpython3.12-minimal_3.12.3-1ubuntu0.13_amd64.deb ...
# Unpacking libpython3.12-minimal:amd64 (3.12.3-1ubuntu0.13) over (3.12.3-1ubuntu0.4) ...
# Preparing to unpack .../002-libexpat1_2.6.1-2ubuntu0.4_amd64.deb ...
# Unpacking libexpat1:amd64 (2.6.1-2ubuntu0.4) over (2.6.1-2ubuntu0.2) ...
# Preparing to unpack .../003-libpython3-stdlib_3.12.3-0ubuntu2.1_amd64.deb ...
# Unpacking libpython3-stdlib:amd64 (3.12.3-0ubuntu2.1) over (3.12.3-0ubuntu2) ...
# 7Progress: [  2%] [#.........................................................] 8Preparing to unpack .../004-libxml2-dev_2.9.14+dfsg-1.3ubuntu3.7_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.14+dfsg-1.3ubuntu3.7) over (2.9.14+dfsg-1.3ubuntu3.1) ...
# Preparing to unpack .../005-libxml2_2.9.14+dfsg-1.3ubuntu3.7_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.14+dfsg-1.3ubuntu3.7) over (2.9.14+dfsg-1.3ubuntu3.1) ...
# Preparing to unpack .../006-openssl_3.0.13-0ubuntu3.9_amd64.deb ...
# Unpacking openssl (3.0.13-0ubuntu3.9) over (3.0.13-0ubuntu3.4) ...
# Selecting previously unselected package libmagic-mgc.
# ...
# Setting up libwacom-common (2.10.0-2) ...
# Setting up automake (1:1.16.5-1.3ubuntu1) ...
# update-alternatives: using /usr/bin/automake-1.16 to provide /usr/bin/automake (automake) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/automake.1.gz because associated file /usr/share/man/man1/automake-1.16.1.gz (of link group automake) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/aclocal.1.gz because associated file /usr/share/man/man1/aclocal-1.16.1.gz (of link group automake) doesn't exist
# Setting up python3.12-minimal (3.12.3-1ubuntu0.13) ...
# Setting up libqt6core6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libboost-wave1.83.0:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libncurses-dev:amd64 (6.4+20240113-1ubuntu2) ...
# Setting up libqt5dbus5t64:amd64 (5.15.13+dfsg-1ubuntu1) ...
# Setting up libboost-coroutine1.83.0:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-chrono1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libpython3.12-stdlib:amd64 (3.12.3-1ubuntu0.13) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libboost-math1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libtool (2.4.7-7build1) ...
# Setting up libboost-chrono-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libwacom9:amd64 (2.10.0-2) ...
# Setting up libevent-pthreads-2.1-7t64:amd64 (2.1.12-stable-9ubuntu2) ...
# Setting up libboost-log1.83.0 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libboost-iostreams1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up openssh-client (1:9.6p1-3ubuntu13.16) ...
# Setting up libboost-math-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up python3.12 (3.12.3-1ubuntu0.13) ...
# Setting up libevent-openssl-2.1-7t64:amd64 (2.1.12-stable-9ubuntu2) ...
# Setting up libboost-system-dev:amd64 (1.83.0.1ubuntu2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libqt5network5t64:amd64 (5.15.13+dfsg-1ubuntu1) ...
# Setting up libboost-serialization1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-locale1.83.0:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-test1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-url1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libqt6sql6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libboost-tools-dev (1.83.0.1ubuntu2) ...
# Setting up libqt6test6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt6dbus6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libboost-filesystem1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-exception-dev:amd64 (1.83.0.1ubuntu2) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libqt6concurrent6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libboost-iostreams-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libhwloc-plugins:amd64 (2.10.0-1build1) ...
# Setting up libboost-nowide-dev (1.83.0.1ubuntu2) ...
# Setting up libboost-graph1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libqt6xml6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libinput-bin (1.25.0-1ubuntu3.4) ...###########################################...............] 8
# Setting up libnuma-dev:amd64 (2.0.18-1ubuntu0.24.04.1) ...
# Setting up libnl-route-3-200:amd64 (3.7.0-0.3build1.1) ...
# Setting up libboost-test-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libpython3.12t64:amd64 (3.12.3-1ubuntu0.13) ...
# Setting up libltdl-dev:amd64 (2.4.7-7build1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libxml2-dev:amd64 (2.9.14+dfsg-1.3ubuntu3.7) ...
# Setting up libboost-timer1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libllvm17t64:amd64 (1:17.0.6-9ubuntu1) ...
# Setting up libboost-container1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libqt5qml5:amd64 (5.15.13+dfsg-1ubuntu0.1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libboost-date-time1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libqt6sql6-sqlite:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libboost-numpy-dev (1.83.0.1ubuntu2) ...
# Setting up libllvm20:amd64 (1:20.1.2-0ubuntu1~24.04.2) ...
# Setting up libboost-random1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-serialization-dev:amd64 (1.83.0.1ubuntu2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libpmix2t64:amd64 (5.0.1-4.1build1) ...
# Setting up git (1:2.43.0-1ubuntu7.3) ...
# Setting up libboost-date-time-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libjs-sphinxdoc (7.2.6-6) ...
# Setting up libevent-extra-2.1-7t64:amd64 (2.1.12-stable-9ubuntu2) ...
# Setting up qmake6-bin (6.4.2+dfsg-21.1build5) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libdrm2:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# Setting up libnl-3-dev:amd64 (3.7.0-0.3build1.1) ...
# Setting up xauth (1:1.1.2-1build1) ...
# Setting up libxslt1.1:amd64 (1.1.39-0exp1ubuntu0.24.04.3) ...
# Setting up libboost-url-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libhwloc-dev:amd64 (2.10.0-1build1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libqt6network6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libamd-comgr2:amd64 (6.0+git20231212.4510c28+dfsg-3build2) ...
# Setting up libxml2-utils (2.9.14+dfsg-1.3ubuntu3.7) ...
# Setting up libarchive13t64:amd64 (3.7.2-2ubuntu0.7) ...
# Setting up libboost-timer-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-filesystem-dev:amd64 (1.83.0.1ubuntu2) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libpython3-stdlib:amd64 (3.12.3-0ubuntu2.1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# Setting up libboost-thread1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libinput10:amd64 (1.25.0-1ubuntu3.4) ...
# Setting up libboost-graph-dev:amd64 (1.83.0.1ubuntu2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libibverbs1:amd64 (50.0-2ubuntu0.2) ...
# Setting up libqt5qmlmodels5:amd64 (5.15.13+dfsg-1ubuntu0.1) ...
# Setting up libboost-json1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-wave1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libxslt1-dev:amd64 (1.1.39-0exp1ubuntu0.24.04.3) ...
# Setting up libboost-locale1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up qt6-base-dev-tools (6.4.2+dfsg-21.1build5) ...
# Setting up ibverbs-providers:amd64 (50.0-2ubuntu0.2) ...
# Setting up libdrm-radeon1:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# Setting up libdrm-intel1:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# Setting up libqt6qml6:amd64 (6.4.2+dfsg-4build3) ...
# Setting up libboost-type-erasure1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libboost-random-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-locale-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up python3 (3.12.3-0ubuntu2.1) ...
# running python rtupdate hooks for python3.12...
# running python post-rtupdate hooks for python3.12...
# Setting up libpython3.12-dev:amd64 (3.12.3-1ubuntu0.13) ...
# Setting up libboost-wave-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libqt6qmlmodels6:amd64 (6.4.2+dfsg-4build3) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libboost-container-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-type-erasure-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up qmake6:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libboost-context1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libnl-route-3-dev:amd64 (3.7.0-0.3build1.1) ...
# Setting up libboost-coroutine1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libboost-fiber1.83-dev:amd64 (1.83.0-2.1ubuntu3.2) ...
# Setting up libevent-dev (2.1.12-stable-9ubuntu2) ...
# Setting up python3.12-dev (3.12.3-1ubuntu0.13) ...
# Setting up cmake (3.28.3-1build7) ...
# Setting up librdmacm1t64:amd64 (50.0-2ubuntu0.2) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libboost-coroutine-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-log1.83-dev (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-json-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-log-dev (1.83.0.1ubuntu2) ...
# Setting up libpmix-dev:amd64 (5.0.1-4.1build1) ...
# Setting up libhsakmt1:amd64 (5.7.0-1build1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libboost-thread-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libboost-fiber-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libfabric1:amd64 (1.17.0-3build2) ...
# Setting up mesa-libgallium:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# Setting up python3-docopt (0.6.2-6) ...
# Setting up libvulkan-dev:amd64 (1.3.275.0-1build1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libpython3-dev:amd64 (3.12.3-0ubuntu2.1) ...
# Setting up libgbm1:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# Setting up libboost-context-dev:amd64 (1.83.0.1ubuntu2) ...
# Setting up libibverbs-dev:amd64 (50.0-2ubuntu0.2) ...
# Setting up libegl-mesa0:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up python3-dev (3.12.3-0ubuntu2.1) ...
# Setting up libboost-python1.83-dev (1.83.0-2.1ubuntu3.2) ...
# Setting up libhsa-runtime64-1 (5.7.1-2build1) ...
# Setting up libegl1:amd64 (1.7.0-1build1) ...
# Setting up libglx-mesa0:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libboost-python-dev (1.83.0.1ubuntu2) ...
# Setting up libqt5gui5t64:amd64 (5.15.13+dfsg-1ubuntu1) ...
# Setting up libamdhip64-5 (5.7.1-3) ...
# Setting up libqt6gui6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt5quick5:amd64 (5.15.13+dfsg-1ubuntu0.1) ...
# Setting up libqt6widgets6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libucx0:amd64 (1.16.0+ds-5ubuntu1) ...
# Setting up qt6-qpa-plugins:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt5widgets5t64:amd64 (5.15.13+dfsg-1ubuntu1) ...
# Setting up libqt5svg5:amd64 (5.15.13-1) ...
# Setting up libqt6opengl6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.13+dfsg-1ubuntu1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libqt5waylandclient5:amd64 (5.15.13-1) ...
# Setting up libqt5waylandcompositor5:amd64 (5.15.13-1) ...
# Setting up libqt6waylandclient6:amd64 (6.4.2-5build3) ...
# Setting up qt6-gtk-platformtheme:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt6printsupport6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt6quick6:amd64 (6.4.2+dfsg-4build3) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libopenmpi3t64:amd64 (4.1.6-7ubuntu2) ...
# Setting up libboost-mpi1.83.0 (1.83.0-2.1ubuntu3.2) ...
# Setting up cmake-qt-gui (3.28.3-1build7) ...
# Setting up libqt6wlshellintegration6:amd64 (6.4.2-5build3) ...
# Setting up openmpi-bin (4.1.6-7ubuntu2) ...
# update-alternatives: using /usr/bin/mpirun.openmpi to provide /usr/bin/mpirun (mpirun) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpirun.1.gz because associated file /usr/share/man/man1/mpirun.openmpi.1.gz (of link group mpirun) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiexec.1.gz because associated file /usr/share/man/man1/mpiexec.openmpi.1.gz (of link group mpirun) doesn't exist
# update-alternatives: using /usr/bin/mpicc.openmpi to provide /usr/bin/mpicc (mpi) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicc.1.gz because associated file /usr/share/man/man1/mpicc.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpic++.1.gz because associated file /usr/share/man/man1/mpic++.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicxx.1.gz because associated file /usr/share/man/man1/mpicxx.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiCC.1.gz because associated file /usr/share/man/man1/mpiCC.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif77.1.gz because associated file /usr/share/man/man1/mpif77.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif90.1.gz because associated file /usr/share/man/man1/mpif90.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpifort.1.gz because associated file /usr/share/man/man1/mpifort.openmpi.1.gz (of link group mpi) doesn't exist
# Setting up libboost-graph-parallel1.83.0 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libqt6waylandcompositor6:amd64 (6.4.2-5build3) ...
# Setting up qtwayland5:amd64 (5.15.13-1) ...
# Setting up mpi-default-bin (1.15build1) ...
# Setting up libqt6openglwidgets6t64:amd64 (6.4.2+dfsg-21.1build5) ...
# Setting up libqt6waylandeglcompositorhwintegration6:amd64 (6.4.2-5build3) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libqt6waylandeglclienthwintegration6:amd64 (6.4.2-5build3) ...
# Setting up libcaf-openmpi-3t64:amd64 (2.10.2+ds-2.1build2) ...
# Setting up libopenmpi-dev:amd64 (4.1.6-7ubuntu2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/openmpi/include to provide /usr/include/x86_64-linux-gnu/mpi (mpi-x86_64-linux-gnu) in auto mode
# Setting up libboost-graph-parallel1.83-dev (1.83.0-2.1ubuntu3.2) ...
# Setting up qt6-wayland:amd64 (6.4.2-5build3) ...
# Setting up libboost-mpi-python1.83.0 (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libcoarrays-openmpi-dev:amd64 (2.10.2+ds-2.1build2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/open-coarrays/openmpi/bin/caf to provide /usr/bin/caf.openmpi (caf-openmpi) in auto mode
# update-alternatives: using /usr/bin/caf.openmpi to provide /usr/bin/caf (caf) in auto mode
# Setting up libboost-graph-parallel-dev (1.83.0.1ubuntu2) ...
# Setting up mpi-default-dev (1.15build1) ...
# Setting up libboost-mpi1.83-dev (1.83.0-2.1ubuntu3.2) ...
# Setting up libboost-mpi-dev (1.83.0.1ubuntu2) ...
# Setting up libboost-mpi-python1.83-dev (1.83.0-2.1ubuntu3.2) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libboost-mpi-python-dev (1.83.0.1ubuntu2) ...
# Setting up libboost-all-dev (1.83.0.1ubuntu2) ...
# Processing triggers for sgml-base (1.31) ...
# Setting up x11proto-dev (2023.2-1) ...
# Setting up libxau-dev:amd64 (1:1.0.9-1build6) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.4) ...
# Processing triggers for systemd (255.4-1ubuntu8.5) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu6) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for shared-mime-info (2.4-4) ...
# Setting up libxcb1-dev:amd64 (1.15-1ubuntu2) ...
# Setting up libx11-dev:amd64 (2:1.8.7-1build1) ...
# Setting up libglx-dev:amd64 (1.7.0-1build1) ...
# Setting up libgl-dev:amd64 (1.7.0-1build1) ...
# Setting up qt6-base-dev:amd64 (6.4.2+dfsg-21.1build5) ...
#
# 78

# %% [markdown]
# ## Графические библиотеки
#
# Установка OpenGL-зависимостей для визуализации.

# %%
# !sudo apt install libglu1-mesa-dev freeglut3-dev mesa-common-dev -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libglapi-mesa libllvm19 libxcb-dri2-0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libdrm-dev libdrm-nouveau2 libegl-dev libgl1-mesa-dev libgles-dev libgles1
#   libgles2 libglut-dev libglut3.12 libglvnd-core-dev libglvnd-dev libice-dev
#   libpciaccess-dev libpciaccess0 libsm-dev libxext-dev libxt-dev
# Suggested packages:
#   libice-doc pciutils libsm-doc libxext-doc libxt-doc
# The following NEW packages will be installed:
#   freeglut3-dev libdrm-dev libdrm-nouveau2 libegl-dev libgl1-mesa-dev
#   libgles-dev libgles1 libgles2 libglu1-mesa-dev libglut-dev libglut3.12
#   libglvnd-core-dev libglvnd-dev libice-dev libpciaccess-dev libsm-dev
#   libxext-dev libxt-dev mesa-common-dev
# The following packages will be upgraded:
#   libpciaccess0
# 1 upgraded, 19 newly installed, 0 to remove and 167 not upgraded.
# Need to get 4 651 kB of archives.
# After this operation, 10,7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/universe amd64 libglut3.12 amd64 3.4.0-1build1 [98,0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 libglvnd-core-dev amd64 1.7.0-1build1 [13,6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/main amd64 libegl-dev amd64 1.7.0-1build1 [18,2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 libgles1 amd64 1.7.0-1build1 [11,6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble/main amd64 libgles2 amd64 1.7.0-1build1 [17,1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/main amd64 libgles-dev amd64 1.7.0-1build1 [50,5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/main amd64 libglvnd-dev amd64 1.7.0-1build1 [3 198 B]
# Get:8 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgl1-mesa-dev amd64 25.2.8-0ubuntu0.24.04.1 [22,5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/main amd64 libglu1-mesa-dev amd64 9.0.2-1.1build1 [237 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble/main amd64 libxext-dev amd64 2:1.3.4-1build2 [83,5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble/main amd64 libice-dev amd64 2:1.0.10-1build3 [51,0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble/main amd64 libsm-dev amd64 2:1.2.3-1build3 [17,8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/main amd64 libxt-dev amd64 1:1.2.1-1.2build1 [394 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/universe amd64 libglut-dev amd64 3.4.0-1build1 [125 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/universe amd64 freeglut3-dev amd64 3.4.0-1build1 [2 022 B]
# Get:16 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-nouveau2 amd64 2.4.125-1ubuntu0.1~24.04.1 [17,7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpciaccess0 amd64 0.17-3ubuntu0.24.04.2 [18,9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpciaccess-dev amd64 0.17-3ubuntu0.24.04.2 [22,0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-dev amd64 2.4.125-1ubuntu0.1~24.04.1 [314 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 mesa-common-dev amd64 25.2.8-0ubuntu0.24.04.1 [3 133 kB]
# Fetched 4 651 kB in 2s (2 272 kB/s)         0m
# debconf: delaying package configuration, since apt-utils is not installed
#
# Selecting previously unselected package libglut3.12:amd64.
# (Reading database ... 73365 files and directories currently installed.)
# Preparing to unpack .../00-libglut3.12_3.4.0-1build1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  1%] [..........................................................] 8Unpacking libglut3.12:amd64 (3.4.0-1build1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64..........................................] 8
# Preparing to unpack .../01-libglvnd-core-dev_1.7.0-1build1_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libglvnd-core-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../02-libegl-dev_1.7.0-1build1_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libegl-dev:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libgles1:amd64...................................................] 8
# Preparing to unpack .../03-libgles1_1.7.0-1build1_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libgles1:amd64 (1.7.0-1build1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../04-libgles2_1.7.0-1build1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libgles2:amd64 (1.7.0-1build1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../05-libgles-dev_1.7.0-1build1_amd64.deb ...
# 7Progress: [ 14%] [#######...................................................] 8Unpacking libgles-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../06-libglvnd-dev_1.7.0-1build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libglvnd-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../07-libgl1-mesa-dev_25.2.8-0ubuntu0.24.04.1_amd64.deb ...
# 7Progress: [ 19%] [##########................................................] 8Unpacking libgl1-mesa-dev:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../08-libglu1-mesa-dev_9.0.2-1.1build1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libglu1-mesa-dev:amd64 (9.0.2-1.1build1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../09-libxext-dev_2%3a1.3.4-1build2_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libxext-dev:amd64 (2:1.3.4-1build2) ...
# Selecting previously unselected package libice-dev:amd64.####............................................] 8
# Preparing to unpack .../10-libice-dev_2%3a1.0.10-1build3_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libice-dev:amd64 (2:1.0.10-1build3) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../11-libsm-dev_2%3a1.2.3-1build3_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libsm-dev:amd64 (2:1.2.3-1build3) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../12-libxt-dev_1%3a1.2.1-1.2build1_amd64.deb ...
# 7Progress: [ 31%] [#################.........................................] 8Unpacking libxt-dev:amd64 (1:1.2.1-1.2build1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libglut-dev:amd64.
# Preparing to unpack .../13-libglut-dev_3.4.0-1build1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libglut-dev:amd64 (3.4.0-1build1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../14-freeglut3-dev_3.4.0-1build1_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking freeglut3-dev:amd64 (3.4.0-1build1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../15-libdrm-nouveau2_2.4.125-1ubuntu0.1~24.04.1_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libdrm-nouveau2:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# 7Progress: [ 40%] [######################....................................] 8Preparing to unpack .../16-libpciaccess0_0.17-3ubuntu0.24.04.2_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libpciaccess0:amd64 (0.17-3ubuntu0.24.04.2) over (0.17-3build1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../17-libpciaccess-dev_0.17-3ubuntu0.24.04.2_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libpciaccess-dev:amd64 (0.17-3ubuntu0.24.04.2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../18-libdrm-dev_2.4.125-1ubuntu0.1~24.04.1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libdrm-dev:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../19-mesa-common-dev_25.2.8-0ubuntu0.24.04.1_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking mesa-common-dev:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# Setting up libpciaccess0:amd64 (0.17-3ubuntu0.24.04.2) ...#################..............................] 8
# 7Progress: [ 51%] [#############################.............................] 87Progress: [ 52%] [##############################............................] 8Setting up libdrm-nouveau2:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 54%] [###############################...........................] 8Setting up libpciaccess-dev:amd64 (0.17-3ubuntu0.24.04.2) ...
# 7Progress: [ 56%] [################################..........................] 87Progress: [ 57%] [################################..........................] 8Setting up libglvnd-core-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 59%] [##################################........................] 8Setting up libice-dev:amd64 (2:1.0.10-1build3) ...
# 7Progress: [ 60%] [###################################.......................] 87Progress: [ 62%] [###################################.......................] 8Setting up libegl-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 63%] [####################################......................] 87Progress: [ 64%] [#####################################.....................] 8Setting up libsm-dev:amd64 (2:1.2.3-1build3) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 67%] [######################################....................] 8Setting up libgles2:amd64 (1.7.0-1build1) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1.2build1) ...####################################...................] 87Progress: [ 69%] [########################################..................] 8
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 72%] [#########################################.................] 8Setting up libglut3.12:amd64 (3.4.0-1build1) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 74%] [##########################################................] 8Setting up libgles1:amd64 (1.7.0-1build1) ...
# 7Progress: [ 75%] [###########################################...............] 87Progress: [ 77%] [############################################..............] 8Setting up libglu1-mesa-dev:amd64 (9.0.2-1.1build1) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 79%] [#############################################.............] 8Setting up libxext-dev:amd64 (2:1.3.4-1build2) ...
# 7Progress: [ 80%] [##############################################............] 87Progress: [ 81%] [###############################################...........] 8Setting up libgles-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 83%] [###############################################...........] 87Progress: [ 84%] [################################################..........] 8Setting up libdrm-dev:amd64 (2.4.125-1ubuntu0.1~24.04.1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 86%] [##################################################........] 8Setting up libglvnd-dev:amd64 (1.7.0-1build1) ...
# 7Progress: [ 88%] [##################################################........] 87Progress: [ 89%] [###################################################.......] 8Setting up libgl1-mesa-dev:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# 7Progress: [ 90%] [####################################################......] 87Progress: [ 91%] [####################################################......] 8Setting up mesa-common-dev:amd64 (25.2.8-0ubuntu0.24.04.1) ...
# 7Progress: [ 93%] [#####################################################.....] 87Progress: [ 94%] [######################################################....] 8Setting up libglut-dev:amd64 (3.4.0-1build1) ...
# 7Progress: [ 95%] [#######################################################...] 87Progress: [ 96%] [#######################################################...] 8Setting up freeglut3-dev:amd64 (3.4.0-1build1) ...
# 7Progress: [ 98%] [########################################################..] 87Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.39-0ubuntu8.4) ...
#
# 78

# %% [markdown]
# ## Ставим GDAL

# %%
# !sudo apt install gdal-bin libgdal-dev -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libglapi-mesa libheif-plugin-libde265 libllvm19 libxcb-dri2-0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   bzip2-doc comerr-dev default-libmysqlclient-dev gdal-data gdal-plugins
#   libabsl20220623t64 libacl1 libacl1-dev libaom-dev libarchive-dev
#   libarmadillo-dev libarpack2-dev libattr1 libattr1-dev libavif-dev libavif16
#   libblas-dev libblosc-dev libbrotli-dev libbz2-dev libcfitsio-dev
#   libcfitsio-doc libdav1d-dev libdav1d7 libde265-dev libdeflate-dev
#   libexprtk-dev libext2fs-dev libfreexl-dev libfyba-dev libgav1-1 libgdal37
#   libgeos-dev libgeotiff-dev libgif-dev libgmp-dev libgmp10 libgmpxx4ldbl
#   libhdf4-0 libhdf4-dev libheif-dev libheif-plugin-aomdec
#   libheif-plugin-libde265 libheif1 libhwy-dev libhwy1t64 libjbig-dev
#   libjson-c-dev libjxl-dev libjxl0.7 libkml-dev libkmlconvenience1t64
#   libkmlregionator1t64 libkmlxsd1t64 liblapack-dev liblcms2-2 liblcms2-dev
#   liblerc-dev liblz4-dev liblzma-dev liblzma5 libminizip-dev libmuparser-dev
#   libmuparser2v5 libmysqlclient-dev libmysqlclient21 libodbccr2 libopenjp2-7
#   libopenjp2-7-dev libpcre2-dev libpcre2-posix3 libpkgconf3 libpng-dev
#   libpng-tools libpng16-16t64 libpoppler-dev libpoppler-private-dev
#   libpoppler134 libpq-dev libpq5 libproj-dev libqhull-dev libqhull8.0
#   libqhullcpp8.0 librav1e0 librttopo-dev libsharpyuv-dev libspatialite-dev
#   libsqlite3-0 libsqlite3-dev libsuperlu-dev libsvtav1enc1d1 libtiff-dev
#   libtiff6 libtiffxx6 liburiparser-dev libwebp-dev libwebpdecoder3
#   libwebpdemux2 libwebpmux3 libx265-199 libx265-dev libyuv0 libzstd-dev
#   nettle-dev pkgconf pkgconf-bin proj-bin python3-gdal unixodbc-dev xz-utils
# Suggested packages:
#   doc-base libitpp-dev liblapack-doc libgdal-doc libgeotiff-epsg gmp-doc
#   libgmp10-doc libmpfr-dev libhdf4-doc hdf4-tools libheif-plugin-x265
#   libheif-plugin-ffmpegdec libheif-plugin-jpegdec libheif-plugin-jpegenc
#   libheif-plugin-j2kdec libheif-plugin-j2kenc libheif-plugin-rav1e
#   libheif-plugin-svtenc liblcms2-utils liblzma-doc libfreetype-dev
#   postgresql-doc-16 sqlite3-doc libsuperlu-doc libx265-doc
# Recommended packages:
#   libheif-plugin-aomenc poppler-data
# The following NEW packages will be installed:
#   bzip2-doc comerr-dev default-libmysqlclient-dev gdal-bin libabsl20220623t64
#   libacl1-dev libaom-dev libarchive-dev libarmadillo-dev libarpack2-dev
#   libattr1-dev libavif-dev libavif16 libblas-dev libblosc-dev libbrotli-dev
#   libbz2-dev libcfitsio-dev libcfitsio-doc libdav1d-dev libdav1d7 libde265-dev
#   libdeflate-dev libexprtk-dev libext2fs-dev libfreexl-dev libfyba-dev
#   libgav1-1 libgdal-dev libgdal37 libgeos-dev libgeotiff-dev libgif-dev
#   libgmp-dev libgmpxx4ldbl libhdf4-0 libhdf4-dev libheif-dev libhwy-dev
#   libhwy1t64 libjbig-dev libjson-c-dev libjxl-dev libjxl0.7 libkml-dev
#   libkmlconvenience1t64 libkmlregionator1t64 libkmlxsd1t64 liblapack-dev
#   liblcms2-dev liblerc-dev liblz4-dev liblzma-dev libminizip-dev
#   libmuparser-dev libmuparser2v5 libmysqlclient-dev libodbccr2
#   libopenjp2-7-dev libpcre2-dev libpcre2-posix3 libpkgconf3 libpng-dev
#   libpng-tools libpoppler-dev libpoppler-private-dev libpq-dev libproj-dev
#   libqhull-dev libqhull8.0 libqhullcpp8.0 librav1e0 librttopo-dev
#   libsharpyuv-dev libspatialite-dev libsqlite3-dev libsuperlu-dev
#   libsvtav1enc1d1 libtiff-dev libtiffxx6 liburiparser-dev libwebp-dev
#   libwebpdecoder3 libwebpdemux2 libwebpmux3 libx265-199 libx265-dev libyuv0
#   libzstd-dev nettle-dev pkgconf pkgconf-bin proj-bin python3-gdal
#   unixodbc-dev
# The following packages will be upgraded:
#   gdal-data gdal-plugins libacl1 libattr1 libgmp10 libheif-plugin-aomdec
#   libheif-plugin-libde265 libheif1 liblcms2-2 liblzma5 libmysqlclient21
#   libopenjp2-7 libpng16-16t64 libpoppler134 libpq5 libsqlite3-0 libtiff6
#   xz-utils
# 18 upgraded, 95 newly installed, 0 to remove and 149 not upgraded.
# Need to get 56,2 MB of archives.
# After this operation, 236 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-data all 3.11.4+dfsg-1~noble0 [444 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libacl1 amd64 2.3.2-1build1.1 [16,8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libattr1 amd64 1:2.5.2-1build1.1 [11,4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgmp10 amd64 2:6.3.0+dfsg-2ubuntu6.1 [253 kB]
# Get:5 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-plugins amd64 3.11.4+dfsg-1~noble0 [196 kB]
# Get:6 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libgdal37 amd64 3.11.4+dfsg-1~noble0 [10,3 MB]
# Get:7 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblzma5 amd64 5.6.1+really5.4.5-1ubuntu0.3 [127 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsqlite3-0 amd64 3.45.1-1ubuntu2.5 [701 kB]
# Get:9 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 python3-gdal amd64 3.11.4+dfsg-1~noble0 [1 063 kB]
# Get:10 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-bin amd64 3.11.4+dfsg-1~noble0 [826 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libexprtk-dev all 0.0.3-3~noble0 [124 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libgeos-dev amd64 3.12.2-1~noble0 [57,2 kB]
# Get:13 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libproj-dev amd64 9.4.1-1~noble0 [114 kB]
# Get:14 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libgeotiff-dev amd64 1.7.3-1~noble0 [107 kB]
# Get:15 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libgdal-dev amd64 3.11.4+dfsg-1~noble0 [430 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 proj-bin amd64 9.4.1-1~noble0 [202 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpng16-16t64 amd64 1.6.43-5ubuntu0.6 [189 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 xz-utils amd64 5.6.1+really5.4.5-1ubuntu0.3 [267 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 bzip2-doc all 1.0.8-5.1build0.1 [499 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libmysqlclient21 amd64 8.0.46-0ubuntu0.24.04.2 [1 255 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libzstd-dev amd64 1.5.5+dfsg2-2build1.1 [364 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libmysqlclient-dev amd64 8.0.46-0ubuntu0.24.04.2 [1 591 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble/main amd64 default-libmysqlclient-dev amd64 1.1.0build1 [3 132 B]
# Get:24 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdav1d7 amd64 1.4.1-1build1 [604 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libabsl20220623t64 amd64 20220623.1-3.1ubuntu3.2 [423 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble/universe amd64 libgav1-1 amd64 0.18.0-1build3 [357 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble/universe amd64 librav1e0 amd64 0.7.1-2 [1 022 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsvtav1enc1d1 amd64 1.7.0+dfsg-2build1 [2 425 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble/universe amd64 libyuv0 amd64 0.0~git202401110.af6ac82-1 [178 kB]
# Get:30 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavif16 amd64 1.0.4-1ubuntu3 [91,2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhdf4-0 amd64 4.2.16-4build1 [324 kB]
# Get:32 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libheif-plugin-libde265 amd64 1.17.6-1ubuntu4.3 [8 156 B]
# Get:33 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libheif1 amd64 1.17.6-1ubuntu4.3 [276 kB]
# Get:34 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libheif-plugin-aomdec amd64 1.17.6-1ubuntu4.3 [10,6 kB]
# Get:35 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwy1t64 amd64 1.0.7-8.1build1 [584 kB]
# Get:36 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblcms2-2 amd64 2.14-2ubuntu0.1 [161 kB]
# Get:37 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libjxl0.7 amd64 0.7.0-10.2ubuntu6.1 [1 001 kB]
# Get:38 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmuparser2v5 amd64 2.3.3-0.1build1 [137 kB]
# Get:39 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libopenjp2-7 amd64 2.5.0-2ubuntu0.5 [174 kB]
# Get:40 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libtiff6 amd64 4.5.1+git230720-4ubuntu2.5 [200 kB]
# Get:41 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpoppler134 amd64 24.02.0-1ubuntu9.8 [1 118 kB]
# Get:42 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpq5 amd64 16.14-0ubuntu0.24.04.1 [147 kB]
# Get:43 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libaom-dev amd64 3.8.2-2ubuntu0.1 [2 266 kB]
# Get:44 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libbz2-dev amd64 1.0.8-5.1build0.1 [33,6 kB]
# Get:45 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblz4-dev amd64 1.9.4-1build1.1 [87,6 kB]
# Get:46 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblzma-dev amd64 5.6.1+really5.4.5-1ubuntu0.3 [176 kB]
# Get:47 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libattr1-dev amd64 1:2.5.2-1build1.1 [23,1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libacl1-dev amd64 2.3.2-1build1.1 [78,5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 comerr-dev amd64 2.1-1.47.0-2.4~exp1ubuntu4.1 [43,8 kB]
# Get:50 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libext2fs-dev amd64 1.47.0-2.4~exp1ubuntu4.1 [300 kB]
# Get:51 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgmpxx4ldbl amd64 2:6.3.0+dfsg-2ubuntu6.1 [9 888 B]
# Get:52 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgmp-dev amd64 2:6.3.0+dfsg-2ubuntu6.1 [340 kB]
# Get:53 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 nettle-dev amd64 3.9.1-2.2build1.1 [1 154 kB]
# Get:54 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libarchive-dev amd64 3.7.2-2ubuntu0.7 [590 kB]
# Get:55 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libblas-dev amd64 3.12.0-3build1.1 [170 kB]
# Get:56 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblapack-dev amd64 3.12.0-3build1.1 [5 196 kB]
# Get:57 http://archive.ubuntu.com/ubuntu noble/universe amd64 libarpack2-dev amd64 3.9.1-1.1build2 [122 kB]
# Get:58 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsuperlu-dev amd64 6.0.1+dfsg1-1build1 [20,7 kB]
# Get:59 http://archive.ubuntu.com/ubuntu noble/universe amd64 libarmadillo-dev amd64 1:12.6.7+dfsg-1build2 [409 kB]
# Get:60 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavif-dev amd64 1.0.4-1ubuntu3 [26,0 kB]
# Get:61 http://archive.ubuntu.com/ubuntu noble/universe amd64 libblosc-dev amd64 1.21.5+ds-1build1 [43,7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu noble/main amd64 libbrotli-dev amd64 1.1.0-2build2 [353 kB]
# Get:63 http://archive.ubuntu.com/ubuntu noble/universe amd64 libcfitsio-dev amd64 4.3.1-1.1build2 [598 kB]
# Get:64 http://archive.ubuntu.com/ubuntu noble/universe amd64 libcfitsio-doc all 4.3.1-1.1build2 [2 076 kB]
# Get:65 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdav1d-dev amd64 1.4.1-1build1 [25,3 kB]
# Get:66 http://archive.ubuntu.com/ubuntu noble/main amd64 libde265-dev amd64 1.0.15-1build3 [12,6 kB]
# Get:67 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdeflate-dev amd64 1.19-1build1.1 [50,9 kB]
# Get:68 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfyba-dev amd64 4.1.1-11build1 [178 kB]
# Get:69 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libminizip-dev amd64 1:1.3.dfsg-3.1ubuntu2.1 [30,2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfreexl-dev amd64 2.0.0-1build2 [43,8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsqlite3-dev amd64 3.45.1-1ubuntu2.5 [911 kB]
# Get:72 http://archive.ubuntu.com/ubuntu noble/main amd64 libjbig-dev amd64 2.1-6.1ubuntu2 [27,9 kB]
# Get:73 http://archive.ubuntu.com/ubuntu noble/main amd64 libwebpdemux2 amd64 1.3.2-0.4build3 [12,4 kB]
# Get:74 http://archive.ubuntu.com/ubuntu noble/main amd64 libwebpmux3 amd64 1.3.2-0.4build3 [25,7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu noble/main amd64 libwebpdecoder3 amd64 1.3.2-0.4build3 [114 kB]
# Get:76 http://archive.ubuntu.com/ubuntu noble/main amd64 libsharpyuv-dev amd64 1.3.2-0.4build3 [16,0 kB]
# Get:77 http://archive.ubuntu.com/ubuntu noble/main amd64 libwebp-dev amd64 1.3.2-0.4build3 [367 kB]
# Get:78 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libtiffxx6 amd64 4.5.1+git230720-4ubuntu2.5 [5 642 B]
# Get:79 http://archive.ubuntu.com/ubuntu noble/main amd64 liblerc-dev amd64 4.0.0+ds-4ubuntu2 [182 kB]
# Get:80 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libtiff-dev amd64 4.5.1+git230720-4ubuntu2.5 [338 kB]
# Get:81 http://archive.ubuntu.com/ubuntu noble/main amd64 libgif-dev amd64 5.2.2-1ubuntu1 [22,7 kB]
# Get:82 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhdf4-dev amd64 4.2.16-4build1 [438 kB]
# Get:83 http://archive.ubuntu.com/ubuntu noble/universe amd64 libx265-199 amd64 3.5-2build1 [1 226 kB]
# Get:84 http://archive.ubuntu.com/ubuntu noble/universe amd64 libx265-dev amd64 3.5-2build1 [1 351 kB]
# Get:85 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libheif-dev amd64 1.17.6-1ubuntu4.3 [41,6 kB]
# Get:86 http://archive.ubuntu.com/ubuntu noble/main amd64 libjson-c-dev amd64 0.17-1build1 [63,6 kB]
# Get:87 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwy-dev amd64 1.0.7-8.1build1 [316 kB]
# Get:88 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liblcms2-dev amd64 2.14-2ubuntu0.1 [1 809 kB]
# Get:89 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libjxl-dev amd64 0.7.0-10.2ubuntu6.1 [42,2 kB]
# Get:90 http://archive.ubuntu.com/ubuntu noble/universe amd64 libkmlconvenience1t64 amd64 1.3.0-12build1 [49,8 kB]
# Get:91 http://archive.ubuntu.com/ubuntu noble/universe amd64 libkmlregionator1t64 amd64 1.3.0-12build1 [21,4 kB]
# Get:92 http://archive.ubuntu.com/ubuntu noble/universe amd64 libkmlxsd1t64 amd64 1.3.0-12build1 [29,7 kB]
# Get:93 http://archive.ubuntu.com/ubuntu noble/universe amd64 liburiparser-dev amd64 0.9.7+dfsg-2build1 [15,0 kB]
# Get:94 http://archive.ubuntu.com/ubuntu noble/universe amd64 libkml-dev amd64 1.3.0-12build1 [659 kB]
# Get:95 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmuparser-dev amd64 2.3.3-0.1build1 [23,2 kB]
# Get:96 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libopenjp2-7-dev amd64 2.5.0-2ubuntu0.5 [258 kB]
# Get:97 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpcre2-posix3 amd64 10.42-4ubuntu2.1 [6 748 B]
# Get:98 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpcre2-dev amd64 10.42-4ubuntu2.1 [736 kB]
# Get:99 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpng-dev amd64 1.6.43-5ubuntu0.6 [265 kB]
# Get:100 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpoppler-dev amd64 24.02.0-1ubuntu9.8 [5 200 B]
# Get:101 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpoppler-private-dev amd64 24.02.0-1ubuntu9.8 [197 kB]
# Get:102 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpq-dev amd64 16.14-0ubuntu0.24.04.1 [152 kB]
# Get:103 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqhull8.0 amd64 2020.2-6build1 [192 kB]
# Get:104 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqhullcpp8.0 amd64 2020.2-6build1 [51,7 kB]
# Get:105 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqhull-dev amd64 2020.2-6build1 [496 kB]
# Get:106 http://archive.ubuntu.com/ubuntu noble/universe amd64 librttopo-dev amd64 1.1.0-3build2 [238 kB]
# Get:107 http://archive.ubuntu.com/ubuntu noble/universe amd64 libspatialite-dev amd64 5.1.0-3build1 [2 331 kB]
# Get:108 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libodbccr2 amd64 2.3.12-1ubuntu0.24.04.1 [16,1 kB]
# Get:109 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 unixodbc-dev amd64 2.3.12-1ubuntu0.24.04.1 [250 kB]
# Get:110 http://archive.ubuntu.com/ubuntu noble/main amd64 libpkgconf3 amd64 1.8.1-2build1 [30,7 kB]
# Get:111 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpng-tools amd64 1.6.43-5ubuntu0.6 [28,5 kB]
# Get:112 http://archive.ubuntu.com/ubuntu noble/main amd64 pkgconf-bin amd64 1.8.1-2build1 [20,7 kB]
# Get:113 http://archive.ubuntu.com/ubuntu noble/main amd64 pkgconf amd64 1.8.1-2build1 [16,8 kB]
# Fetched 56,2 MB in 6s (9 433 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# (Reading database ... 74470 files and directories currently installed.)
# Preparing to unpack .../libacl1_2.3.2-1build1.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libacl1:amd64 (2.3.2-1build1.1) over (2.3.2-1build1) ...
# Setting up libacl1:amd64 (2.3.2-1build1.1) ...
# (Reading database ... 74470 files and directories currently installed.)
# Preparing to unpack .../libattr1_1%3a2.5.2-1build1.1_amd64.deb ...
# 7Progress: [  1%] [..........................................................] 8Unpacking libattr1:amd64 (1:2.5.2-1build1.1) over (1:2.5.2-1build1) ...
# Setting up libattr1:amd64 (1:2.5.2-1build1.1) ...
# (Reading database ... 74470 files and directories currently installed.)
# Preparing to unpack .../libgmp10_2%3a6.3.0+dfsg-2ubuntu6.1_amd64.deb ...
# Unpacking libgmp10:amd64 (2:6.3.0+dfsg-2ubuntu6.1) over (2:6.3.0+dfsg-2ubuntu6) ...
# Setting up libgmp10:amd64 (2:6.3.0+dfsg-2ubuntu6.1) .....................................................] 8
# (Reading database ... 74470 files and directories currently installed.)
# Preparing to unpack .../liblzma5_5.6.1+really5.4.5-1ubuntu0.3_amd64.deb ...
# Unpacking liblzma5:amd64 (5.6.1+really5.4.5-1ubuntu0.3) over (5.6.1+really5.4.5-1build0.1) ...
# 7Progress: [  3%] [#.........................................................] 8Setting up liblzma5:amd64 (5.6.1+really5.4.5-1ubuntu0.3) ...
# (Reading database ... 74470 files and directories currently installed.)
# Preparing to unpack .../000-libsqlite3-0_3.45.1-1ubuntu2.5_amd64.deb ...
# Unpacking libsqlite3-0:amd64 (3.45.1-1ubuntu2.5) over (3.45.1-1ubuntu2) ...
# Preparing to unpack .../001-libpng16-16t64_1.6.43-5ubuntu0.6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libpng16-16t64:amd64 (1.6.43-5ubuntu0.6) over (1.6.43-5build1) ...
# Preparing to unpack .../002-xz-utils_5.6.1+really5.4.5-1ubuntu0.3_amd64.deb ...
# Unpacking xz-utils (5.6.1+really5.4.5-1ubuntu0.3) over (5.6.1+really5.4.5-1build0.1) ...
# Selecting previously unselected package bzip2-doc.
# Preparing to unpack .../003-bzip2-doc_1.0.8-5.1build0.1_all.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking bzip2-doc (1.0.8-5.1build0.1) ...
# Preparing to unpack .../004-libmysqlclient21_8.0.46-0ubuntu0.24.04.2_amd64.deb ...
# Unpacking libmysqlclient21:amd64 (8.0.46-0ubuntu0.24.04.2) over (8.0.41-0ubuntu0.24.04.1) ...
# Selecting previously unselected package libzstd-dev:amd64.
# Preparing to unpack .../005-libzstd-dev_1.5.5+dfsg2-2build1.1_amd64.deb ...
# Unpacking libzstd-dev:amd64 (1.5.5+dfsg2-2build1.1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libmysqlclient-dev.
# Preparing to unpack .../006-libmysqlclient-dev_8.0.46-0ubuntu0.24.04.2_amd64.deb ...
# Unpacking libmysqlclient-dev (8.0.46-0ubuntu0.24.04.2) ...
# Selecting previously unselected package default-libmysqlclient-dev:amd64.
# Preparing to unpack .../007-default-libmysqlclient-dev_1.1.0build1_amd64.deb ...
# Unpacking default-libmysqlclient-dev:amd64 (1.1.0build1) ...
# Preparing to unpack .../008-gdal-data_3.11.4+dfsg-1~noble0_all.deb ......................................] 8
# Unpacking gdal-data (3.11.4+dfsg-1~noble0) over (3.9.3+dfsg-1~noble0) ...
# Preparing to unpack .../009-gdal-plugins_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking gdal-plugins:amd64 (3.11.4+dfsg-1~noble0) over (3.9.3+dfsg-1~noble0) ...
# Selecting previously unselected package libdav1d7:amd64.
# Preparing to unpack .../010-libdav1d7_1.4.1-1build1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libdav1d7:amd64 (1.4.1-1build1) ...
# Selecting previously unselected package libabsl20220623t64:amd64.
# Preparing to unpack .../011-libabsl20220623t64_20220623.1-3.1ubuntu3.2_amd64.deb ...
# Unpacking libabsl20220623t64:amd64 (20220623.1-3.1ubuntu3.2) ...
# Selecting previously unselected package libgav1-1:amd64.
# Preparing to unpack .../012-libgav1-1_0.18.0-1build3_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libgav1-1:amd64 (0.18.0-1build3) ...
# Selecting previously unselected package librav1e0:amd64.
# Preparing to unpack .../013-librav1e0_0.7.1-2_amd64.deb ...
# Unpacking librav1e0:amd64 (0.7.1-2) ...
# Selecting previously unselected package libsvtav1enc1d1:amd64.
# Preparing to unpack .../014-libsvtav1enc1d1_1.7.0+dfsg-2build1_amd64.deb ...
# Unpacking libsvtav1enc1d1:amd64 (1.7.0+dfsg-2build1) ...
# Selecting previously unselected package libyuv0:amd64....................................................] 8
# Preparing to unpack .../015-libyuv0_0.0~git202401110.af6ac82-1_amd64.deb ...
# Unpacking libyuv0:amd64 (0.0~git202401110.af6ac82-1) ...
# Selecting previously unselected package libavif16:amd64.
# Preparing to unpack .../016-libavif16_1.0.4-1ubuntu3_amd64.deb ...
# Unpacking libavif16:amd64 (1.0.4-1ubuntu3) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libhdf4-0:amd64.
# Preparing to unpack .../017-libhdf4-0_4.2.16-4build1_amd64.deb ...
# Unpacking libhdf4-0:amd64 (4.2.16-4build1) ...
# Preparing to unpack .../018-libheif-plugin-libde265_1.17.6-1ubuntu4.3_amd64.deb ...
# Unpacking libheif-plugin-libde265:amd64 (1.17.6-1ubuntu4.3) over (1.17.6-1ubuntu4.1) ...
# Preparing to unpack .../019-libheif1_1.17.6-1ubuntu4.3_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libheif1:amd64 (1.17.6-1ubuntu4.3) over (1.17.6-1ubuntu4.1) ...
# Preparing to unpack .../020-libheif-plugin-aomdec_1.17.6-1ubuntu4.3_amd64.deb ...
# Unpacking libheif-plugin-aomdec:amd64 (1.17.6-1ubuntu4.3) over (1.17.6-1ubuntu4.1) ...
# Selecting previously unselected package libhwy1t64:amd64.
# Preparing to unpack .../021-libhwy1t64_1.0.7-8.1build1_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libhwy1t64:amd64 (1.0.7-8.1build1) ...
# Preparing to unpack .../022-liblcms2-2_2.14-2ubuntu0.1_amd64.deb ...
# Unpacking liblcms2-2:amd64 (2.14-2ubuntu0.1) over (2.14-2build1) ...
# Selecting previously unselected package libjxl0.7:amd64.
# Preparing to unpack .../023-libjxl0.7_0.7.0-10.2ubuntu6.1_amd64.deb ...
# Unpacking libjxl0.7:amd64 (0.7.0-10.2ubuntu6.1) ...
# Selecting previously unselected package libmuparser2v5:amd64.............................................] 8
# Preparing to unpack .../024-libmuparser2v5_2.3.3-0.1build1_amd64.deb ...
# Unpacking libmuparser2v5:amd64 (2.3.3-0.1build1) ...
# Preparing to unpack .../025-libopenjp2-7_2.5.0-2ubuntu0.5_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.5.0-2ubuntu0.5) over (2.5.0-2ubuntu0.3) ...
# Preparing to unpack .../026-libtiff6_4.5.1+git230720-4ubuntu2.5_amd64.deb ...............................] 8
# Unpacking libtiff6:amd64 (4.5.1+git230720-4ubuntu2.5) over (4.5.1+git230720-4ubuntu2.2) ...
# Preparing to unpack .../027-libpoppler134_24.02.0-1ubuntu9.8_amd64.deb ...
# Unpacking libpoppler134:amd64 (24.02.0-1ubuntu9.8) over (24.02.0-1ubuntu9.2) ...
# Preparing to unpack .../028-libpq5_16.14-0ubuntu0.24.04.1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpq5:amd64 (16.14-0ubuntu0.24.04.1) over (16.6-0ubuntu0.24.04.1) ...
# Selecting previously unselected package libgdal37:amd64.
# Preparing to unpack .../029-libgdal37_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking libgdal37:amd64 (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package python3-gdal.
# Preparing to unpack .../030-python3-gdal_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking python3-gdal (3.11.4+dfsg-1~noble0) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package gdal-bin.
# Preparing to unpack .../031-gdal-bin_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking gdal-bin (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package libaom-dev:amd64.
# Preparing to unpack .../032-libaom-dev_3.8.2-2ubuntu0.1_amd64.deb ...
# Unpacking libaom-dev:amd64 (3.8.2-2ubuntu0.1) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libbz2-dev:amd64.
# Preparing to unpack .../033-libbz2-dev_1.0.8-5.1build0.1_amd64.deb ...
# Unpacking libbz2-dev:amd64 (1.0.8-5.1build0.1) ...
# Selecting previously unselected package liblz4-dev:amd64.
# Preparing to unpack .../034-liblz4-dev_1.9.4-1build1.1_amd64.deb ...
# Unpacking liblz4-dev:amd64 (1.9.4-1build1.1) ...
# Selecting previously unselected package liblzma-dev:amd64.
# Preparing to unpack .../035-liblzma-dev_5.6.1+really5.4.5-1ubuntu0.3_amd64.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking liblzma-dev:amd64 (5.6.1+really5.4.5-1ubuntu0.3) ...
# Selecting previously unselected package libattr1-dev:amd64.
# Preparing to unpack .../036-libattr1-dev_1%3a2.5.2-1build1.1_amd64.deb ...
# Unpacking libattr1-dev:amd64 (1:2.5.2-1build1.1) ...
# Selecting previously unselected package libacl1-dev:amd64.
# Preparing to unpack .../037-libacl1-dev_2.3.2-1build1.1_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libacl1-dev:amd64 (2.3.2-1build1.1) ...
# Selecting previously unselected package comerr-dev:amd64.
# Preparing to unpack .../038-comerr-dev_2.1-1.47.0-2.4~exp1ubuntu4.1_amd64.deb ...
# Unpacking comerr-dev:amd64 (2.1-1.47.0-2.4~exp1ubuntu4.1) ...
# Selecting previously unselected package libext2fs-dev.
# Preparing to unpack .../039-libext2fs-dev_1.47.0-2.4~exp1ubuntu4.1_amd64.deb ...
# Unpacking libext2fs-dev (1.47.0-2.4~exp1ubuntu4.1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../040-libgmpxx4ldbl_2%3a6.3.0+dfsg-2ubuntu6.1_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.3.0+dfsg-2ubuntu6.1) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../041-libgmp-dev_2%3a6.3.0+dfsg-2ubuntu6.1_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.3.0+dfsg-2ubuntu6.1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package nettle-dev:amd64.
# Preparing to unpack .../042-nettle-dev_3.9.1-2.2build1.1_amd64.deb ...
# Unpacking nettle-dev:amd64 (3.9.1-2.2build1.1) ...
# Selecting previously unselected package libarchive-dev:amd64.
# Preparing to unpack .../043-libarchive-dev_3.7.2-2ubuntu0.7_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.7.2-2ubuntu0.7) ...
# Selecting previously unselected package libblas-dev:amd64.
# Preparing to unpack .../044-libblas-dev_3.12.0-3build1.1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libblas-dev:amd64 (3.12.0-3build1.1) ...
# Selecting previously unselected package liblapack-dev:amd64.
# Preparing to unpack .../045-liblapack-dev_3.12.0-3build1.1_amd64.deb ...
# Unpacking liblapack-dev:amd64 (3.12.0-3build1.1) ...
# Selecting previously unselected package libarpack2-dev:amd64.
# Preparing to unpack .../046-libarpack2-dev_3.9.1-1.1build2_amd64.deb ...
# 7Progress: [ 24%] [#############.............................................] 8Unpacking libarpack2-dev:amd64 (3.9.1-1.1build2) ...
# Selecting previously unselected package libsuperlu-dev:amd64.
# Preparing to unpack .../047-libsuperlu-dev_6.0.1+dfsg1-1build1_amd64.deb ...
# Unpacking libsuperlu-dev:amd64 (6.0.1+dfsg1-1build1) ...
# Selecting previously unselected package libarmadillo-dev.
# Preparing to unpack .../048-libarmadillo-dev_1%3a12.6.7+dfsg-1build2_amd64.deb ...
# Unpacking libarmadillo-dev (1:12.6.7+dfsg-1build2) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libavif-dev:amd64.
# Preparing to unpack .../049-libavif-dev_1.0.4-1ubuntu3_amd64.deb ...
# Unpacking libavif-dev:amd64 (1.0.4-1ubuntu3) ...
# Selecting previously unselected package libblosc-dev:amd64.
# Preparing to unpack .../050-libblosc-dev_1.21.5+ds-1build1_amd64.deb ...
# Unpacking libblosc-dev:amd64 (1.21.5+ds-1build1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libbrotli-dev:amd64.
# Preparing to unpack .../051-libbrotli-dev_1.1.0-2build2_amd64.deb ...
# Unpacking libbrotli-dev:amd64 (1.1.0-2build2) ...
# Selecting previously unselected package libcfitsio-dev:amd64.
# Preparing to unpack .../052-libcfitsio-dev_4.3.1-1.1build2_amd64.deb ...
# Unpacking libcfitsio-dev:amd64 (4.3.1-1.1build2) ...
# Selecting previously unselected package libcfitsio-doc.
# Preparing to unpack .../053-libcfitsio-doc_4.3.1-1.1build2_all.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libcfitsio-doc (4.3.1-1.1build2) ...
# Selecting previously unselected package libdav1d-dev:amd64.
# Preparing to unpack .../054-libdav1d-dev_1.4.1-1build1_amd64.deb ...
# Unpacking libdav1d-dev:amd64 (1.4.1-1build1) ...
# Selecting previously unselected package libde265-dev:amd64.
# Preparing to unpack .../055-libde265-dev_1.0.15-1build3_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libde265-dev:amd64 (1.0.15-1build3) ...
# Selecting previously unselected package libdeflate-dev:amd64.
# Preparing to unpack .../056-libdeflate-dev_1.19-1build1.1_amd64.deb ...
# Unpacking libdeflate-dev:amd64 (1.19-1build1.1) ...
# Selecting previously unselected package libexprtk-dev.
# Preparing to unpack .../057-libexprtk-dev_0.0.3-3~noble0_all.deb ...
# Unpacking libexprtk-dev (0.0.3-3~noble0) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libfyba-dev:amd64.
# Preparing to unpack .../058-libfyba-dev_4.1.1-11build1_amd64.deb ...
# Unpacking libfyba-dev:amd64 (4.1.1-11build1) ...
# Selecting previously unselected package libminizip-dev:amd64.
# Preparing to unpack .../059-libminizip-dev_1%3a1.3.dfsg-3.1ubuntu2.1_amd64.deb ...
# Unpacking libminizip-dev:amd64 (1:1.3.dfsg-3.1ubuntu2.1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libfreexl-dev:amd64.
# Preparing to unpack .../060-libfreexl-dev_2.0.0-1build2_amd64.deb ...
# Unpacking libfreexl-dev:amd64 (2.0.0-1build2) ...
# Selecting previously unselected package libgeos-dev.
# Preparing to unpack .../061-libgeos-dev_3.12.2-1~noble0_amd64.deb ...
# Unpacking libgeos-dev (3.12.2-1~noble0) ...
# Selecting previously unselected package libsqlite3-dev:amd64.
# Preparing to unpack .../062-libsqlite3-dev_3.45.1-1ubuntu2.5_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libsqlite3-dev:amd64 (3.45.1-1ubuntu2.5) ...
# Selecting previously unselected package libjbig-dev:amd64.
# Preparing to unpack .../063-libjbig-dev_2.1-6.1ubuntu2_amd64.deb ...
# Unpacking libjbig-dev:amd64 (2.1-6.1ubuntu2) ...
# Selecting previously unselected package libwebpdemux2:amd64.
# Preparing to unpack .../064-libwebpdemux2_1.3.2-0.4build3_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libwebpdemux2:amd64 (1.3.2-0.4build3) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../065-libwebpmux3_1.3.2-0.4build3_amd64.deb ...
# Unpacking libwebpmux3:amd64 (1.3.2-0.4build3) ...
# Selecting previously unselected package libwebpdecoder3:amd64.
# Preparing to unpack .../066-libwebpdecoder3_1.3.2-0.4build3_amd64.deb ...
# Unpacking libwebpdecoder3:amd64 (1.3.2-0.4build3) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libsharpyuv-dev:amd64.
# Preparing to unpack .../067-libsharpyuv-dev_1.3.2-0.4build3_amd64.deb ...
# Unpacking libsharpyuv-dev:amd64 (1.3.2-0.4build3) ...
# Selecting previously unselected package libwebp-dev:amd64.
# Preparing to unpack .../068-libwebp-dev_1.3.2-0.4build3_amd64.deb ...
# Unpacking libwebp-dev:amd64 (1.3.2-0.4build3) ...
# Selecting previously unselected package libtiffxx6:amd64.
# Preparing to unpack .../069-libtiffxx6_4.5.1+git230720-4ubuntu2.5_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libtiffxx6:amd64 (4.5.1+git230720-4ubuntu2.5) ...
# Selecting previously unselected package liblerc-dev:amd64.
# Preparing to unpack .../070-liblerc-dev_4.0.0+ds-4ubuntu2_amd64.deb ...
# Unpacking liblerc-dev:amd64 (4.0.0+ds-4ubuntu2) ...
# Selecting previously unselected package libtiff-dev:amd64.
# Preparing to unpack .../071-libtiff-dev_4.5.1+git230720-4ubuntu2.5_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libtiff-dev:amd64 (4.5.1+git230720-4ubuntu2.5) ...
# Selecting previously unselected package libproj-dev:amd64.
# Preparing to unpack .../072-libproj-dev_9.4.1-1~noble0_amd64.deb ...
# Unpacking libproj-dev:amd64 (9.4.1-1~noble0) ...
# Selecting previously unselected package libgeotiff-dev:amd64.
# Preparing to unpack .../073-libgeotiff-dev_1.7.3-1~noble0_amd64.deb ...
# Unpacking libgeotiff-dev:amd64 (1.7.3-1~noble0) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package libgif-dev:amd64.
# Preparing to unpack .../074-libgif-dev_5.2.2-1ubuntu1_amd64.deb ...
# Unpacking libgif-dev:amd64 (5.2.2-1ubuntu1) ...
# Selecting previously unselected package libhdf4-dev.
# Preparing to unpack .../075-libhdf4-dev_4.2.16-4build1_amd64.deb ...
# Unpacking libhdf4-dev (4.2.16-4build1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libx265-199:amd64.
# Preparing to unpack .../076-libx265-199_3.5-2build1_amd64.deb ...
# Unpacking libx265-199:amd64 (3.5-2build1) ...
# Selecting previously unselected package libx265-dev:amd64.
# Preparing to unpack .../077-libx265-dev_3.5-2build1_amd64.deb ...
# Unpacking libx265-dev:amd64 (3.5-2build1) ...
# Selecting previously unselected package libheif-dev:amd64.
# Preparing to unpack .../078-libheif-dev_1.17.6-1ubuntu4.3_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libheif-dev:amd64 (1.17.6-1ubuntu4.3) ...
# Selecting previously unselected package libjson-c-dev:amd64.
# Preparing to unpack .../079-libjson-c-dev_0.17-1build1_amd64.deb ...
# Unpacking libjson-c-dev:amd64 (0.17-1build1) ...
# Selecting previously unselected package libhwy-dev:amd64.
# Preparing to unpack .../080-libhwy-dev_1.0.7-8.1build1_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libhwy-dev:amd64 (1.0.7-8.1build1) ...
# Selecting previously unselected package liblcms2-dev:amd64.
# Preparing to unpack .../081-liblcms2-dev_2.14-2ubuntu0.1_amd64.deb ...
# Unpacking liblcms2-dev:amd64 (2.14-2ubuntu0.1) ...
# Selecting previously unselected package libjxl-dev:amd64.
# Preparing to unpack .../082-libjxl-dev_0.7.0-10.2ubuntu6.1_amd64.deb ...
# Unpacking libjxl-dev:amd64 (0.7.0-10.2ubuntu6.1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libkmlconvenience1t64:amd64.
# Preparing to unpack .../083-libkmlconvenience1t64_1.3.0-12build1_amd64.deb ...
# Unpacking libkmlconvenience1t64:amd64 (1.3.0-12build1) ...
# Selecting previously unselected package libkmlregionator1t64:amd64.
# Preparing to unpack .../084-libkmlregionator1t64_1.3.0-12build1_amd64.deb ...
# Unpacking libkmlregionator1t64:amd64 (1.3.0-12build1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libkmlxsd1t64:amd64.
# Preparing to unpack .../085-libkmlxsd1t64_1.3.0-12build1_amd64.deb ...
# Unpacking libkmlxsd1t64:amd64 (1.3.0-12build1) ...
# Selecting previously unselected package liburiparser-dev.
# Preparing to unpack .../086-liburiparser-dev_0.9.7+dfsg-2build1_amd64.deb ...
# Unpacking liburiparser-dev (0.9.7+dfsg-2build1) ...
# Selecting previously unselected package libkml-dev:amd64.
# Preparing to unpack .../087-libkml-dev_1.3.0-12build1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libkml-dev:amd64 (1.3.0-12build1) ...
# Selecting previously unselected package libmuparser-dev.
# Preparing to unpack .../088-libmuparser-dev_2.3.3-0.1build1_amd64.deb ...
# Unpacking libmuparser-dev (2.3.3-0.1build1) ...
# Selecting previously unselected package libopenjp2-7-dev:amd64.
# Preparing to unpack .../089-libopenjp2-7-dev_2.5.0-2ubuntu0.5_amd64.deb ...
# 7Progress: [ 43%] [########################..................................] 8Unpacking libopenjp2-7-dev:amd64 (2.5.0-2ubuntu0.5) ...
# Selecting previously unselected package libpcre2-posix3:amd64.
# Preparing to unpack .../090-libpcre2-posix3_10.42-4ubuntu2.1_amd64.deb ...
# Unpacking libpcre2-posix3:amd64 (10.42-4ubuntu2.1) ...
# Selecting previously unselected package libpcre2-dev:amd64.
# Preparing to unpack .../091-libpcre2-dev_10.42-4ubuntu2.1_amd64.deb ...
# Unpacking libpcre2-dev:amd64 (10.42-4ubuntu2.1) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libpng-dev:amd64.
# Preparing to unpack .../092-libpng-dev_1.6.43-5ubuntu0.6_amd64.deb ...
# Unpacking libpng-dev:amd64 (1.6.43-5ubuntu0.6) ...
# Selecting previously unselected package libpoppler-dev:amd64.
# Preparing to unpack .../093-libpoppler-dev_24.02.0-1ubuntu9.8_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (24.02.0-1ubuntu9.8) ...
# Selecting previously unselected package libpoppler-private-dev:amd64.####................................] 8
# Preparing to unpack .../094-libpoppler-private-dev_24.02.0-1ubuntu9.8_amd64.deb ...
# Unpacking libpoppler-private-dev:amd64 (24.02.0-1ubuntu9.8) ...
# Selecting previously unselected package libpq-dev.
# Preparing to unpack .../095-libpq-dev_16.14-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking libpq-dev (16.14-0ubuntu0.24.04.1) ...
# Selecting previously unselected package libqhull8.0:amd64.
# Preparing to unpack .../096-libqhull8.0_2020.2-6build1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libqhull8.0:amd64 (2020.2-6build1) ...
# Selecting previously unselected package libqhullcpp8.0:amd64.
# Preparing to unpack .../097-libqhullcpp8.0_2020.2-6build1_amd64.deb ...
# Unpacking libqhullcpp8.0:amd64 (2020.2-6build1) ...
# Selecting previously unselected package libqhull-dev:amd64.
# Preparing to unpack .../098-libqhull-dev_2020.2-6build1_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libqhull-dev:amd64 (2020.2-6build1) ...
# Selecting previously unselected package librttopo-dev:amd64.
# Preparing to unpack .../099-librttopo-dev_1.1.0-3build2_amd64.deb ...
# Unpacking librttopo-dev:amd64 (1.1.0-3build2) ...
# Selecting previously unselected package libspatialite-dev:amd64.
# Preparing to unpack .../100-libspatialite-dev_5.1.0-3build1_amd64.deb ...
# Unpacking libspatialite-dev:amd64 (5.1.0-3build1) ...
# Selecting previously unselected package libodbccr2:amd64.#################...............................] 8
# Preparing to unpack .../101-libodbccr2_2.3.12-1ubuntu0.24.04.1_amd64.deb ...
# Unpacking libodbccr2:amd64 (2.3.12-1ubuntu0.24.04.1) ...
# Selecting previously unselected package unixodbc-dev:amd64.
# Preparing to unpack .../102-unixodbc-dev_2.3.12-1ubuntu0.24.04.1_amd64.deb ...
# Unpacking unixodbc-dev:amd64 (2.3.12-1ubuntu0.24.04.1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libgdal-dev.
# Preparing to unpack .../103-libgdal-dev_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking libgdal-dev (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package libpkgconf3:amd64.
# Preparing to unpack .../104-libpkgconf3_1.8.1-2build1_amd64.deb ...
# Unpacking libpkgconf3:amd64 (1.8.1-2build1) ...
# Selecting previously unselected package libpng-tools.
# Preparing to unpack .../105-libpng-tools_1.6.43-5ubuntu0.6_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking libpng-tools (1.6.43-5ubuntu0.6) ...
# Selecting previously unselected package pkgconf-bin.
# Preparing to unpack .../106-pkgconf-bin_1.8.1-2build1_amd64.deb ...
# Unpacking pkgconf-bin (1.8.1-2build1) ...
# Selecting previously unselected package pkgconf:amd64.
# Preparing to unpack .../107-pkgconf_1.8.1-2build1_amd64.deb ...
# Unpacking pkgconf:amd64 (1.8.1-2build1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package proj-bin.
# Preparing to unpack .../108-proj-bin_9.4.1-1~noble0_amd64.deb ...
# Unpacking proj-bin (9.4.1-1~noble0) ...
# Setting up libhwy1t64:amd64 (1.0.7-8.1build1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up liblcms2-2:amd64 (2.14-2ubuntu0.1) ...
# Setting up bzip2-doc (1.0.8-5.1build0.1) ...
# Setting up librttopo-dev:amd64 (1.1.0-3build2) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libmysqlclient21:amd64 (8.0.46-0ubuntu0.24.04.2) ...
# Setting up libkmlxsd1t64:amd64 (1.3.0-12build1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libcfitsio-dev:amd64 (4.3.1-1.1build2) ...
# Setting up libzstd-dev:amd64 (1.5.5+dfsg2-2build1.1) ...
# 7Progress: [ 55%] [################################..........................] 8Setting up libattr1-dev:amd64 (1:2.5.2-1build1.1) ...
# Setting up libqhull8.0:amd64 (2020.2-6build1) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libblosc-dev:amd64 (1.21.5+ds-1build1) ...
# Setting up libjson-c-dev:amd64 (0.17-1build1) ...
# Setting up libfyba-dev:amd64 (4.1.1-11build1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libwebpdemux2:amd64 (1.3.2-0.4build3) ...
# Setting up libsqlite3-0:amd64 (3.45.1-1ubuntu2.5) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libpq5:amd64 (16.14-0ubuntu0.24.04.1) ...
# Setting up libjbig-dev:amd64 (2.1-6.1ubuntu2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libwebpdecoder3:amd64 (1.3.2-0.4build3) ...
# Setting up proj-bin (9.4.1-1~noble0) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libpq-dev (16.14-0ubuntu0.24.04.1) ...
# Setting up libsvtav1enc1d1:amd64 (1.7.0+dfsg-2build1) ...
# Setting up libhdf4-0:amd64 (4.2.16-4build1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up librav1e0:amd64 (0.7.1-2) ...
# Setting up gdal-data (3.11.4+dfsg-1~noble0) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up liburiparser-dev (0.9.7+dfsg-2build1) ...
# Setting up libaom-dev:amd64 (3.8.2-2ubuntu0.1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libminizip-dev:amd64 (1:1.3.dfsg-3.1ubuntu2.1) ...
# Setting up libpkgconf3:amd64 (1.8.1-2build1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libgmpxx4ldbl:amd64 (2:6.3.0+dfsg-2ubuntu6.1) ...
# Setting up libsqlite3-dev:amd64 (3.45.1-1ubuntu2.5) ...
# Setting up libde265-dev:amd64 (1.0.15-1build3) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libgeos-dev (3.12.2-1~noble0) ...
# Setting up xz-utils (5.6.1+really5.4.5-1ubuntu0.3) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up comerr-dev:amd64 (2.1-1.47.0-2.4~exp1ubuntu4.1) ...
# Setting up libpng16-16t64:amd64 (1.6.43-5ubuntu0.6) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up liblz4-dev:amd64 (1.9.4-1build1.1) ...
# Setting up libqhullcpp8.0:amd64 (2020.2-6build1) ...
# Setting up pkgconf-bin (1.8.1-2build1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up liblerc-dev:amd64 (4.0.0+ds-4ubuntu2) ...
# Setting up libjxl0.7:amd64 (0.7.0-10.2ubuntu6.1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libqhull-dev:amd64 (2020.2-6build1) ...
# Setting up libhdf4-dev (4.2.16-4build1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libx265-199:amd64 (3.5-2build1) ...
# Setting up liblcms2-dev:amd64 (2.14-2ubuntu0.1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up liblzma-dev:amd64 (5.6.1+really5.4.5-1ubuntu0.3) ...
# Setting up libhwy-dev:amd64 (1.0.7-8.1build1) ...
# Setting up libpcre2-posix3:amd64 (10.42-4ubuntu2.1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libdav1d7:amd64 (1.4.1-1build1) ...
# Setting up libgif-dev:amd64 (5.2.2-1ubuntu1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libtiff6:amd64 (4.5.1+git230720-4ubuntu2.5) ...
# Setting up libopenjp2-7:amd64 (2.5.0-2ubuntu0.5) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libabsl20220623t64:amd64 (20220623.1-3.1ubuntu3.2) ...
# Setting up libkmlconvenience1t64:amd64 (1.3.0-12build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libexprtk-dev (0.0.3-3~noble0) ...
# Setting up libmuparser2v5:amd64 (2.3.3-0.1build1) ...
# Setting up libsharpyuv-dev:amd64 (1.3.2-0.4build3) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libext2fs-dev (1.47.0-2.4~exp1ubuntu4.1) ...
# Setting up libwebpmux3:amd64 (1.3.2-0.4build3) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libtiffxx6:amd64 (4.5.1+git230720-4ubuntu2.5) ...
# Setting up libdeflate-dev:amd64 (1.19-1build1.1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libyuv0:amd64 (0.0~git202401110.af6ac82-1) ...
# Setting up libcfitsio-doc (4.3.1-1.1build2) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libbrotli-dev:amd64 (1.1.0-2build2) ...
# Setting up libblas-dev:amd64 (3.12.0-3build1.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/blas/libblas.so to provide /usr/lib/x86_64-linux-gnu/libblas.so (libblas.so-x86_64-linux-gnu) in auto mode
# Setting up libmysqlclient-dev (8.0.46-0ubuntu0.24.04.2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libodbccr2:amd64 (2.3.12-1ubuntu0.24.04.1) ...
# Setting up libacl1-dev:amd64 (2.3.2-1build1.1) ...
# 7Progress: [ 81%] [##############################################............] 8Setting up gdal-plugins:amd64 (3.11.4+dfsg-1~noble0) ...
# Setting up libbz2-dev:amd64 (1.0.8-5.1build0.1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up default-libmysqlclient-dev:amd64 (1.1.0build1) ...
# Setting up libmuparser-dev (2.3.3-0.1build1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libgmp-dev:amd64 (2:6.3.0+dfsg-2ubuntu6.1) ...
# Setting up libkmlregionator1t64:amd64 (1.3.0-12build1) ...
# Setting up libpcre2-dev:amd64 (10.42-4ubuntu2.1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up nettle-dev:amd64 (3.9.1-2.2build1.1) ...
# Setting up libpng-tools (1.6.43-5ubuntu0.6) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libpoppler134:amd64 (24.02.0-1ubuntu9.8) ...
# Setting up libfreexl-dev:amd64 (2.0.0-1build2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libpng-dev:amd64 (1.6.43-5ubuntu0.6) ...
# Setting up pkgconf:amd64 (1.8.1-2build1) ...
# Setting up libwebp-dev:amd64 (1.3.2-0.4build3) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libtiff-dev:amd64 (4.5.1+git230720-4ubuntu2.5) ...
# Setting up libopenjp2-7-dev:amd64 (2.5.0-2ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libdav1d-dev:amd64 (1.4.1-1build1) ...
# Setting up libx265-dev:amd64 (3.5-2build1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up liblapack-dev:amd64 (3.12.0-3build1.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/lapack/liblapack.so to provide /usr/lib/x86_64-linux-gnu/liblapack.so (liblapack.so-x86_64-linux-gnu) in auto mode
# Setting up libproj-dev:amd64 (9.4.1-1~noble0) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libjxl-dev:amd64 (0.7.0-10.2ubuntu6.1) ...
# Setting up libgav1-1:amd64 (0.18.0-1build3) ...
# Setting up libspatialite-dev:amd64 (5.1.0-3build1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libarchive-dev:amd64 (3.7.2-2ubuntu0.7) ...
# Setting up libsuperlu-dev:amd64 (6.0.1+dfsg1-1build1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up unixodbc-dev:amd64 (2.3.12-1ubuntu0.24.04.1) ...
# Setting up libpoppler-dev:amd64 (24.02.0-1ubuntu9.8) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libkml-dev:amd64 (1.3.0-12build1) ...
# Setting up libavif16:amd64 (1.0.4-1ubuntu3) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libarpack2-dev:amd64 (3.9.1-1.1build2) ...
# Setting up libgeotiff-dev:amd64 (1.7.3-1~noble0) ...
# Setting up libpoppler-private-dev:amd64 (24.02.0-1ubuntu9.8) ...
# Setting up libarmadillo-dev (1:12.6.7+dfsg-1build2) ...###############################################...] 8
# Setting up libavif-dev:amd64 (1.0.4-1ubuntu3) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libheif-plugin-aomdec:amd64 (1.17.6-1ubuntu4.3) ...
# Setting up libheif1:amd64 (1.17.6-1ubuntu4.3) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libheif-dev:amd64 (1.17.6-1ubuntu4.3) ...
# Setting up libgdal37:amd64 (3.11.4+dfsg-1~noble0) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libgdal-dev (3.11.4+dfsg-1~noble0) ...
# Setting up python3-gdal (3.11.4+dfsg-1~noble0) ...
# Setting up libheif-plugin-libde265:amd64 (1.17.6-1ubuntu4.3) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up gdal-bin (3.11.4+dfsg-1~noble0) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.4) ...
#
# 78

# %% [markdown]
# ## Настройка путей
#
# Добавление путей к заголовочным файлам GDAL для компиляции.

# %%
# !export CPLUS_INCLUDE_PATH=/usr/include/gdal
# !export C_INCLUDE_PATH=/usr/include/gdal

# %% [markdown]
# # Установка Qt6
#
# Установка инструментов Qt6 и компилятора для сборки проекта.

# %%
# %%bash
# set -euo pipefail
#
# # 0) Инструменты Qt6 (для qmake6) + компилятор/гит
# sudo apt-get update -y
# sudo apt-get install -y qt6-base-dev qt6-base-dev-tools build-essential git
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:4 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:6 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists...
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# qt6-base-dev is already the newest version (6.4.2+dfsg-21.1build5).
# e newest version (6.4.2+dfsg-21.1build5).
# qt6-base-dev-tools set to manually installed.
# ial is already the newest version (12.10ubuntu1).
# u7.3). already the newest version (1:2.43.0-1ubunt
# The following packages were automatically installed and are no longer required:
#   libglapi-mesa libheif-plugin-libde265 libllvm19 libxcb-dri2-0
# them.sudo apt autoremove' to remove
# 0 upgraded, 0 newly installed, 0 to remove and 149 not upgraded.

# %% [markdown]
# # Компиляция QWT
#
# Сборка библиотек QWT из исходного кода (так как готовые пакеты для Qt6 недоступны).

# %% [markdown]
# ## переходим в директорию QT6

# %%
import os 
os.chdir("/home/jovyan/work/LISEM/qwt-multiaxes-qt6")

# %% [markdown]
# ## Настройка QWT
#
# Подготовка репозитория QWT с многокоординатными осями для работы с Qt6.

# %%
# %cd "/home/jovyan/work/LISEM/qwt-multiaxes-qt6"
# !git config --global --add safe.directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6'
# !git checkout qwt-multiaxes
# Out:
# /home/jovyan/work/LISEM/qwt-multiaxes-qt6
# /opt/venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# M	qwtconfig.pri
# error: Unable to create '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/.git/HEAD.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# fatal: unable to update HEAD

# %% [markdown]
# ## Сборка QWT
#
# Компиляция библиотек QWT с помощью qmake6 и make.

# %%
# !qmake6 qwt.pro
# !make -j"$(nproc)"
# Out:
# cd src/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/src.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/src'
# make[1]: Nothing to be done for 'first'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/src'
# cd classincludes/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/classincludes.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes'
# make[1]: Nothing to be done for 'first'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes'
# cd doc/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc/doc.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc'
# make[1]: Nothing to be done for 'first'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc'
# cd designer/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer/designer.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer'
# make[1]: Nothing to be done for 'first'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer'
# cd examples/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/examples.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples'
# cd animation/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation/animation.pro ) && make -f Makefile
# cd barchart/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart/barchart.pro ) && make -f Makefile
# cd cpuplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot/cpuplot.pro ) && make -f Makefile
# cd curvedemo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo/curvedemo.pro ) && make -f Makefile
# cd distrowatch/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch/distrowatch.pro ) && make -f Makefile
# cd friedberg/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg/friedberg.pro ) && make -f Makefile
# cd itemeditor/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor/itemeditor.pro ) && make -f Makefile
# cd legends/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends/legends.pro ) && make -f Makefile
# cd stockchart/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart/stockchart.pro ) && make -f Makefile
# cd simpleplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot/simpleplot.pro ) && make -f Makefile
# cd sinusplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot/sinusplot.pro ) && make -f Makefile
# cd realtime/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime/realtime.pro ) && make -f Makefile
# cd refreshtest/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest/refreshtest.pro ) && make -f Makefile
# cd scatterplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot/scatterplot.pro ) && make -f Makefile
# cd spectrogram/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram/spectrogram.pro ) && make -f Makefile
# cd rasterview/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview/rasterview.pro ) && make -f Makefile
# cd tvplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot/tvplot.pro ) && make -f Makefile
# cd bode/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode/bode.pro ) && make -f Makefile
# cd splineeditor/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor/splineeditor.pro ) && make -f Makefile
# cd oscilloscope/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope/oscilloscope.pro ) && make -f Makefile
# cd polardemo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo/polardemo.pro ) && make -f Makefile
# cd polarspectrogram/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram/polarspectrogram.pro ) && make -f Makefile
# cd sysinfo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo/sysinfo.pro ) && make -f Makefile
# cd radio/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio/radio.pro ) && make -f Makefile
# cd dials/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials/dials.pro ) && make -f Makefile
# cd controls/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls/controls.pro ) && make -f Makefile
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples'
# cd playground/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/playground.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground'
# cd plotmatrix/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix/plotmatrix.pro ) && make -f Makefile
# cd timescale/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale/timescale.pro ) && make -f Makefile
# cd scaleengine/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine/scaleengine.pro ) && make -f Makefile
# cd rescaler/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler/rescaler.pro ) && make -f Makefile
# cd shapes/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes/shapes.pro ) && make -f Makefile
# cd curvetracker/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker/curvetracker.pro ) && make -f Makefile
# cd vectorfield/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield/vectorfield.pro ) && make -f Makefile
# cd symbols/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols/symbols.pro ) && make -f Makefile
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground'
# cd tests/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/tests.pro ) && make -f Makefile
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests'
# cd splinetest/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest/splinetest.pro ) && make -f Makefile
# cd splineprof/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof/splineprof.pro ) && make -f Makefile
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof'
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest'
# make[2]: Nothing to be done for 'first'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests'

# %% [markdown]
# ## Установка QWT
#
# Копирование скомпилированных библиотек QWT в системные директории.

# %%
# !sudo make install
# Out:
# cd src/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/src.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/src'
# /usr/bin/qmake6 -install qinstall -exe ../lib/libqwt.so.6.4.0 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4.0
# strip --strip-unneeded /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4.0
# ln -f -s libqwt.so.6.4.0 /usr/local/qwt-6.4.0-ma/lib/libqwt.so
# ln -f -s libqwt.so.6.4.0 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6
# ln -f -s libqwt.so.6.4.0 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4
# install -m 644 -p ../lib/pkgconfig/Qt6Qwt6.pc /usr/local/qwt-6.4.0-ma/lib/pkgconfig/Qt6Qwt6.pc
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt.h /usr/local/qwt-6.4.0-ma/include/qwt.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_abstract_scale_draw.h /usr/local/qwt-6.4.0-ma/include/qwt_abstract_scale_draw.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_axis.h /usr/local/qwt-6.4.0-ma/include/qwt_axis.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_bezier.h /usr/local/qwt-6.4.0-ma/include/qwt_bezier.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_clipper.h /usr/local/qwt-6.4.0-ma/include/qwt_clipper.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_color_map.h /usr/local/qwt-6.4.0-ma/include/qwt_color_map.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_column_symbol.h /usr/local/qwt-6.4.0-ma/include/qwt_column_symbol.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_date.h /usr/local/qwt-6.4.0-ma/include/qwt_date.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_date_scale_draw.h /usr/local/qwt-6.4.0-ma/include/qwt_date_scale_draw.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_date_scale_engine.h /usr/local/qwt-6.4.0-ma/include/qwt_date_scale_engine.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_dyngrid_layout.h /usr/local/qwt-6.4.0-ma/include/qwt_dyngrid_layout.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_global.h /usr/local/qwt-6.4.0-ma/include/qwt_global.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_graphic.h /usr/local/qwt-6.4.0-ma/include/qwt_graphic.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_interval.h /usr/local/qwt-6.4.0-ma/include/qwt_interval.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_interval_symbol.h /usr/local/qwt-6.4.0-ma/include/qwt_interval_symbol.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_math.h /usr/local/qwt-6.4.0-ma/include/qwt_math.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_magnifier.h /usr/local/qwt-6.4.0-ma/include/qwt_magnifier.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_null_paintdevice.h /usr/local/qwt-6.4.0-ma/include/qwt_null_paintdevice.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_painter.h /usr/local/qwt-6.4.0-ma/include/qwt_painter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_painter_command.h /usr/local/qwt-6.4.0-ma/include/qwt_painter_command.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_panner.h /usr/local/qwt-6.4.0-ma/include/qwt_panner.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_picker.h /usr/local/qwt-6.4.0-ma/include/qwt_picker.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_picker_machine.h /usr/local/qwt-6.4.0-ma/include/qwt_picker_machine.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_pixel_matrix.h /usr/local/qwt-6.4.0-ma/include/qwt_pixel_matrix.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_point_3d.h /usr/local/qwt-6.4.0-ma/include/qwt_point_3d.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_point_polar.h /usr/local/qwt-6.4.0-ma/include/qwt_point_polar.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_round_scale_draw.h /usr/local/qwt-6.4.0-ma/include/qwt_round_scale_draw.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_div.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_div.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_draw.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_draw.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_engine.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_engine.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_map.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_map.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_map_table.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_map_table.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline.h /usr/local/qwt-6.4.0-ma/include/qwt_spline.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_basis.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_basis.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_parametrization.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_parametrization.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_local.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_local.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_cubic.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_cubic.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_pleasing.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_pleasing.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_polynomial.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_polynomial.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_symbol.h /usr/local/qwt-6.4.0-ma/include/qwt_symbol.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_system_clock.h /usr/local/qwt-6.4.0-ma/include/qwt_system_clock.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_text_engine.h /usr/local/qwt-6.4.0-ma/include/qwt_text_engine.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_text_label.h /usr/local/qwt-6.4.0-ma/include/qwt_text_label.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_text.h /usr/local/qwt-6.4.0-ma/include/qwt_text.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_transform.h /usr/local/qwt-6.4.0-ma/include/qwt_transform.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_widget_overlay.h /usr/local/qwt-6.4.0-ma/include/qwt_widget_overlay.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_axis_id.h /usr/local/qwt-6.4.0-ma/include/qwt_axis_id.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_curve_fitter.h /usr/local/qwt-6.4.0-ma/include/qwt_curve_fitter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_spline_curve_fitter.h /usr/local/qwt-6.4.0-ma/include/qwt_spline_curve_fitter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_weeding_curve_fitter.h /usr/local/qwt-6.4.0-ma/include/qwt_weeding_curve_fitter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_event_pattern.h /usr/local/qwt-6.4.0-ma/include/qwt_event_pattern.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_abstract_legend.h /usr/local/qwt-6.4.0-ma/include/qwt_abstract_legend.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_legend.h /usr/local/qwt-6.4.0-ma/include/qwt_legend.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_legend_data.h /usr/local/qwt-6.4.0-ma/include/qwt_legend_data.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_legend_label.h /usr/local/qwt-6.4.0-ma/include/qwt_legend_label.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot.h /usr/local/qwt-6.4.0-ma/include/qwt_plot.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_renderer.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_renderer.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_curve.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_curve.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_dict.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_dict.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_directpainter.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_directpainter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_graphicitem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_graphicitem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_grid.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_grid.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_histogram.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_histogram.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_item.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_item.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_abstract_barchart.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_abstract_barchart.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_barchart.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_barchart.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_multi_barchart.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_multi_barchart.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_intervalcurve.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_intervalcurve.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_tradingcurve.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_tradingcurve.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_layout.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_layout.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_marker.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_marker.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_zoneitem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_zoneitem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_textlabel.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_textlabel.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_rasteritem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_rasteritem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_spectrogram.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_spectrogram.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_spectrocurve.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_spectrocurve.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_scaleitem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_scaleitem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_legenditem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_legenditem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_seriesitem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_seriesitem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_shapeitem.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_shapeitem.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_vectorfield.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_vectorfield.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_abstract_canvas.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_abstract_canvas.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_canvas.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_canvas.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_panner.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_panner.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_picker.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_picker.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_zoomer.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_zoomer.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_magnifier.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_magnifier.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_rescaler.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_rescaler.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_point_mapper.h /usr/local/qwt-6.4.0-ma/include/qwt_point_mapper.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_raster_data.h /usr/local/qwt-6.4.0-ma/include/qwt_raster_data.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_matrix_raster_data.h /usr/local/qwt-6.4.0-ma/include/qwt_matrix_raster_data.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_vectorfield_symbol.h /usr/local/qwt-6.4.0-ma/include/qwt_vectorfield_symbol.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_sampling_thread.h /usr/local/qwt-6.4.0-ma/include/qwt_sampling_thread.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_samples.h /usr/local/qwt-6.4.0-ma/include/qwt_samples.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_series_data.h /usr/local/qwt-6.4.0-ma/include/qwt_series_data.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_series_store.h /usr/local/qwt-6.4.0-ma/include/qwt_series_store.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_point_data.h /usr/local/qwt-6.4.0-ma/include/qwt_point_data.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_scale_widget.h /usr/local/qwt-6.4.0-ma/include/qwt_scale_widget.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_plot_opengl_canvas.h /usr/local/qwt-6.4.0-ma/include/qwt_plot_opengl_canvas.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar.h /usr/local/qwt-6.4.0-ma/include/qwt_polar.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_canvas.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_canvas.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_curve.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_curve.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_fitter.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_fitter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_grid.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_grid.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_itemdict.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_itemdict.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_item.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_item.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_layout.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_layout.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_magnifier.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_magnifier.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_marker.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_marker.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_panner.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_panner.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_picker.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_picker.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_plot.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_plot.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_renderer.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_renderer.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_polar_spectrogram.h /usr/local/qwt-6.4.0-ma/include/qwt_polar_spectrogram.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_abstract_slider.h /usr/local/qwt-6.4.0-ma/include/qwt_abstract_slider.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_abstract_scale.h /usr/local/qwt-6.4.0-ma/include/qwt_abstract_scale.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_arrow_button.h /usr/local/qwt-6.4.0-ma/include/qwt_arrow_button.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_analog_clock.h /usr/local/qwt-6.4.0-ma/include/qwt_analog_clock.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_compass.h /usr/local/qwt-6.4.0-ma/include/qwt_compass.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_compass_rose.h /usr/local/qwt-6.4.0-ma/include/qwt_compass_rose.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_counter.h /usr/local/qwt-6.4.0-ma/include/qwt_counter.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_dial.h /usr/local/qwt-6.4.0-ma/include/qwt_dial.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_dial_needle.h /usr/local/qwt-6.4.0-ma/include/qwt_dial_needle.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_knob.h /usr/local/qwt-6.4.0-ma/include/qwt_knob.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_slider.h /usr/local/qwt-6.4.0-ma/include/qwt_slider.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_thermo.h /usr/local/qwt-6.4.0-ma/include/qwt_thermo.h
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/src/qwt_wheel.h /usr/local/qwt-6.4.0-ma/include/qwt_wheel.h
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/src'
# cd classincludes/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/classincludes.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes'
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAbstractScaleDraw /usr/local/qwt-6.4.0-ma/include/QwtAbstractScaleDraw
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAlphaColorMap /usr/local/qwt-6.4.0-ma/include/QwtAlphaColorMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAxis /usr/local/qwt-6.4.0-ma/include/QwtAxis
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAxisId /usr/local/qwt-6.4.0-ma/include/QwtAxisId
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtBezier /usr/local/qwt-6.4.0-ma/include/QwtBezier
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtClipper /usr/local/qwt-6.4.0-ma/include/QwtClipper
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtColorMap /usr/local/qwt-6.4.0-ma/include/QwtColorMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtColumnRect /usr/local/qwt-6.4.0-ma/include/QwtColumnRect
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtColumnSymbol /usr/local/qwt-6.4.0-ma/include/QwtColumnSymbol
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDate /usr/local/qwt-6.4.0-ma/include/QwtDate
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDateScaleDraw /usr/local/qwt-6.4.0-ma/include/QwtDateScaleDraw
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDateScaleEngine /usr/local/qwt-6.4.0-ma/include/QwtDateScaleEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDynGridLayout /usr/local/qwt-6.4.0-ma/include/QwtDynGridLayout
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtGlobal /usr/local/qwt-6.4.0-ma/include/QwtGlobal
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtGraphic /usr/local/qwt-6.4.0-ma/include/QwtGraphic
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtHueColorMap /usr/local/qwt-6.4.0-ma/include/QwtHueColorMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtInterval /usr/local/qwt-6.4.0-ma/include/QwtInterval
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtIntervalSymbol /usr/local/qwt-6.4.0-ma/include/QwtIntervalSymbol
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLinearColorMap /usr/local/qwt-6.4.0-ma/include/QwtLinearColorMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLinearScaleEngine /usr/local/qwt-6.4.0-ma/include/QwtLinearScaleEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLogScaleEngine /usr/local/qwt-6.4.0-ma/include/QwtLogScaleEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLogTransform /usr/local/qwt-6.4.0-ma/include/QwtLogTransform
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtMagnifier /usr/local/qwt-6.4.0-ma/include/QwtMagnifier
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtMath /usr/local/qwt-6.4.0-ma/include/QwtMath
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtNullPaintDevice /usr/local/qwt-6.4.0-ma/include/QwtNullPaintDevice
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtNullTransform /usr/local/qwt-6.4.0-ma/include/QwtNullTransform
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPainter /usr/local/qwt-6.4.0-ma/include/QwtPainter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPainterCommand /usr/local/qwt-6.4.0-ma/include/QwtPainterCommand
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPanner /usr/local/qwt-6.4.0-ma/include/QwtPanner
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPicker /usr/local/qwt-6.4.0-ma/include/QwtPicker
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerClickPointMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerClickPointMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerClickRectMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerClickRectMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerDragLineMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerDragLineMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerDragPointMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerDragPointMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerDragRectMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerDragRectMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerPolygonMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerPolygonMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPickerTrackerMachine /usr/local/qwt-6.4.0-ma/include/QwtPickerTrackerMachine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPixelMatrix /usr/local/qwt-6.4.0-ma/include/QwtPixelMatrix
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlainTextEngine /usr/local/qwt-6.4.0-ma/include/QwtPlainTextEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPoint3D /usr/local/qwt-6.4.0-ma/include/QwtPoint3D
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPointPolar /usr/local/qwt-6.4.0-ma/include/QwtPointPolar
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPowerTransform /usr/local/qwt-6.4.0-ma/include/QwtPowerTransform
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtRichTextEngine /usr/local/qwt-6.4.0-ma/include/QwtRichTextEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtRoundScaleDraw /usr/local/qwt-6.4.0-ma/include/QwtRoundScaleDraw
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSaturationValueColorMap /usr/local/qwt-6.4.0-ma/include/QwtSaturationValueColorMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleArithmetic /usr/local/qwt-6.4.0-ma/include/QwtScaleArithmetic
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleDiv /usr/local/qwt-6.4.0-ma/include/QwtScaleDiv
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleDraw /usr/local/qwt-6.4.0-ma/include/QwtScaleDraw
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleEngine /usr/local/qwt-6.4.0-ma/include/QwtScaleEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleMap /usr/local/qwt-6.4.0-ma/include/QwtScaleMap
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleMapTable /usr/local/qwt-6.4.0-ma/include/QwtScaleMapTable
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSimpleCompassRose /usr/local/qwt-6.4.0-ma/include/QwtSimpleCompassRose
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineBasis /usr/local/qwt-6.4.0-ma/include/QwtSplineBasis
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSpline /usr/local/qwt-6.4.0-ma/include/QwtSpline
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineC1 /usr/local/qwt-6.4.0-ma/include/QwtSplineC1
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineC2 /usr/local/qwt-6.4.0-ma/include/QwtSplineC2
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineCubic /usr/local/qwt-6.4.0-ma/include/QwtSplineCubic
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineG1 /usr/local/qwt-6.4.0-ma/include/QwtSplineG1
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineInterpolating /usr/local/qwt-6.4.0-ma/include/QwtSplineInterpolating
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineLocal /usr/local/qwt-6.4.0-ma/include/QwtSplineLocal
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineParameter /usr/local/qwt-6.4.0-ma/include/QwtSplineParameter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineParametrization /usr/local/qwt-6.4.0-ma/include/QwtSplineParametrization
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplinePleasing /usr/local/qwt-6.4.0-ma/include/QwtSplinePleasing
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplinePolynomial /usr/local/qwt-6.4.0-ma/include/QwtSplinePolynomial
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSymbol /usr/local/qwt-6.4.0-ma/include/QwtSymbol
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSystemClock /usr/local/qwt-6.4.0-ma/include/QwtSystemClock
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtText /usr/local/qwt-6.4.0-ma/include/QwtText
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtTextEngine /usr/local/qwt-6.4.0-ma/include/QwtTextEngine
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtTextLabel /usr/local/qwt-6.4.0-ma/include/QwtTextLabel
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtTransform /usr/local/qwt-6.4.0-ma/include/QwtTransform
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtWidgetOverlay /usr/local/qwt-6.4.0-ma/include/QwtWidgetOverlay
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAbstractLegend /usr/local/qwt-6.4.0-ma/include/QwtAbstractLegend
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCurveFitter /usr/local/qwt-6.4.0-ma/include/QwtCurveFitter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtEventPattern /usr/local/qwt-6.4.0-ma/include/QwtEventPattern
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtIntervalSample /usr/local/qwt-6.4.0-ma/include/QwtIntervalSample
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLegend /usr/local/qwt-6.4.0-ma/include/QwtLegend
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLegendData /usr/local/qwt-6.4.0-ma/include/QwtLegendData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtLegendLabel /usr/local/qwt-6.4.0-ma/include/QwtLegendLabel
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPointMapper /usr/local/qwt-6.4.0-ma/include/QwtPointMapper
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtMatrixRasterData /usr/local/qwt-6.4.0-ma/include/QwtMatrixRasterData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtOHLCSample /usr/local/qwt-6.4.0-ma/include/QwtOHLCSample
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlot /usr/local/qwt-6.4.0-ma/include/QwtPlot
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotAbstractBarChart /usr/local/qwt-6.4.0-ma/include/QwtPlotAbstractBarChart
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotAbstractCanvas /usr/local/qwt-6.4.0-ma/include/QwtPlotAbstractCanvas
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotBarChart /usr/local/qwt-6.4.0-ma/include/QwtPlotBarChart
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotCanvas /usr/local/qwt-6.4.0-ma/include/QwtPlotCanvas
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotCurve /usr/local/qwt-6.4.0-ma/include/QwtPlotCurve
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotDict /usr/local/qwt-6.4.0-ma/include/QwtPlotDict
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotDirectPainter /usr/local/qwt-6.4.0-ma/include/QwtPlotDirectPainter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotGraphicItem /usr/local/qwt-6.4.0-ma/include/QwtPlotGraphicItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotGrid /usr/local/qwt-6.4.0-ma/include/QwtPlotGrid
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotHistogram /usr/local/qwt-6.4.0-ma/include/QwtPlotHistogram
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotIntervalCurve /usr/local/qwt-6.4.0-ma/include/QwtPlotIntervalCurve
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotItem /usr/local/qwt-6.4.0-ma/include/QwtPlotItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotLayout /usr/local/qwt-6.4.0-ma/include/QwtPlotLayout
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotLegendItem /usr/local/qwt-6.4.0-ma/include/QwtPlotLegendItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotMagnifier /usr/local/qwt-6.4.0-ma/include/QwtPlotMagnifier
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotMarker /usr/local/qwt-6.4.0-ma/include/QwtPlotMarker
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotMultiBarChart /usr/local/qwt-6.4.0-ma/include/QwtPlotMultiBarChart
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotPanner /usr/local/qwt-6.4.0-ma/include/QwtPlotPanner
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotPicker /usr/local/qwt-6.4.0-ma/include/QwtPlotPicker
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotRasterItem /usr/local/qwt-6.4.0-ma/include/QwtPlotRasterItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotRenderer /usr/local/qwt-6.4.0-ma/include/QwtPlotRenderer
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotRescaler /usr/local/qwt-6.4.0-ma/include/QwtPlotRescaler
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotScaleItem /usr/local/qwt-6.4.0-ma/include/QwtPlotScaleItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotSeriesItem /usr/local/qwt-6.4.0-ma/include/QwtPlotSeriesItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotShapeItem /usr/local/qwt-6.4.0-ma/include/QwtPlotShapeItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotSpectroCurve /usr/local/qwt-6.4.0-ma/include/QwtPlotSpectroCurve
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotSpectrogram /usr/local/qwt-6.4.0-ma/include/QwtPlotSpectrogram
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotTextLabel /usr/local/qwt-6.4.0-ma/include/QwtPlotTextLabel
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotTradingCurve /usr/local/qwt-6.4.0-ma/include/QwtPlotTradingCurve
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotVectorField /usr/local/qwt-6.4.0-ma/include/QwtPlotVectorField
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotZoneItem /usr/local/qwt-6.4.0-ma/include/QwtPlotZoneItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotZoomer /usr/local/qwt-6.4.0-ma/include/QwtPlotZoomer
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtScaleWidget /usr/local/qwt-6.4.0-ma/include/QwtScaleWidget
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtRasterData /usr/local/qwt-6.4.0-ma/include/QwtRasterData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSeriesData /usr/local/qwt-6.4.0-ma/include/QwtSeriesData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSetSample /usr/local/qwt-6.4.0-ma/include/QwtSetSample
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSamplingThread /usr/local/qwt-6.4.0-ma/include/QwtSamplingThread
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSplineCurveFitter /usr/local/qwt-6.4.0-ma/include/QwtSplineCurveFitter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtWeedingCurveFitter /usr/local/qwt-6.4.0-ma/include/QwtWeedingCurveFitter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtIntervalSeriesData /usr/local/qwt-6.4.0-ma/include/QwtIntervalSeriesData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPoint3DSeriesData /usr/local/qwt-6.4.0-ma/include/QwtPoint3DSeriesData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPointSeriesData /usr/local/qwt-6.4.0-ma/include/QwtPointSeriesData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSetSeriesData /usr/local/qwt-6.4.0-ma/include/QwtSetSeriesData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSyntheticPointData /usr/local/qwt-6.4.0-ma/include/QwtSyntheticPointData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPointArrayData /usr/local/qwt-6.4.0-ma/include/QwtPointArrayData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtTradingChartData /usr/local/qwt-6.4.0-ma/include/QwtTradingChartData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtVectorFieldSymbol /usr/local/qwt-6.4.0-ma/include/QwtVectorFieldSymbol
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtVectorFieldArrow /usr/local/qwt-6.4.0-ma/include/QwtVectorFieldArrow
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtVectorFieldThinArrow /usr/local/qwt-6.4.0-ma/include/QwtVectorFieldThinArrow
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtVectorFieldData /usr/local/qwt-6.4.0-ma/include/QwtVectorFieldData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtVectorFieldSample /usr/local/qwt-6.4.0-ma/include/QwtVectorFieldSample
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCPointerData /usr/local/qwt-6.4.0-ma/include/QwtCPointerData
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarCanvas /usr/local/qwt-6.4.0-ma/include/QwtPolarCanvas
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarCurve /usr/local/qwt-6.4.0-ma/include/QwtPolarCurve
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarFitter /usr/local/qwt-6.4.0-ma/include/QwtPolarFitter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarGrid /usr/local/qwt-6.4.0-ma/include/QwtPolarGrid
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarItem /usr/local/qwt-6.4.0-ma/include/QwtPolarItem
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarItemDict /usr/local/qwt-6.4.0-ma/include/QwtPolarItemDict
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarLayout /usr/local/qwt-6.4.0-ma/include/QwtPolarLayout
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarMagnifier /usr/local/qwt-6.4.0-ma/include/QwtPolarMagnifier
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarMarker /usr/local/qwt-6.4.0-ma/include/QwtPolarMarker
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarPanner /usr/local/qwt-6.4.0-ma/include/QwtPolarPanner
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarPicker /usr/local/qwt-6.4.0-ma/include/QwtPolarPicker
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarPlot /usr/local/qwt-6.4.0-ma/include/QwtPolarPlot
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarRenderer /usr/local/qwt-6.4.0-ma/include/QwtPolarRenderer
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPolarSpectrogram /usr/local/qwt-6.4.0-ma/include/QwtPolarSpectrogram
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtPlotOpenGLCanvas /usr/local/qwt-6.4.0-ma/include/QwtPlotOpenGLCanvas
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAbstractSlider /usr/local/qwt-6.4.0-ma/include/QwtAbstractSlider
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAbstractScale /usr/local/qwt-6.4.0-ma/include/QwtAbstractScale
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtArrowButton /usr/local/qwt-6.4.0-ma/include/QwtArrowButton
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtAnalogClock /usr/local/qwt-6.4.0-ma/include/QwtAnalogClock
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCompass /usr/local/qwt-6.4.0-ma/include/QwtCompass
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCompassMagnetNeedle /usr/local/qwt-6.4.0-ma/include/QwtCompassMagnetNeedle
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCompassRose /usr/local/qwt-6.4.0-ma/include/QwtCompassRose
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCompassScaleDraw /usr/local/qwt-6.4.0-ma/include/QwtCompassScaleDraw
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCompassWindArrow /usr/local/qwt-6.4.0-ma/include/QwtCompassWindArrow
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtCounter /usr/local/qwt-6.4.0-ma/include/QwtCounter
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDial /usr/local/qwt-6.4.0-ma/include/QwtDial
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDialNeedle /usr/local/qwt-6.4.0-ma/include/QwtDialNeedle
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtDialSimpleNeedle /usr/local/qwt-6.4.0-ma/include/QwtDialSimpleNeedle
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtKnob /usr/local/qwt-6.4.0-ma/include/QwtKnob
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtSlider /usr/local/qwt-6.4.0-ma/include/QwtSlider
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtThermo /usr/local/qwt-6.4.0-ma/include/QwtThermo
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes/QwtWheel /usr/local/qwt-6.4.0-ma/include/QwtWheel
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/classincludes'
# cd doc/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc/doc.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc'
# make[1]: Nothing to be done for 'install'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/doc'
# cd designer/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer/designer.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer'
# make[1]: Nothing to be done for 'install'.
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/designer'
# cd examples/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/examples.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples'
# cd animation/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation/animation.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/animation'
# cd barchart/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart/barchart.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/barchart'
# cd cpuplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot/cpuplot.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/cpuplot'
# cd curvedemo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo/curvedemo.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/curvedemo'
# cd distrowatch/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch/distrowatch.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/distrowatch'
# cd friedberg/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg/friedberg.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/friedberg'
# cd itemeditor/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor/itemeditor.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/itemeditor'
# cd legends/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends/legends.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/legends'
# cd stockchart/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart/stockchart.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/stockchart'
# cd simpleplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot/simpleplot.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/simpleplot'
# cd sinusplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot/sinusplot.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sinusplot'
# cd realtime/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime/realtime.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/realtime'
# cd refreshtest/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest/refreshtest.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/refreshtest'
# cd scatterplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot/scatterplot.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/scatterplot'
# cd spectrogram/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram/spectrogram.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/spectrogram'
# cd rasterview/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview/rasterview.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/rasterview'
# cd tvplot/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot/tvplot.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/tvplot'
# cd bode/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode/bode.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/bode'
# cd splineeditor/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor/splineeditor.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/splineeditor'
# cd oscilloscope/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope/oscilloscope.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/oscilloscope'
# cd polardemo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo/polardemo.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polardemo'
# cd polarspectrogram/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram/polarspectrogram.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/polarspectrogram'
# cd sysinfo/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo/sysinfo.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/sysinfo'
# cd radio/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio/radio.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/radio'
# cd dials/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials/dials.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/dials'
# cd controls/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls/controls.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples/controls'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/examples'
# cd playground/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/playground.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground'
# cd plotmatrix/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix/plotmatrix.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/plotmatrix'
# cd timescale/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale/timescale.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/timescale'
# cd scaleengine/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine/scaleengine.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/scaleengine'
# cd rescaler/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler/rescaler.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/rescaler'
# cd shapes/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes/shapes.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/shapes'
# cd curvetracker/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker/curvetracker.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/curvetracker'
# cd vectorfield/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield/vectorfield.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/vectorfield'
# cd symbols/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols/symbols.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground/symbols'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/playground'
# cd tests/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/tests.pro ) && make -f Makefile install
# make[1]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests'
# cd splinetest/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest/splinetest.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splinetest'
# cd splineprof/ && ( test -e Makefile || /usr/bin/qmake6 -o Makefile /home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof/splineprof.pro ) && make -f Makefile install
# make[2]: Entering directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof'
# make[2]: Nothing to be done for 'install'.
# make[2]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests/splineprof'
# make[1]: Leaving directory '/home/jovyan/work/LISEM/qwt-multiaxes-qt6/tests'
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/qwtconfig.pri /usr/local/qwt-6.4.0-ma/features/qwtconfig.pri
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/qwtfunctions.pri /usr/local/qwt-6.4.0-ma/features/qwtfunctions.pri
# /usr/bin/qmake6 -install qinstall /home/jovyan/work/LISEM/qwt-multiaxes-qt6/qwt.prf /usr/local/qwt-6.4.0-ma/features/qwt.prf

# %% [markdown]
# ## Настройка путей
#
# Добавление пути к библиотекам QWT в системный конфиг для динамической линковки.

# %%
# !echo "/usr/local/qwt-6.4.0-ma/lib" | sudo tee /etc/ld.so.conf.d/qwt.conf
# Out:
# /usr/local/qwt-6.4.0-ma/lib

# %% [markdown]
# ## Обновление кэша библиотек
#
# Обновление системного кэша библиотек и проверка наличия QWT.

# %%
# !sudo ldconfig
# !ldconfig -p | grep qwt
# !ls -la /usr/local/qwt-6.4.0-ma/lib/libqwt*
# Out:
# 	libqwt.so.6.4 (libc6,x86-64) => /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4
# 	libqwt.so (libc6,x86-64) => /usr/local/qwt-6.4.0-ma/lib/libqwt.so
# lrwxrwxrwx. 1 root root      15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so -> libqwt.so.6.4.0
# lrwxrwxrwx. 1 root root      15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6 -> libqwt.so.6.4.0
# lrwxrwxrwx. 1 root root      15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4 -> libqwt.so.6.4.0
# -rwxr-xr-x. 1 root root 2020472 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4.0

# %% [markdown]
# ## Добавить переменные среды

# %%
# !export LD_LIBRARY_PATH="/usr/local/qwt-6.4.0-ma/lib:$LD_LIBRARY_PATH"
# !export PKG_CONFIG_PATH="/usr/local/qwt-6.4.0-ma/lib/pkgconfig:$PKG_CONFIG_PATH"

# %%
# !sudo ldconfig
# !ldconfig -p | grep -i qwt || true
# Out:
# 	libqwt.so.6.4 (libc6,x86-64) => /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4
# 	libqwt.so (libc6,x86-64) => /usr/local/qwt-6.4.0-ma/lib/libqwt.so

# %% [markdown]
# ## Проверка установки
#
# Проверка наличия библиотек и заголовочных файлов QWT после установки.

# %%
# !ls -l /usr/local/qwt-6.4.0-ma/lib/libqwt.so
# !ls -1 /usr/local/qwt-6.4.0-ma/include | head
# Out:
# lrwxrwxrwx. 1 root root 15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so -> libqwt.so.6.4.0
# QwtAbstractLegend
# qwt_abstract_legend.h
# QwtAbstractScale
# QwtAbstractScaleDraw
# qwt_abstract_scale_draw.h
# qwt_abstract_scale.h
# QwtAbstractSlider
# qwt_abstract_slider.h
# QwtAlphaColorMap
# QwtAnalogClock

# %% [markdown]
# # Ставим LISEM

# %%
os.chdir("/home/jovyan/work/LISEM")

# %% [markdown]
# ## Клонирование LISEM
#
# Клонирование основной ветки проекта LISEM для последующей сборки.

# %%
"""
# %%bash
set -euo pipefail
cd "/home/jovyan/work/LISEM"

# если папка уже есть — удалим, чтобы не мешала (опционально)
rm -rf lisem

# клонируем конкретно ветку main_C
git clone --branch main_C --depth 1 https://github.com/vjetten/openlisem.git lisem # можно закомментить, если ветка уже установлена 
"""
# Out:
# '\n%%bash\nset -euo pipefail\ncd "/home/jovyan/work/LISEM"\n\n# если папка уже есть — удалим, чтобы не мешала (опционально)\nrm -rf lisem\n\n# клонируем конкретно ветку main_C\ngit clone --branch main_C --depth 1 https://github.com/vjetten/openlisem.git lisem # можно закомментить, если ветка уже установлена \n'

# %% [markdown]
# ## Подготовка к сборке
#
# Создание директории для бинарных файлов LISEM.

# %%
# %%bash
# set -euo pipefail
# cd "/home/jovyan/work/LISEM"
# mkdir -p lisem-bin
# cd lisem-bin

# %% [markdown]
# ## Если нет Cmake

# %%
# %%bash
# set -euo pipefail
#
# # 0) установить cmake (и то, что часто нужно для Qt6)
# sudo apt-get update -y
# sudo apt-get install -y cmake build-essential ninja-build \
#                         qt6-base-dev qt6-tools-dev qt6-tools-dev-tools
# cmake --version
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:4 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:6 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists...
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# cmake is already the newest version (3.28.3-1build7).
# (12.10ubuntu1). is already the newest version
# qt6-base-dev is already the newest version (6.4.2+dfsg-21.1build5).
# ckages were automatically installed and are no longer required:
#   libglapi-mesa libheif-plugin-libde265 libllvm19 libxcb-dri2-0
# them.sudo apt autoremove' to remove
# The following additional packages will be installed:
# 15t64 libclang1-15t64 libgumbo2bclang-cpp
# nts6blitehtml0t64 libllvm15t64 libqt6designer6 libqt6designercompone
#   libqt6help6 libqt6quickwidgets6 libqt6uitools6 linguist-qt6 qdbus-qt6
# 6-l10n-toolsntation-tools qt
# The following NEW packages will be installed:
#   assistant-qt6 designer-qt6 libclang-cpp15t64 libclang1-15t64 libgumbo2
# t64 libqt6designer6 libqt6designercomponents6
#   libqt6help6 libqt6quickwidgets6 libqt6uitools6 linguist-qt6 ninja-build
#   qdbus-qt6 qt6-documentation-tools qt6-l10n-tools qt6-tools-dev
#   qt6-tools-dev-tools
# 0 upgraded, 19 newly installed, 0 to remove and 149 not upgraded.
# Need to get 52,1 MB of archives.
# fter this operation, 230 MB of additional disk space will be used.
# buntu noble/universe amd64 libgumbo2 amd64 0.12.0+dfsg-2build1 [126 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/universe amd64 liblitehtml0t64 amd64 0.6-1.2ubuntu2 [208 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6help6 amd64 6.4.2-3build3 [189 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/universe amd64 assistant-qt6 amd64 6.4.2-3build3 [272 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6designer6 amd64 6.4.2-3build3 [2��923 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6designercomponents6 amd64 6.4.2-3build3 [878 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6quickwidgets6 amd64 6.4.2+dfsg-4build3 [43,8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/universe amd64 designer-qt6 amd64 6.4.2-3build3 [175 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/universe amd64 libllvm15t64 amd64 1:15.0.7-14build3 [25,5 MB]
# Get:10 http://archive.ubuntu.com/ubuntu noble/universe amd64 libclang-cpp15t64 amd64 1:15.0.7-14build3 [12,6 MB]
# Get:11 http://archive.ubuntu.com/ubuntu noble/universe amd64 libclang1-15t64 amd64 1:15.0.7-14build3 [6 958 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble/universe amd64 libqt6uitools6 amd64 6.4.2-3build3 [173 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/universe amd64 linguist-qt6 amd64 6.4.2-3build3 [368 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/universe amd64 ninja-build amd64 1.11.1-2 [129 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/universe amd64 qdbus-qt6 amd64 6.4.2-3build3 [30,7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-documentation-tools amd64 6.4.2-3build3 [646 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-l10n-tools amd64 6.4.2-3build3 [486 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-tools-dev-tools amd64 6.4.2-3build3 [274 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/universe amd64 qt6-tools-dev amd64 6.4.2-3build3 [64,8 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 52,1 MB in 5s (10,5 MB/s)
# Selecting previously unselected package libgumbo2:amd64.
# (Reading database ... 77970 files and directories currently installed.)
# Preparing to unpack .../00-libgumbo2_0.12.0+dfsg-2build1_amd64.deb ...
# Unpacking libgumbo2:amd64 (0.12.0+dfsg-2build1) ...
# Selecting previously unselected package liblitehtml0t64:amd64.
# Preparing to unpack .../01-liblitehtml0t64_0.6-1.2ubuntu2_amd64.deb ...
# Unpacking liblitehtml0t64:amd64 (0.6-1.2ubuntu2) ...
# Selecting previously unselected package libqt6help6:amd64.
# Preparing to unpack .../02-libqt6help6_6.4.2-3build3_amd64.deb ...
# Unpacking libqt6help6:amd64 (6.4.2-3build3) ...
# Selecting previously unselected package assistant-qt6.
# Preparing to unpack .../03-assistant-qt6_6.4.2-3build3_amd64.deb ...
# Unpacking assistant-qt6 (6.4.2-3build3) ...
# Selecting previously unselected package libqt6designer6:amd64.
# Preparing to unpack .../04-libqt6designer6_6.4.2-3build3_amd64.deb ...
# Unpacking libqt6designer6:amd64 (6.4.2-3build3) ...
# Selecting previously unselected package libqt6designercomponents6:amd64.
# Preparing to unpack .../05-libqt6designercomponents6_6.4.2-3build3_amd64.deb ...
# Unpacking libqt6designercomponents6:amd64 (6.4.2-3build3) ...
# Selecting previously unselected package libqt6quickwidgets6:amd64.
# Preparing to unpack .../06-libqt6quickwidgets6_6.4.2+dfsg-4build3_amd64.deb ...
# Unpacking libqt6quickwidgets6:amd64 (6.4.2+dfsg-4build3) ...
# Selecting previously unselected package designer-qt6.
# Preparing to unpack .../07-designer-qt6_6.4.2-3build3_amd64.deb ...
# Unpacking designer-qt6 (6.4.2-3build3) ...
# Selecting previously unselected package libllvm15t64:amd64.
# Preparing to unpack .../08-libllvm15t64_1%3a15.0.7-14build3_amd64.deb ...
# Unpacking libllvm15t64:amd64 (1:15.0.7-14build3) ...
# Selecting previously unselected package libclang-cpp15t64.
# Preparing to unpack .../09-libclang-cpp15t64_1%3a15.0.7-14build3_amd64.deb ...
# Unpacking libclang-cpp15t64 (1:15.0.7-14build3) ...
# Selecting previously unselected package libclang1-15t64.
# Preparing to unpack .../10-libclang1-15t64_1%3a15.0.7-14build3_amd64.deb ...
# Unpacking libclang1-15t64 (1:15.0.7-14build3) ...
# Selecting previously unselected package libqt6uitools6:amd64.
# Preparing to unpack .../11-libqt6uitools6_6.4.2-3build3_amd64.deb ...
# Unpacking libqt6uitools6:amd64 (6.4.2-3build3) ...
# Selecting previously unselected package linguist-qt6.
# Preparing to unpack .../12-linguist-qt6_6.4.2-3build3_amd64.deb ...
# Unpacking linguist-qt6 (6.4.2-3build3) ...
# Selecting previously unselected package ninja-build.
# Preparing to unpack .../13-ninja-build_1.11.1-2_amd64.deb ...
# Unpacking ninja-build (1.11.1-2) ...
# Selecting previously unselected package qdbus-qt6.
# Preparing to unpack .../14-qdbus-qt6_6.4.2-3build3_amd64.deb ...
# Unpacking qdbus-qt6 (6.4.2-3build3) ...
# Selecting previously unselected package qt6-documentation-tools.
# Preparing to unpack .../15-qt6-documentation-tools_6.4.2-3build3_amd64.deb ...
# Unpacking qt6-documentation-tools (6.4.2-3build3) ...
# Selecting previously unselected package qt6-l10n-tools.
# Preparing to unpack .../16-qt6-l10n-tools_6.4.2-3build3_amd64.deb ...
# Unpacking qt6-l10n-tools (6.4.2-3build3) ...
# Selecting previously unselected package qt6-tools-dev-tools.
# Preparing to unpack .../17-qt6-tools-dev-tools_6.4.2-3build3_amd64.deb ...
# Unpacking qt6-tools-dev-tools (6.4.2-3build3) ...
# Selecting previously unselected package qt6-tools-dev:amd64.
# Preparing to unpack .../18-qt6-tools-dev_6.4.2-3build3_amd64.deb ...
# Unpacking qt6-tools-dev:amd64 (6.4.2-3build3) ...
# Setting up libllvm15t64:amd64 (1:15.0.7-14build3) ...
# Setting up libqt6help6:amd64 (6.4.2-3build3) ...
# Setting up qdbus-qt6 (6.4.2-3build3) ...
# Setting up libqt6designer6:amd64 (6.4.2-3build3) ...
# Setting up libqt6quickwidgets6:amd64 (6.4.2+dfsg-4build3) ...
# Setting up ninja-build (1.11.1-2) ...
# Setting up libgumbo2:amd64 (0.12.0+dfsg-2build1) ...
# Setting up libclang1-15t64 (1:15.0.7-14build3) ...
# Setting up libqt6uitools6:amd64 (6.4.2-3build3) ...
# Setting up libclang-cpp15t64 (1:15.0.7-14build3) ...
# Setting up qt6-l10n-tools (6.4.2-3build3) ...
# Setting up liblitehtml0t64:amd64 (0.6-1.2ubuntu2) ...
# Setting up libqt6designercomponents6:amd64 (6.4.2-3build3) ...
# Setting up qt6-documentation-tools (6.4.2-3build3) ...
# Setting up linguist-qt6 (6.4.2-3build3) ...
# Setting up designer-qt6 (6.4.2-3build3) ...
# Setting up assistant-qt6 (6.4.2-3build3) ...
# Setting up qt6-tools-dev-tools (6.4.2-3build3) ...
# Setting up qt6-tools-dev:amd64 (6.4.2-3build3) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.4) ...
# cmake version 3.28.3
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %% [markdown]
# ## Проверка QWT
#
# Проверка наличия заголовочных файлов и библиотек QWT после установки.

# %%
# %%bash
# ls -l /usr/local/qwt-6.4.0-ma/include/qwt_plot.h
# ls -l /usr/local/qwt-6.4.0-ma/lib/libqwt.so
# Out:
# -rw-r--r--. 1 root root 8572 окт 30  2025 /usr/local/qwt-6.4.0-ma/include/qwt_plot.h
# lrwxrwxrwx. 1 root root 15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so -> libqwt.so.6.4.0

# %% [markdown]
# ## Создание симлинков
#
# Создание символических ссылок для совместимости с путями, которые ожидает LISEM.

# %%
# %%bash
# set -euo pipefail
#
# # подложим "старый" путь как ссылки на Qt6-версию
# sudo mkdir -p /usr/local/qwt-6.4.0-ma
# sudo ln -sfn /usr/local/qwt-6.4.0-ma-qt6/include /usr/local/qwt-6.4.0-ma/include
# sudo ln -sfn /usr/local/qwt-6.4.0-ma-qt6/lib     /usr/local/qwt-6.4.0-ma/lib
# sudo ldconfig
#
# # проверим, что по старому пути всё видно
# ls -l /usr/local/qwt-6.4.0-ma/include/qwt_plot.h
# ls -l /usr/local/qwt-6.4.0-ma/lib/libqwt.so || true
# readlink -f /usr/local/qwt-6.4.0-ma/lib/libqwt.so || true
# Out:
# -rw-r--r--. 1 root root 8572 окт 30  2025 /usr/local/qwt-6.4.0-ma/include/qwt_plot.h
# lrwxrwxrwx. 1 root root 15 июн  4 16:12 /usr/local/qwt-6.4.0-ma/lib/libqwt.so -> libqwt.so.6.4.0
# /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4.0

# %% [markdown]
# # Сборка LISEM
#
# Конфигурация и компиляция проекта LISEM с указанием путей к QWT и GDAL.

# %%
# %%bash
# set -euo pipefail
# cd "/home/jovyan/work/LISEM/lisem-bin"
#
# # Re-run CMake configure. We also pass Qwt include/lib and GDAL so it compiles cleanly.
# cmake -S ../lisem -B . -G "Unix Makefiles" \
#   -DCMAKE_BUILD_TYPE=Release \
#   -DCMAKE_PREFIX_PATH="/usr/lib/cmake/Qt6" \
#   -DCMAKE_CXX_FLAGS="-I/usr/local/qwt-6.4.0-ma/include" \
#   -DCMAKE_EXE_LINKER_FLAGS="-L/usr/local/qwt-6.4.0-ma/lib" \
#   -DGDAL_INCLUDE_DIR="/usr/include/gdal" \
#   -DGDAL_LIBRARY="/usr/lib/x86_64-linux-gnu/libgdal.so"
#
# # Build with a safe job count (avoid OOM)
# cmake --build . -j4
# Out:
# -- Could NOT find XKB (missing: XKB_LIBRARY XKB_INCLUDE_DIR) (Required is at least version "0.5.0")
# -- Configuring done (0.3s)
# -- Generating done (1.5s)
# -- Build files have been written to: /home/jovyan/work/LISEM/lisem-bin
# [  0%] Built target Lisem_autogen_timestamp_deps
# [  1%] Built target Lisem_autogen
# [  2%] Linking CXX executable Lisem
# [100%] Built target Lisem

# %% [markdown]
# ## Проверка зависимостей
#
# Проверка динамических библиотек LISEM - поиск связей с QWT, Qt6 и GDAL.

# %%
# !ldd "/home/jovyan/work/LISEM/lisem-bin/Lisem" | egrep 'qwt|Qt6|gdal'
# Out:
# 	libQt6Widgets.so.6 => /lib/x86_64-linux-gnu/libQt6Widgets.so.6 (0x00007fbe89369000)
# 	libQt6Gui.so.6 => /lib/x86_64-linux-gnu/libQt6Gui.so.6 (0x00007fbe88c38000)
# 	libQt6Network.so.6 => /lib/x86_64-linux-gnu/libQt6Network.so.6 (0x00007fbe88aa1000)
# 	libgdal.so.37 => /lib/x86_64-linux-gnu/libgdal.so.37 (0x00007fbe86af9000)
# 	libqwt.so.6.4 => /usr/local/qwt-6.4.0-ma/lib/libqwt.so.6.4 (0x00007fbe8690c000)
# 	libQt6Core.so.6 => /lib/x86_64-linux-gnu/libQt6Core.so.6 (0x00007fbe863fe000)
# 	libQt6DBus.so.6 => /lib/x86_64-linux-gnu/libQt6DBus.so.6 (0x00007fbe85a61000)
# 	libQt6OpenGLWidgets.so.6 => /lib/x86_64-linux-gnu/libQt6OpenGLWidgets.so.6 (0x00007fbe81f31000)
# 	libQt6OpenGL.so.6 => /lib/x86_64-linux-gnu/libQt6OpenGL.so.6 (0x00007fbe81e94000)

# %% [markdown]
# ## Поиск проблемных плагинов
#
# Поиск и удаление GRASS-плагинов GDAL, которые могут вызывать конфликты.

# %%
# %%bash
# set -euo pipefail
#
# # See which GRASS plugin files you have and which package owns them
# ls -l /usr/lib/x86_64-linux-gnu/gdalplugins | grep -i grass || true
# for f in /usr/lib/x86_64-linux-gnu/gdalplugins/*GRASS*.so; do
#   [ -e "$f" ] && echo "$f -> $(dpkg -S "$f")"
# done || true
#
# # Remove the offending package(s) (try both names safely)
# sudo apt-get remove -y gdal-grass || true
# sudo apt-get remove -y libgdal-grass || true
# Out:
# -rw-r--r--. 1 root root 47432 июл 30  2024 gdal_GRASS.so
#  2024 ogr_GRASS.so root 59720 июл 30
# /usr/lib/x86_64-linux-gnu/gdalplugins/gdal_GRASS.so -> libgdal-grass: /usr/lib/x86_64-linux-gnu/gdalplugins/gdal_GRASS.so
# /usr/lib/x86_64-linux-gnu/gdalplugins/ogr_GRASS.so -> libgdal-grass: /usr/lib/x86_64-linux-gnu/gdalplugins/ogr_GRASS.so
# Reading package lists...
# Building dependency tree...
# Reading state information...
# E: Unable to locate package gdal-grass
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following packages were automatically installed and are no longer required:
#   libglapi-mesa libheif-plugin-libde265 libllvm19 libxcb-dri2-0
# them.sudo apt autoremove' to remove
# The following packages will be REMOVED:
#   libgdal-grass
# 0 upgraded, 0 newly installed, 1 to remove and 148 not upgraded.
# pace will be freed.n, 133 kB disk s
# (Reading database ... 78375 files and directories currently installed.)
# Removing libgdal-grass (1:1.0.2-7~noble1) ...

# %% [markdown]
# ## Тестовый запуск LISEM
#
# Пробный запуск приложения на виртуальном сервере для проверки работоспособности (должно вернуть stopped (expected))

# %%
# %%bash
# set -eo pipefail
# APP="/home/jovyan/work/LISEM/lisem-bin/Lisem"
# sudo apt-get -y install xvfb >/dev/null
# XDG_RUNTIME_DIR="$(mktemp -d)"; chmod 700 "$XDG_RUNTIME_DIR"; export XDG_RUNTIME_DIR
# LIBGL_ALWAYS_SOFTWARE=1 timeout 5 xvfb-run -a "$APP" || echo "stopped (expected)"
# Out:
# debconf: delaying package configuration, since apt-utils is not installed
# stopped (expected)

# %% [markdown]
# # Запуск расчета в LISEM
#
# Запуск гидрологической модели LISEM с run-файлом.

# %%
2+2
# Out:
# 4

# %%
# %%bash
# set -euo pipefail
# APP="/home/jovyan/work/LISEM/lisem-bin/Lisem" #путь до бинарника LISEM
# RUNF="/home/jovyan/work/LISEM/runfiles/Gorsch.run" # путь до runfile
#
# # keep locale fixed (decimal dot), and silence GRASS plugin warnings
# export LC_ALL=C.UTF-8 LANG=C.UTF-8 LC_NUMERIC=C.UTF-8 # Всякое форматирование
# export GDAL_SKIP=GRASS OGR_SKIP=GRASS # Отключаются проблемные GRASS-плагины GDAL
# export LIBGL_ALWAYS_SOFTWARE=1 #Включается программная отрисовка OpenGL
# #
# # stream progress to the notebook
# stdbuf -oL "$APP" -ni -r "$RUNF"

# %%
# !pip install GDAL
# Out:
# Requirement already satisfied: GDAL in /opt/venv/lib/python3.12/site-packages (3.9.3)

# %%
os.getcwd()
# Out:
# '/home/jovyan/work/LISEM'

# %%
# !find openlisem_bmi -maxdepth 2 -type f
# Out:
# openlisem_bmi/pyproject.toml
# openlisem_bmi/README.txt
# openlisem_bmi/licence.txt
# openlisem_bmi/swatre/swatinit.cpp
# openlisem_bmi/swatre/swatinp.cpp
# openlisem_bmi/swatre/lookup.cpp
# openlisem_bmi/swatre/lisInfilSwatre.cpp
# openlisem_bmi/swatre/swatstep.cpp
# openlisem_bmi/changes.txt
# openlisem_bmi/ui_full/LisUItreemodel.h
# openlisem_bmi/ui_full/LisUIDefaultNames.cpp
# openlisem_bmi/ui_full/LisUIplot.cpp
# openlisem_bmi/ui_full/lismpeg.h
# openlisem_bmi/ui_full/LisUItreecheck.cpp
# openlisem_bmi/ui_full/LisUImapplot.h
# openlisem_bmi/ui_full/lisemqt.ui
# openlisem_bmi/ui_full/LisUImapplot.cpp
# openlisem_bmi/ui_full/LisUItreeitem.h
# openlisem_bmi/ui_full/LisUIPatch.cpp
# openlisem_bmi/ui_full/LisUIModel.cpp
# openlisem_bmi/ui_full/LisUIdialogs.cpp
# openlisem_bmi/ui_full/lisScreenshot.cpp
# openlisem_bmi/ui_full/LisUImapnames.cpp
# openlisem_bmi/ui_full/mpegdialog.ui
# openlisem_bmi/ui_full/lismpeg.ui
# openlisem_bmi/ui_full/lisemqt.cpp
# openlisem_bmi/ui_full/LisUItreemodel.cpp
# openlisem_bmi/ui_full/lisUIStyle.cpp
# openlisem_bmi/ui_full/LisUIScreenshot.cpp
# openlisem_bmi/ui_full/lismpeg.cpp
# openlisem_bmi/ui_full/lisUIplot2.cpp
# openlisem_bmi/ui_full/LisUItreeitem.cpp
# openlisem_bmi/ui_full/lisemqt.h
# openlisem_bmi/ui_full/LisUIrunfile.cpp
# openlisem_bmi/channel/lisExtendedChannel.cpp
# openlisem_bmi/channel/lisChannelflood.cpp
# openlisem_bmi/channel/lisChannelflow.cpp
# openlisem_bmi/channel/lisChannelAux.cpp
# openlisem_bmi/channel/lisDischargein.cpp
# openlisem_bmi/openLisemN.ico
# openlisem_bmi/README_BMI.md
# openlisem_bmi/maps/CsfRGBMap.cpp
# openlisem_bmi/maps/error.cpp
# openlisem_bmi/maps/operation.cpp
# openlisem_bmi/maps/io.cpp
# openlisem_bmi/maps/fixture.cpp
# openlisem_bmi/maps/CsfMap.cpp
# openlisem_bmi/maps/mmath.cpp
# openlisem_bmi/PCR/kernlcsf.c
# openlisem_bmi/PCR/putsomec.c
# openlisem_bmi/PCR/mclose.c
# openlisem_bmi/PCR/gproj.c
# openlisem_bmi/PCR/swapio.c
# openlisem_bmi/PCR/csfglob.c
# openlisem_bmi/PCR/setvtmv.c
# openlisem_bmi/PCR/dumconv.c
# openlisem_bmi/PCR/create2.c
# openlisem_bmi/PCR/gcellrep.c
# openlisem_bmi/PCR/COPYING
# openlisem_bmi/PCR/ruseas.c
# openlisem_bmi/PCR/setangle.c
# openlisem_bmi/PCR/AUTHORS
# openlisem_bmi/PCR/gvalscal.c
# openlisem_bmi/flow/lisBoundary.cpp
# openlisem_bmi/flow/lisKinematic.cpp
# openlisem_bmi/flow/lisSWOF2DopenMUSCL.cpp
# openlisem_bmi/flow/lisSWOF2Daux.cpp
# openlisem_bmi/flow/lisGWflow.cpp
# openlisem_bmi/flow/lisSWOF2Dopen.cpp
# openlisem_bmi/flow/lisKinematicSWMM.cpp
# openlisem_bmi/flow/lisTiledrainflow.cpp
# openlisem_bmi/flow/lisFlowBarriers.cpp
# openlisem_bmi/flow/lisOverlandflow.cpp
# openlisem_bmi/flow/lisRouting.cpp
# openlisem_bmi/resources/openlisem.qrc
# openlisem_bmi/resources/help7.html
# openlisem_bmi/resources/advanced.png
# openlisem_bmi/resources/settings1.png
# openlisem_bmi/resources/help3.html
# openlisem_bmi/resources/new1.qss
# openlisem_bmi/resources/river2.png
# openlisem_bmi/resources/soil6.png
# openlisem_bmi/resources/d_soil5.png
# openlisem_bmi/resources/help10.html
# openlisem_bmi/resources/rain.png
# openlisem_bmi/resources/openlisem.qss
# openlisem_bmi/resources/d_water.png
# openlisem_bmi/resources/d_river2.png
# openlisem_bmi/resources/d_advanced.png
# openlisem_bmi/resources/d_Plant-icon.png
# openlisem_bmi/resources/d_eros1bw.png
# openlisem_bmi/resources/openLisemN.ico
# openlisem_bmi/resources/map.jpg
# openlisem_bmi/resources/bullet.png
# openlisem_bmi/resources/river3.png
# openlisem_bmi/resources/river4.png
# openlisem_bmi/resources/openlisem.psd
# openlisem_bmi/resources/water1.png
# openlisem_bmi/resources/soil3bwa.png
# openlisem_bmi/resources/d_water1.png
# openlisem_bmi/resources/help6.html
# openlisem_bmi/resources/question-mark-button.png
# openlisem_bmi/resources/pagefold.qss
# openlisem_bmi/resources/black-and-white.png
# openlisem_bmi/resources/d_river3.png
# openlisem_bmi/resources/help2.html
# openlisem_bmi/resources/d_settings2.png
# openlisem_bmi/resources/d_water2.png
# openlisem_bmi/resources/Plant-icon.png
# openlisem_bmi/resources/default.qss
# openlisem_bmi/resources/settings.png
# openlisem_bmi/resources/house.png
# openlisem_bmi/resources/help8.html
# openlisem_bmi/resources/d_settings1.png
# openlisem_bmi/resources/soil4.png
# openlisem_bmi/resources/help4.html
# openlisem_bmi/resources/openLisemN.bmp
# openlisem_bmi/resources/ITC logo.png
# openlisem_bmi/resources/d_black-and-white.png
# openlisem_bmi/resources/openLisemN.png
# openlisem_bmi/resources/water2.png
# openlisem_bmi/resources/soil5.png
# openlisem_bmi/resources/d_soil6.png
# openlisem_bmi/resources/coffee.qss
# openlisem_bmi/resources/help5.html
# openlisem_bmi/resources/water.png
# openlisem_bmi/resources/eros1bw.png
# openlisem_bmi/resources/help1.html
# openlisem_bmi/resources/map.png
# openlisem_bmi/resources/d_rain.png
# openlisem_bmi/resources/settings2.png
# openlisem_bmi/resources/help9.html
# openlisem_bmi/CMakeLists.txt
# openlisem_bmi/tests/test_bmi_openlisem.py
# openlisem_bmi/tests/__init__.py
# openlisem_bmi/bmi_openlisem/map_io.py
# openlisem_bmi/bmi_openlisem/bmi_openlisem.py
# openlisem_bmi/bmi_openlisem/__init__.py
# openlisem_bmi/bmi_openlisem/config_manager.py
# openlisem_bmi/bmi_openlisem/cli.py
# openlisem_bmi/AUTHORS
# openlisem_bmi/cmake/DoxygenDoc.cmake
# openlisem_bmi/doxygen/CMakeLists.txt
# openlisem_bmi/doxygen/Doxyfile.in
# openlisem_bmi/doxygen/openlisem.main
# openlisem_bmi/erosion/lisErosion.cpp
# openlisem_bmi/erosion/lisErosionSplash.cpp
# openlisem_bmi/erosion/lisChannelErosion.cpp
# openlisem_bmi/erosion/lisErosionAux.cpp
# openlisem_bmi/erosion/lisSWOF2DSediment.cpp
# openlisem_bmi/include/lerror.h
# openlisem_bmi/include/model.h
# openlisem_bmi/include/CsfMap.h
# openlisem_bmi/include/csf.h
# openlisem_bmi/include/raster.h
# openlisem_bmi/include/option.h
# openlisem_bmi/include/CsfRGBMap.h
# openlisem_bmi/include/PrecisionConfig.h
# openlisem_bmi/include/TMmapVariables.h
# openlisem_bmi/include/csfattr.h
# openlisem_bmi/include/array.h
# openlisem_bmi/include/fixture.h
# openlisem_bmi/include/swatre_p.h
# openlisem_bmi/include/csftypes.h
# openlisem_bmi/include/csfimpl.h
# openlisem_bmi/include/mmath.h
# openlisem_bmi/include/LisUIoutput.h
# openlisem_bmi/include/operation.h
# openlisem_bmi/include/version.h
# openlisem_bmi/include/masked_raster.h
# openlisem_bmi/include/pcrtypes.h
# openlisem_bmi/include/io.h
# openlisem_bmi/include/global.h
# openlisem_bmi/hardmain.cmd
# openlisem_bmi/.git/packed-refs
# openlisem_bmi/.git/config
# openlisem_bmi/.git/HEAD
# openlisem_bmi/.git/description
# openlisem_bmi/.git/index
# openlisem_bmi/hydro/lisPercolation.cpp
# openlisem_bmi/hydro/lisSurfstor.cpp
# openlisem_bmi/hydro/lisInterception.cpp
# openlisem_bmi/hydro/lisInfiltration.cpp
# openlisem_bmi/hydro/lisSoilmoisture.cpp
# openlisem_bmi/compile_lisem_windows.txt
# openlisem_bmi/.gitignore
# openlisem_bmi/model/lisDisplayMaps.cpp
# openlisem_bmi/model/lisTotalsMB.cpp
# openlisem_bmi/model/lisReportmaps.cpp
# openlisem_bmi/model/lisReportfile.cpp
# openlisem_bmi/model/lisRunfile.cpp
# openlisem_bmi/model/main.cpp
# openlisem_bmi/model/lisModel.cpp
# openlisem_bmi/model/lisDataFunctions.cpp
# openlisem_bmi/model/lisDataInit.cpp
# openlisem_bmi/openlisemico.rc
# openlisem_bmi/bmi_openlisem.egg-info/dependency_links.txt
# openlisem_bmi/bmi_openlisem.egg-info/top_level.txt
# openlisem_bmi/bmi_openlisem.egg-info/requires.txt
# openlisem_bmi/bmi_openlisem.egg-info/entry_points.txt
# openlisem_bmi/bmi_openlisem.egg-info/SOURCES.txt
# openlisem_bmi/bmi_openlisem.egg-info/PKG-INFO
# openlisem_bmi/auxfiles/vanrijn.xlsx
# openlisem_bmi/auxfiles/green and ampt 2015.pdf
# openlisem_bmi/auxfiles/swatreprecision.xlsx
# openlisem_bmi/auxfiles/flux limiter.xlsx
# openlisem_bmi/auxfiles/channel overflow.xlsx
# openlisem_bmi/auxfiles/GetImerg.py
# openlisem_bmi/auxfiles/Final Equations for WEB Page-10-05_OMDens_VJ.xlsx
# openlisem_bmi/auxfiles/precisionswatre.xlsx
# openlisem_bmi/auxfiles/infilksat2layer.xlsx
# openlisem_bmi/auxfiles/tcvanrijn.xlsx
# openlisem_bmi/auxfiles/Final Equations for WEB Page-10-05.xls
# openlisem_bmi/auxfiles/SOAPSOIL.PAS
# openlisem_bmi/auxfiles/ganspoel.7z
# openlisem_bmi/auxfiles/cukvertN.xlsx
# openlisem_bmi/auxfiles/coh.xlsx
# openlisem_bmi/auxfiles/aggrstab.xlsx
# openlisem_bmi/auxfiles/roughnessperim.xlsx
# openlisem_bmi/auxfiles/GSSHApedotransfer.xlsx
# openlisem_bmi/auxfiles/eurosem user_v2.pdf
# openlisem_bmi/auxfiles/saxton2006.pdf
# openlisem_bmi/auxfiles/textured50.xlsx
# openlisem_bmi/auxfiles/alphachannel.xlsx
# openlisem_bmi/auxfiles/coh_engineering.xlsx
# openlisem_bmi/hard.cmd
# openlisem_bmi/examples/bmi_example.py
# openlisem_bmi/examples/coupling_example.py
# openlisem_bmi/INSTALL
# openlisem_bmi/openLisemN.bmp
# openlisem_bmi/COPYRIGHT
# openlisem_bmi/pest/lisPesticide.cpp
# openlisem_bmi/GPL-v3.0.txt
# openlisem_bmi/meteo/lisEvaporation.cpp
# openlisem_bmi/meteo/lisRainfall.cpp
# openlisem_bmi/meteo/lisSnowmelt.cpp
# openlisem_bmi/docs/surface roughness.xlsx
# openlisem_bmi/docs/90 mm huidig.pdf
# openlisem_bmi/docs/gwflow swat.pdf
# openlisem_bmi/docs/Fig. 1.1 - OpenLISEM modelling scheme.pdf
# openlisem_bmi/docs/floodchannel.xlsx
# openlisem_bmi/docs/d50texture.xlsx
# openlisem_bmi/docs/avgh.txt
# openlisem_bmi/docs/A brief guide to openLISEM 140109.docx
# openlisem_bmi/docs/brooks corey.xlsx
# openlisem_bmi/docs/Partially Full Pipe Flow Calculations.pdf
# openlisem_bmi/docs/morel seytoux.xlsx
# openlisem_bmi/docs/A brief guide to openLISEM 140702.docx
# openlisem_bmi/docs/short lisem description.docx
# openlisem_bmi/docs/LISEM INPUT.docx
# openlisem_bmi/docs/pipeflow.xlsx
# openlisem_bmi/docs/flodoing description.docx
# openlisem_bmi/docs/interception.xlsx
# openlisem_bmi/ReleaseVersion.txt
# openlisem_bmi/.gitattributes
# openlisem_bmi/compile_lisem_linux.txt
# openlisem_bmi/Application.cmake
# openlisem_bmi/openLisem.ico

# %%
# !mkdir -p openlisem-bmi-package

# %% [markdown]
# # Визуализация результатов

# %%
import os
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm, ListedColormap

resdir = "/home/jovyan/work/LISEM/results/"
fnames = ["soilloss.map"]

def open_map(path):
    ds = gdal.Open(path, gdal.GA_ReadOnly)
    arr = ds.GetRasterBand(1).ReadAsArray()
    ndv = ds.GetRasterBand(1).GetNoDataValue()
    if ndv is not None:
        arr = np.ma.masked_equal(arr, ndv)
    return arr

# интервалы как в QGIS
bounds = [-9999, -10, 0, 2.5, 5, 7.5, 10, 15, 20, 9999]  
labels = [
    ">10",
    "0–10",
    "0–2.5",
    "2.5–5",
    "5–7.5",
    "7.5–10",
    "10–15",
    "15–20",
    ">20 аккумуляция"
]

# подбираем цвета (из QGIS скрина)
colors = [
    "#08306b",  # >10 аккумуляция (синий)
    "#7fcdbb",  # 0-10 аккумуляция (зелёный)
    "#f7fcb9",  # 0-2.5 (светло-жёлтый)
    "#fee08b",  # 2.5-5
    "#fdae61",  # 5-7.5
    "#f46d43",  # 7.5-10
    "#d73027",  # 10-15
    "#a50026",  # 15-20
    "#67001f"   # >20
]

cmap = ListedColormap(colors)
norm = BoundaryNorm(bounds, len(colors))

for fname in fnames:
    path = os.path.join(resdir, fname)
    if not os.path.exists(path):
        print(f"Missing: {path}")
        continue

    arr = open_map(path)
    if arr is None:
        continue

    plt.figure(figsize=(12, 10))
    im = plt.imshow(arr, cmap=cmap, norm=norm, origin="upper")
    cbar = plt.colorbar(im, shrink=0.8, ticks=[-5, 0, 1, 3.5, 6.25, 8.75, 12.5, 17.5, 25])
    cbar.ax.set_yticklabels(labels)
    plt.title(fname)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## skip BMI

# %%
# !git clone --branch claude/bmi-Opus https://github.com/pihchikk/openlisem_bmi.git
# Out:
# fatal: destination path 'openlisem_bmi' already exists and is not an empty directory.

# %%
import os
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm, ListedColormap

import ipywidgets as widgets
from IPython.display import display, clear_output

# =========================
# 1. Load map as before
# =========================
resdir = "/home/jovyan/work/LISEM/results/"
fname = "soilloss.map"

def open_map(path):
    ds = gdal.Open(path, gdal.GA_ReadOnly)
    arr = ds.GetRasterBand(1).ReadAsArray()
    ndv = ds.GetRasterBand(1).GetNoDataValue()
    if ndv is not None:
        arr = np.ma.masked_equal(arr, ndv)
    return arr

bounds = [-9999, -10, 0, 2.5, 5, 7.5, 10, 15, 20, 9999]
labels = [
    ">10", "0–10", "0–2.5", "2.5–5", "5–7.5",
    "7.5–10", "10–15", "15–20", ">20 аккумуляция"
]

colors = [
    "#08306b", "#7fcdbb", "#f7fcb9", "#fee08b",
    "#fdae61", "#f46d43", "#d73027", "#a50026", "#67001f"
]

cmap = ListedColormap(colors)
norm = BoundaryNorm(bounds, len(colors))

path = os.path.join(resdir, fname)
if not os.path.exists(path):
    raise FileNotFoundError(f"Missing: {path}")

arr = open_map(path)
if isinstance(arr, np.ma.MaskedArray):
    mask = arr.mask
    target_map = arr.filled(0.0).astype(float)
else:
    mask = None
    target_map = arr.astype(float)

ny, nx = target_map.shape

# =========================
# 2. Assume *annual* rainfall used by LISEM
#    If unknown, set to typical ~1000 mm/year
# =========================
ANNUAL_RAIN_MM = 1000.0  # you can change to actual value

# =========================
# 3. Simulation state
# =========================
state = {
    "target": target_map,
    "current_map": np.zeros_like(target_map),
    "current_step": 0,
    "n_steps": 52,
    "cumulative_rain_mm": 0.0
}

# =========================
# 4. Widgets
# =========================
rain_slider = widgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=100.0,
    step=1.0,
    description="Осадков (мм/неделю):",
    continuous_update=False,
    layout=widgets.Layout(width="400px")
)

step_button = widgets.Button(
    description="▶ Step",
    button_style="success",
    layout=widgets.Layout(width="120px")
)

step10_button = widgets.Button(
    description="▶▶ +10",
    button_style="info",
    layout=widgets.Layout(width="120px")
)

reset_button = widgets.Button(
    description="🔄 Reset",
    button_style="warning",
    layout=widgets.Layout(width="120px")
)

info_label = widgets.HTML(
    value="<b>Неделя:</b> 0 | <b>Осадков всего:</b> 0 mm"
)

output_area = widgets.Output()

# =========================
# 5. Plotting
# =========================
def update_plot():
    with output_area:
        clear_output(wait=True)

        img = state["current_map"]
        if mask is not None:
            img = np.ma.array(img, mask=mask)

        fig, ax = plt.subplots(figsize=(8, 8))
        im = ax.imshow(img, cmap=cmap, norm=norm)
        ax.axis("off")
        ax.set_title(
            f"Soilloss simulation – week {state['current_step']} / {state['n_steps']}"
        )

        # Clean right-side colorbar
        cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_ticks([-5, 0, 1, 3.5, 6.25, 8.75, 12.5, 17.5, 25])
        cbar.ax.set_yticklabels(labels)

        plt.tight_layout()
        plt.show()

# =========================
# 6. Step logic
# =========================
def do_step():
    if state["current_step"] >= state["n_steps"]:
        print("Конец симуляции за год.")
        return

    rain_mm = rain_slider.value
    state["cumulative_rain_mm"] += rain_mm

    # Add erosion proportional to rainfall fraction
    rain_fraction = rain_mm / ANNUAL_RAIN_MM
    state["current_map"] += rain_fraction * state["target"]

    # Advance model time
    state["current_step"] += 1

    # Optional: reset slider after an event
    rain_slider.value = 0.0

    info_label.value = (
        f"<b>Week:</b> {state['current_step']} / {state['n_steps']} | "
        f"<b>Total rain:</b> {state['cumulative_rain_mm']:.1f} mm"
    )

    update_plot()


def do_step10():
    for _ in range(10):
        do_step()
        if state["current_step"] >= state["n_steps"]:
            break


def do_reset(_=None):
    state["current_map"][:] = 0.0
    state["current_step"] = 0
    state["cumulative_rain_mm"] = 0.0
    rain_slider.value = 0.0
    info_label.value = "<b>Неделя:</b> 0 | <b>Осадков всего:</b> 0 mm"
    update_plot()

# =========================
# 7. Wire controls
# =========================
step_button.on_click(lambda b: do_step())
step10_button.on_click(lambda b: do_step10())
reset_button.on_click(do_reset)

# =========================
# 8. Display UI
# =========================
do_reset()

controls = widgets.VBox([
    widgets.HTML("<h3>🌧 LISEM bmi виджет</h3>"),
    rain_slider,
    widgets.HBox([step_button, step10_button, reset_button]),
    info_label
])

display(controls)
display(output_area)
# Out:
# VBox(children=(HTML(value='<h3>🌧 LISEM bmi виджет</h3>'), FloatSlider(value=0.0, continuous_update=False, desc…
# Output()

# %%
import os
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm, ListedColormap

import ipywidgets as widgets
from IPython.display import display, clear_output


папка_результатов = "/home/jovyan/work/LISEM/results/"
имя_файла = "soilloss.map"

def открыть_карту(path):
    ds = gdal.Open(path, gdal.GA_ReadOnly)
    arr = ds.GetRasterBand(1).ReadAsArray()
    ndv = ds.GetRasterBand(1).GetNoDataValue()
    if ndv is not None:
        arr = np.ma.masked_equal(arr, ndv)
    return arr

границы = [-9999, -10, 0, 2.5, 5, 7.5, 10, 15, 20, 9999]
ярлыки = [
    "денудация, >10", "0–10", "0–2.5", "2.5–5", "5–7.5",
    "7.5–10", "10–15", "15–20", ">20 аккумуляция"
]

цвета = [
    "#08306b", "#7fcdbb", "#f7fcb9", "#fee08b",
    "#fdae61", "#f46d43", "#d73027", "#a50026", "#67001f"
]

карта_цветов = ListedColormap(цвета)
норма = BoundaryNorm(границы, len(цвета))

путь = os.path.join(папка_результатов, имя_файла)
if not os.path.exists(путь):
    raise FileNotFoundError(f"Файл не найден: {путь}")

arr = открыть_карту(путь)
if isinstance(arr, np.ma.MaskedArray):
    маска = arr.mask
    конечная_карта = arr.filled(0.0).astype(float)
else:
    маска = None
    конечная_карта = arr.astype(float)

ny, nx = конечная_карта.shape


ГОДОВОЙ_ОСАДОК_ММ = 1000.0         # мм/год
ФОНОВАЯ_ЭРОЗИЯ_ММ_В_НЕДЕЛЮ = 0.5   # эквивалент очень слабой эрозии


состояние = {
    "цель": конечная_карта,
    "текущая_карта": np.zeros_like(конечная_карта),
    "неделя": 0,
    "всего_недель": 52,
    "накопленные_осадки_мм": 0.0
}


слайдер_осадки = widgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=100.0,
    step=1.0,
    description="Осадки (мм/нед):",
    continuous_update=False,
    layout=widgets.Layout(width="400px")
)

кнопка_шаг = widgets.Button(
    description="▶ Шаг",
    button_style="success",
    layout=widgets.Layout(width="120px")
)

кнопка_шаг10 = widgets.Button(
    description="▶▶ +10",
    button_style="info",
    layout=widgets.Layout(width="120px")
)

кнопка_сброс = widgets.Button(
    description="🔄 Сброс",
    button_style="warning",
    layout=widgets.Layout(width="120px")
)

метка_инфо = widgets.HTML(
    value="<b>Неделя:</b> 0 | <b>Осадков всего:</b> 0 мм"
)

область_вывода = widgets.Output()


def обновить_график():
    with область_вывода:
        clear_output(wait=True)

        img = состояние["текущая_карта"]
        if маска is not None:
            img = np.ma.array(img, mask=маска)

        fig, ax = plt.subplots(figsize=(8, 8))
        im = ax.imshow(img, cmap=карта_цветов, norm=норма)
        ax.axis("off")
        ax.set_title(
            f"Модель эрозии – неделя {состояние['неделя']} / {состояние['всего_недель']}"
        )

        cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_ticks([-5, 0, 1, 3.5, 6.25, 8.75, 12.5, 17.5, 25])
        cbar.ax.set_yticklabels(ярлыки)

        plt.tight_layout()
        plt.show()


def сделать_шаг():
    if состояние["неделя"] >= состояние["всего_недель"]:
        print("✔ Симуляция завершена (52 недели).")
        return

    осадки = float(слайдер_осадки.value)

    состояние["накопленные_осадки_мм"] += осадки

    if осадки == 0:
        эффективные_осадки = ФОНОВАЯ_ЭРОЗИЯ_ММ_В_НЕДЕЛЮ
    else:
        эффективные_осадки = осадки

    доля_осадков = эффективные_осадки / ГОДОВОЙ_ОСАДОК_ММ
    состояние["текущая_карта"] += доля_осадков * состояние["цель"]

    состояние["неделя"] += 1

    слайдер_осадки.value = 0.0

    метка_инфо.value = (
        f"<b>Неделя:</b> {состояние['неделя']} / {состояние['всего_недель']} | "
        f"<b>Осадков всего:</b> {состояние['накопленные_осадки_мм']:.1f} мм "
        f"(фоновая эрозия работает при 0 мм)"
    )

    обновить_график()


def сделать_шаг10():
    for _ in range(10):
        сделать_шаг()
        if состояние["неделя"] >= состояние["всего_недель"]:
            break


def сброс(_=None):
    состояние["текущая_карта"][:] = 0.0
    состояние["неделя"] = 0
    состояние["накопленные_осадки_мм"] = 0.0
    слайдер_осадки.value = 0.0
    метка_инфо.value = "<b>Неделя:</b> 0 | <b>Осадков всего:</b> 0 мм"
    обновить_график()

# =========================
# 7. Привязка событий
# =========================
кнопка_шаг.on_click(lambda b: сделать_шаг())
кнопка_шаг10.on_click(lambda b: сделать_шаг10())
кнопка_сброс.on_click(сброс)

# =========================
# 8. Отображение интерфейса
# =========================
сброс()

интерфейс = widgets.VBox([
    widgets.HTML("<h3>Модель эрозии LISEM</h3>"),
    слайдер_осадки,
    widgets.HBox([кнопка_шаг, кнопка_шаг10, кнопка_сброс]),
    метка_инфо
])

display(интерфейс)
display(область_вывода)
# Out:
# VBox(children=(HTML(value='<h3>Модель эрозии LISEM</h3>'), FloatSlider(value=0.0, continuous_update=False, des…
# Output()

# %%
if общая_маска is not None:
    transport_masked = np.ma.array(transport_plus, mask=общая_маска)
    комбинированная_masked = np.ma.array(комбинированная, mask=общая_маска)
else:
    transport_masked = transport_plus
    комбинированная_masked = комбинированная

fig = plt.figure(figsize=(18, 8))

gs = gridspec.GridSpec(
    1, 3,
    width_ratios=[1, 1, 0.06],  
    wspace=0.05
)

ax_left = fig.add_subplot(gs[0, 0])
ax_right = fig.add_subplot(gs[0, 1])
ax_cbar = fig.add_subplot(gs[0, 2])

im1 = ax_left.imshow(transport_masked, cmap=карта_цветов, norm=норма)
ax_left.set_title("WaTEM-SEDEM")
ax_left.axis("off")

im2 = ax_right.imshow(комбинированная_masked, cmap=карта_цветов, norm=норма)
ax_right.set_title("WaTEM-SEDEM, ktc взят по расчетам LISEM")
ax_right.axis("off")

cbar = fig.colorbar(im2, cax=ax_cbar)
cbar.set_ticks([-5, 0, 1, 3.5, 6.25, 8.75, 12.5, 17.5, 25])
cbar.ax.set_yticklabels(ярлыки)

plt.tight_layout()
plt.show()

# %%
import os
import subprocess

# Установить путь к LISEM
os.environ['OPENLISEM_EXECUTABLE'] = '/home/jovyan/work/LISEM/lisem-bin/Lisem'

# Запустить LISEM
lisem_path = os.environ['OPENLISEM_EXECUTABLE']
subprocess.run([lisem_path, 'config.yaml'])
# Out:
# syntax:
# lisem [-ni] [-f] -r runfile
# -f = create the result directory it does not exist.
# -ni = no graphical user interface, uses runfile directly.
# -r runfile = Give the full path tot he runfile.
#
# -calH 1;1;1;1;1;1;1 = 7 calibration factors for hydrology, seperated by ;. Look in the interface to see the factors-calF 1;1;1;1;1 = 5 calibration factors for flow, seperated by ;. Look in the interface to see the factors-calE 1;1;1;1;1 = 5 calibration factors for erosion, seperated by ;. Look in the interface to see the factors
# CompletedProcess(args=['/home/jovyan/work/LISEM/lisem-bin/Lisem', 'config.yaml'], returncode=0)

# %%
from bmi_openlisem import BmiOpenLisem

model = BmiOpenLisem()
model.initialize("/home/jovyan/work/LISEM/inputfiles/VNIIMZ_20m/maps/probnik_20m.run")

# %%
while model.get_current_time() < model.get_end_time():
    model.update()
    print(model.get_current_time())

model.finalize()

# %%
print("start:", model.get_start_time())
print("end:", model.get_end_time())
print("dt:", model.get_time_step())
print("n_steps ~", (model.get_end_time() - model.get_start_time()) / model.get_time_step())
# Out:
# start: 0.0
# end: 43200.0
# dt: 120.0
# n_steps ~ 360.0

# %%
import time

t0 = time.time()
model.update()
t1 = time.time()
print("One update took", t1 - t0, "seconds")
print("Current time:", model.get_current_time())

# %% [markdown]
# # WATEM-SEDEM

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/work/LISEM'

# %%
# !git clone https://github.com/pihchikk/WaTEM-SEDEM-python
# Out:
# Cloning into 'WaTEM-SEDEM-python'...
# remote: Enumerating objects: 242, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 242 (delta 50), reused 22 (delta 22), pack-reused 164 (from 2)
# Receiving objects: 100% (242/242), 619.43 KiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# Updating files: 100% (84/84), done.

# %%
# !sudo apt-get update && sudo apt-get install -y libgdal34 gdal-bin
# Out:
# Get:1 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:2 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1 183 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease [17,8 kB]
# Get:5 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [33,1 kB]
# Get:6 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [2 898 kB]
# Get:7 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble InRelease [24,4 kB]
# Get:8 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [1 752 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble/main amd64 Packages [39,8 kB]
# Get:10 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 Packages [63,8 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease [3 631 B]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:13 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ Packages [44,1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/main amd64 Packages [1 808 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [331 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/restricted amd64 Packages [117 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/universe amd64 Packages [19,3 MB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2 130 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [3 059 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1 950 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [35,9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Packages [49,5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [34,6 kB]
# Ign:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Ign:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Ign:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Err:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
#   Could not connect to developer.download.nvidia.com:443 (92.123.135.95), connection timed out Could not connect to developer.download.nvidia.com:443 (92.123.135.77), connection timed out
# Fetched 35,5 MB in 38s (946 kB/s)
# Reading package lists... Done
# W: Failed to fetch https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease  Could not connect to developer.download.nvidia.com:443 (92.123.135.95), connection timed out Could not connect to developer.download.nvidia.com:443 (92.123.135.77), connection timed out
# W: Some index files failed to download. They have been ignored, or old ones used instead.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libgdal34t64' instead of 'libgdal34'
# The following additional packages will be installed:
#   gdal-data gdal-plugins libabsl20220623t64 libarchive13t64 libavif16
#   libdav1d7 libgav1-1 libgdal37 libhdf4-0 libhwy1t64 libjxl0.7 libmuparser2v5
#   librav1e0 libsvtav1enc1d1 libyuv0 proj-bin python3-gdal
# Suggested packages:
#   lrzip libhdf4-doc libhdf4-dev hdf4-tools
# The following NEW packages will be installed:
#   gdal-bin libabsl20220623t64 libarchive13t64 libavif16 libdav1d7 libgav1-1
#   libgdal34t64 libgdal37 libhdf4-0 libhwy1t64 libjxl0.7 libmuparser2v5
#   librav1e0 libsvtav1enc1d1 libyuv0 proj-bin python3-gdal
# The following packages will be upgraded:
#   gdal-data gdal-plugins
# 2 upgraded, 17 newly installed, 0 to remove and 144 not upgraded.
# Need to get 28,9 MB of archives.
# After this operation, 93,0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libarchive13t64 amd64 3.7.2-2ubuntu0.5 [382 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdav1d7 amd64 1.4.1-1build1 [604 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libabsl20220623t64 amd64 20220623.1-3.1ubuntu3.2 [423 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/universe amd64 libgav1-1 amd64 0.18.0-1build3 [357 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble/universe amd64 librav1e0 amd64 0.7.1-2 [1 022 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsvtav1enc1d1 amd64 1.7.0+dfsg-2build1 [2 425 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/universe amd64 libyuv0 amd64 0.0~git202401110.af6ac82-1 [178 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavif16 amd64 1.0.4-1ubuntu3 [91,2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhdf4-0 amd64 4.2.16-4build1 [324 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble/universe amd64 libhwy1t64 amd64 1.0.7-8.1build1 [584 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libjxl0.7 amd64 0.7.0-10.2ubuntu6.1 [1 001 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-data all 3.11.4+dfsg-1~noble0 [444 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmuparser2v5 amd64 2.3.3-0.1build1 [137 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/universe amd64 libgdal34t64 amd64 3.8.4+dfsg-3ubuntu3 [8 346 kB]
# Get:15 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-plugins amd64 3.11.4+dfsg-1~noble0 [196 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 libgdal37 amd64 3.11.4+dfsg-1~noble0 [10,3 MB]
# Get:17 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 python3-gdal amd64 3.11.4+dfsg-1~noble0 [1 063 kB]
# Get:18 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 gdal-bin amd64 3.11.4+dfsg-1~noble0 [826 kB]
# Get:19 https://ppa.launchpadcontent.net/ubuntugis/ubuntugis-unstable/ubuntu noble/main amd64 proj-bin amd64 9.4.1-1~noble0 [202 kB]
# Fetched 28,9 MB in 12s (2 449 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# (Reading database ... 38814 files and directories currently installed.)
# Preparing to unpack .../00-gdal-data_3.11.4+dfsg-1~noble0_all.deb ...
# Unpacking gdal-data (3.11.4+dfsg-1~noble0) over (3.9.3+dfsg-1~noble0) ...
# Preparing to unpack .../01-gdal-plugins_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking gdal-plugins:amd64 (3.11.4+dfsg-1~noble0) over (3.9.3+dfsg-1~noble0) ...
# Selecting previously unselected package libarchive13t64:amd64.
# Preparing to unpack .../02-libarchive13t64_3.7.2-2ubuntu0.5_amd64.deb ...
# Unpacking libarchive13t64:amd64 (3.7.2-2ubuntu0.5) ...
# Selecting previously unselected package libdav1d7:amd64.
# Preparing to unpack .../03-libdav1d7_1.4.1-1build1_amd64.deb ...
# Unpacking libdav1d7:amd64 (1.4.1-1build1) ...
# Selecting previously unselected package libabsl20220623t64:amd64.
# Preparing to unpack .../04-libabsl20220623t64_20220623.1-3.1ubuntu3.2_amd64.deb ...
# Unpacking libabsl20220623t64:amd64 (20220623.1-3.1ubuntu3.2) ...
# Selecting previously unselected package libgav1-1:amd64.
# Preparing to unpack .../05-libgav1-1_0.18.0-1build3_amd64.deb ...
# Unpacking libgav1-1:amd64 (0.18.0-1build3) ...
# Selecting previously unselected package librav1e0:amd64.
# Preparing to unpack .../06-librav1e0_0.7.1-2_amd64.deb ...
# Unpacking librav1e0:amd64 (0.7.1-2) ...
# Selecting previously unselected package libsvtav1enc1d1:amd64.
# Preparing to unpack .../07-libsvtav1enc1d1_1.7.0+dfsg-2build1_amd64.deb ...
# Unpacking libsvtav1enc1d1:amd64 (1.7.0+dfsg-2build1) ...
# Selecting previously unselected package libyuv0:amd64.
# Preparing to unpack .../08-libyuv0_0.0~git202401110.af6ac82-1_amd64.deb ...
# Unpacking libyuv0:amd64 (0.0~git202401110.af6ac82-1) ...
# Selecting previously unselected package libavif16:amd64.
# Preparing to unpack .../09-libavif16_1.0.4-1ubuntu3_amd64.deb ...
# Unpacking libavif16:amd64 (1.0.4-1ubuntu3) ...
# Selecting previously unselected package libhdf4-0:amd64.
# Preparing to unpack .../10-libhdf4-0_4.2.16-4build1_amd64.deb ...
# Unpacking libhdf4-0:amd64 (4.2.16-4build1) ...
# Selecting previously unselected package libhwy1t64:amd64.
# Preparing to unpack .../11-libhwy1t64_1.0.7-8.1build1_amd64.deb ...
# Unpacking libhwy1t64:amd64 (1.0.7-8.1build1) ...
# Selecting previously unselected package libjxl0.7:amd64.
# Preparing to unpack .../12-libjxl0.7_0.7.0-10.2ubuntu6.1_amd64.deb ...
# Unpacking libjxl0.7:amd64 (0.7.0-10.2ubuntu6.1) ...
# Selecting previously unselected package libmuparser2v5:amd64.
# Preparing to unpack .../13-libmuparser2v5_2.3.3-0.1build1_amd64.deb ...
# Unpacking libmuparser2v5:amd64 (2.3.3-0.1build1) ...
# Selecting previously unselected package libgdal37:amd64.
# Preparing to unpack .../14-libgdal37_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking libgdal37:amd64 (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package python3-gdal.
# Preparing to unpack .../15-python3-gdal_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking python3-gdal (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package gdal-bin.
# Preparing to unpack .../16-gdal-bin_3.11.4+dfsg-1~noble0_amd64.deb ...
# Unpacking gdal-bin (3.11.4+dfsg-1~noble0) ...
# Selecting previously unselected package libgdal34t64:amd64.
# Preparing to unpack .../17-libgdal34t64_3.8.4+dfsg-3ubuntu3_amd64.deb ...
# Unpacking libgdal34t64:amd64 (3.8.4+dfsg-3ubuntu3) ...
# Selecting previously unselected package proj-bin.
# Preparing to unpack .../18-proj-bin_9.4.1-1~noble0_amd64.deb ...
# Unpacking proj-bin (9.4.1-1~noble0) ...
# Setting up libhwy1t64:amd64 (1.0.7-8.1build1) ...
# Setting up proj-bin (9.4.1-1~noble0) ...
# Setting up libsvtav1enc1d1:amd64 (1.7.0+dfsg-2build1) ...
# Setting up libhdf4-0:amd64 (4.2.16-4build1) ...
# Setting up librav1e0:amd64 (0.7.1-2) ...
# Setting up gdal-data (3.11.4+dfsg-1~noble0) ...
# Setting up libjxl0.7:amd64 (0.7.0-10.2ubuntu6.1) ...
# Setting up libdav1d7:amd64 (1.4.1-1build1) ...
# Setting up libabsl20220623t64:amd64 (20220623.1-3.1ubuntu3.2) ...
# Setting up libmuparser2v5:amd64 (2.3.3-0.1build1) ...
# Setting up libyuv0:amd64 (0.0~git202401110.af6ac82-1) ...
# Setting up libarchive13t64:amd64 (3.7.2-2ubuntu0.5) ...
# Setting up gdal-plugins:amd64 (3.11.4+dfsg-1~noble0) ...
# Setting up libgdal34t64:amd64 (3.8.4+dfsg-3ubuntu3) ...
# Setting up libgav1-1:amd64 (0.18.0-1build3) ...
# Setting up libavif16:amd64 (1.0.4-1ubuntu3) ...
# Setting up libgdal37:amd64 (3.11.4+dfsg-1~noble0) ...
# Setting up python3-gdal (3.11.4+dfsg-1~noble0) ...
# Setting up gdal-bin (3.11.4+dfsg-1~noble0) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.4) ...

# %%
os.chdir("WaTEM-SEDEM-python")

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.23 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: PyYAML>=6.0 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (6.0.2)
# Collecting pydantic>=2.0 (from -r requirements.txt (line 3))
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: rasterio>=1.3 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: affine>=2.4 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: matplotlib>=3.4 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.10.0)
# Collecting brokenaxes>=0.6 (from -r requirements.txt (line 7))
#   Downloading brokenaxes-0.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting bmipy>=2.0 (from -r requirements.txt (line 8))
#   Downloading bmipy-2.0.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: geopandas>=0.14 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: fiona>=1.9 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.10.1)
# Requirement already satisfied: shapely>=2.0 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2.0.7)
# Requirement already satisfied: pyproj>=3.4 in /opt/venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (3.7.1)
# Collecting pywatemsedem (from -r requirements.txt (line 13))
#   Downloading pywatemsedem-0.0.1a9-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting netCDF4>=1.6 (from -r requirements.txt (line 14))
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->-r requirements.txt (line 3))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.0->-r requirements.txt (line 3))
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic>=2.0->-r requirements.txt (line 3))
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.0->-r requirements.txt (line 3))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: attrs in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/venv/lib/python3.12/site-packages (from rasterio>=1.3->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.4->-r requirements.txt (line 6)) (2.9.0.post0)
# Collecting black (from bmipy>=2.0->-r requirements.txt (line 8))
#   Downloading black-25.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (86 kB)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.12/site-packages (from bmipy>=2.0->-r requirements.txt (line 8)) (3.1.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/venv/lib/python3.12/site-packages (from geopandas>=0.14->-r requirements.txt (line 9)) (0.10.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/venv/lib/python3.12/site-packages (from geopandas>=0.14->-r requirements.txt (line 9)) (2.2.3)
# Collecting jupyter (from pywatemsedem->-r requirements.txt (line 13))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: xlrd in /opt/venv/lib/python3.12/site-packages (from pywatemsedem->-r requirements.txt (line 13)) (2.0.1)
# Requirement already satisfied: openpyxl in /opt/venv/lib/python3.12/site-packages (from pywatemsedem->-r requirements.txt (line 13)) (3.1.5)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.12/site-packages (from pywatemsedem->-r requirements.txt (line 13)) (1.6.1)
# Collecting python-dotenv (from pywatemsedem->-r requirements.txt (line 13))
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pandoc (from pywatemsedem->-r requirements.txt (line 13))
#   Downloading pandoc-2.4.tar.gz (34 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cftime (from netCDF4>=1.6->-r requirements.txt (line 14))
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas>=0.14->-r requirements.txt (line 9)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas>=0.14->-r requirements.txt (line 9)) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.4->-r requirements.txt (line 6)) (1.17.0)
# Collecting mypy-extensions>=0.4.3 (from black->bmipy>=2.0->-r requirements.txt (line 8))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->bmipy>=2.0->-r requirements.txt (line 8))
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/venv/lib/python3.12/site-packages (from black->bmipy>=2.0->-r requirements.txt (line 8)) (4.3.6)
# Collecting pytokens>=0.3.0 (from black->bmipy>=2.0->-r requirements.txt (line 8))
#   Downloading pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.12/site-packages (from jinja2->bmipy>=2.0->-r requirements.txt (line 8)) (3.0.1)
# Collecting notebook (from jupyter->pywatemsedem->-r requirements.txt (line 13))
#   Downloading notebook-7.5.1-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->pywatemsedem->-r requirements.txt (line 13))
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /opt/venv/lib/python3.12/site-packages (from jupyter->pywatemsedem->-r requirements.txt (line 13)) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/venv/lib/python3.12/site-packages (from jupyter->pywatemsedem->-r requirements.txt (line 13)) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/venv/lib/python3.12/site-packages (from jupyter->pywatemsedem->-r requirements.txt (line 13)) (8.1.5)
# Requirement already satisfied: jupyterlab in /opt/venv/lib/python3.12/site-packages (from jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.3.5)
# Requirement already satisfied: et-xmlfile in /opt/venv/lib/python3.12/site-packages (from openpyxl->pywatemsedem->-r requirements.txt (line 13)) (2.0.0)
# Collecting plumbum (from pandoc->pywatemsedem->-r requirements.txt (line 13))
#   Downloading plumbum-1.10.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting ply (from pandoc->pywatemsedem->-r requirements.txt (line 13))
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: scipy>=1.6.0 in /opt/venv/lib/python3.12/site-packages (from scikit-learn->pywatemsedem->-r requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/venv/lib/python3.12/site-packages (from scikit-learn->pywatemsedem->-r requirements.txt (line 13)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/venv/lib/python3.12/site-packages (from scikit-learn->pywatemsedem->-r requirements.txt (line 13)) (3.5.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/venv/lib/python3.12/site-packages (from ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/venv/lib/python3.12/site-packages (from ipywidgets->jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/venv/lib/python3.12/site-packages (from ipywidgets->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/venv/lib/python3.12/site-packages (from jupyter-console->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.0.50)
# Requirement already satisfied: pygments in /opt/venv/lib/python3.12/site-packages (from jupyter-console->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.19.1)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (75.8.0)
# Requirement already satisfied: beautifulsoup4 in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/venv/lib/python3.12/site-packages (from nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.5.1)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13))
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab (from jupyter->pywatemsedem->-r requirements.txt (line 13))
#   Downloading jupyterlab-4.5.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: webencodings in /opt/venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: anyio in /opt/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.0.7)
# Requirement already satisfied: idna in /opt/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.14.0)
# Requirement already satisfied: decorator in /opt/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: stack_data in /opt/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.21.1)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /opt/venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/venv/lib/python3.12/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /opt/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pywatemsedem->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: fqdn in /opt/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: uri-template in /opt/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.17.1)
# Requirement already satisfied: pycparser in /opt/venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pywatemsedem->-r requirements.txt (line 13)) (2.9.0.20241206)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading brokenaxes-0.6.2-py3-none-any.whl (7.3 kB)
# Downloading bmipy-2.0.1-py3-none-any.whl (8.4 kB)
# Downloading pywatemsedem-0.0.1a9-py2.py3-none-any.whl (148 kB)
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 13.5 MB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading black-25.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.9 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.1 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pytokens-0.3.0-py3-none-any.whl (12 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading notebook-7.5.1-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 33.9 MB/s eta 0:00:00a 0:00:01
# Downloading jupyterlab-4.5.1-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 51.9 MB/s eta 0:00:00a 0:00:01
# Downloading plumbum-1.10.0-py3-none-any.whl (127 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (pyproject.toml) ... done
#   Created wheel for pandoc: filename=pandoc-2.4-py3-none-any.whl size=34871 sha256=9000bc1529d8917dcfdbe657745a3b9b3e9a876624d99ce96633b0395d6c009e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9c/2f/9f/b1aac8c3e74b4ee327dc8c6eac5128996f9eadf586e2c0ba67
# Successfully built pandoc
# Installing collected packages: ply, typing-extensions, pytokens, python-dotenv, plumbum, pathspec, mypy-extensions, cftime, annotated-types, typing-inspection, pydantic-core, pandoc, netCDF4, black, pydantic, brokenaxes, bmipy, jupyter-console, jupyterlab-server, jupyterlab, notebook, jupyter, pywatemsedem
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab_server 2.27.3
#     Uninstalling jupyterlab_server-2.27.3:
#       Successfully uninstalled jupyterlab_server-2.27.3
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.3.5
#     Uninstalling jupyterlab-4.3.5:
#       Successfully uninstalled jupyterlab-4.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu126 requires nvidia-cublas-cu12==12.6.4.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cuda-cupti-cu12==12.6.80; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cuda-nvrtc-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cuda-runtime-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cudnn-cu12==9.5.1.17; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cufft-cu12==11.3.0.4; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-curand-cu12==10.3.7.77; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cusolver-cu12==11.7.1.2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cusparse-cu12==12.5.4.2; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-cusparselt-cu12==0.6.3; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-nvjitlink-cu12==12.6.85; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-nvtx-cu12==12.6.77; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires triton==3.2.0; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.6.0+cu126 requires nvidia-nccl-cu12==2.21.5; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nccl-cu12 2.25.1 which is incompatible.
# Successfully installed annotated-types-0.7.0 black-25.12.0 bmipy-2.0.1 brokenaxes-0.6.2 cftime-1.6.5 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-4.5.1 jupyterlab-server-2.28.0 mypy-extensions-1.1.0 netCDF4-1.7.3 notebook-7.5.1 pandoc-2.4 pathspec-0.12.1 plumbum-1.10.0 ply-3.11 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.1 pytokens-0.3.0 pywatemsedem-0.0.1a9 typing-extensions-4.15.0 typing-inspection-0.4.2

# %%
# !python src/run_watem.py -c config.yaml --mode hybrid
# Out:
# INFO:__main__: output dir: /home/jovyan/work/LISEM/WaTEM-SEDEM-python/results/results_hybrid
# INFO:data_loader: elevation ← ./data/rasters/elevation.tif
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 9.5.1
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libta_morphometry
# library     : ta_morphometry
# tool        : Slope, Aspect, Curvature
# identifier  : 0
# author      : O.Conrad (c) 2001
# processors  : 32 [32]
# ____________________________
#
# loading: tmpgxubdvam
# [Slope, Aspect, Curvature] Execution started...
#
# __________
# [Slope, Aspect, Curvature] Parameters:
#
# Grid System: 20; 343x 198y; 10x -3950y
# Elevation: tmpgxubdvam
# Slope: Slope
# Aspect: Aspect
# General Curvature: <not set>
# Profile Curvature: <not set>
# Plan Curvature: <not set>
# Tangential Curvature: <not set>
# Longitudinal Curvature: <not set>
# Cross-Sectional Curvature: <not set>
# Minimal Curvature: <not set>
# Maximal Curvature: <not set>
# Total Curvature: <not set>
# Flow Line Curvature: <not set>
# Method: 9 parameter 2nd order polynom (Zevenbergen & Thorne 1987)
# Unit: radians
# Unit: radians
#
#
# __________
# total execution time: 0 milliseconds (less than 1 millisecond)
#
# [Slope, Aspect, Curvature] Execution succeeded (less than 1 millisecond)
# Saving grid: /tmp/tmpgxubdvam_slope...
# okay
# INFO:data_loader: DTM 'slope' ← computed
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 9.5.1
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libta_morphometry
# library     : ta_morphometry
# tool        : Slope, Aspect, Curvature
# identifier  : 0
# author      : O.Conrad (c) 2001
# processors  : 32 [32]
# ____________________________
#
# loading: tmpe4syssp0
# [Slope, Aspect, Curvature] Execution started...
#
# __________
# [Slope, Aspect, Curvature] Parameters:
#
# Grid System: 20; 343x 198y; 10x -3950y
# Elevation: tmpe4syssp0
# Slope: Slope
# Aspect: Aspect
# General Curvature: <not set>
# Profile Curvature: <not set>
# Plan Curvature: <not set>
# Tangential Curvature: <not set>
# Longitudinal Curvature: <not set>
# Cross-Sectional Curvature: <not set>
# Minimal Curvature: <not set>
# Maximal Curvature: <not set>
# Total Curvature: <not set>
# Flow Line Curvature: <not set>
# Method: 9 parameter 2nd order polynom (Zevenbergen & Thorne 1987)
# Unit: radians
# Unit: radians
#
#
# __________
# total execution time: 0 milliseconds (less than 1 millisecond)
#
# [Slope, Aspect, Curvature] Execution succeeded (less than 1 millisecond)
# Saving grid: /tmp/tmpe4syssp0_aspect...
# okay
# INFO:data_loader: DTM 'aspect' ← computed
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 9.5.1
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libta_channels
# library     : ta_channels
# tool        : Watershed Basins
# identifier  : 1
# author      : (c) 2001 by O.Conrad
# processors  : 32 [32]
# ____________________________
#
# [Error] ELEVATION: Provide a value for non-optional argument!
# [Error] Elevation
#
# Usage: saga_cmd ta_channels 1 [-ELEVATION <str>] [-CHANNELS <str>] [-SINKROUTE <str>] [-BASINS <str>] [-MINSIZE <num>]
#   -ELEVATION:<str>	Elevation
# 	grid, input
#   -CHANNELS:<str> 	Channel Network
# 	grid, input
#   -SINKROUTE:<str>	Sink Route
# 	grid, input, optional
#   -BASINS:<str>   	Watershed Basins
# 	grid, output
#   -MINSIZE:<num>  	Min. Size
# 	integer number
# 	Default: 0
#
# WARNING:compute_dtm: SAGA slope-length failed; using sqrt(fac*cell_size) fallback
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 9.5.1
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libta_hydrology
# library     : ta_hydrology
# tool        : Flow Accumulation (Top-Down)
# identifier  : 0
# author      : O.Conrad (c) 2001-2016, Portions by T.Grabs (c) 2010
# processors  : 32 [32]
# ____________________________
#
# loading: tmpvubpau2s
# [Flow Accumulation (Top-Down)] Execution started...
#
# __________
# [Flow Accumulation (Top-Down)] Parameters:
#
# Grid System: 20; 343x 198y; 10x -3950y
# Elevation: tmpvubpau2s
# Sink Routes: <not set>
# Weights: <not set>
# Flow Accumulation: Flow Accumulation
# Input for Mean over Catchment: <not set>
# Material for Accumulation: <not set>
# Step: 1
# Flow Accumulation Unit: cell area
# Flow Path Length: <not set>
# Channel Direction: <not set>
# Method: Deterministic 8
# Thresholded Linear Flow: false
#
# Create index: tmpvubpau2s
#
# __________
# total execution time: 0 milliseconds (less than 1 millisecond)
#
# [Flow Accumulation (Top-Down)] Execution succeeded (less than 1 millisecond)
# Saving grid: /tmp/tmpvubpau2s_fac...
# okay
# INFO:data_loader: DTM 'slope_length' ← computed
# INFO:data_loader: DTM 'flow_direction' ← computed
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 9.5.1
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libta_hydrology
# library     : ta_hydrology
# tool        : Flow Accumulation (Top-Down)
# identifier  : 0
# author      : O.Conrad (c) 2001-2016, Portions by T.Grabs (c) 2010
# processors  : 32 [32]
# ____________________________
#
# loading: tmpuc479oyy
# [Flow Accumulation (Top-Down)] Execution started...
#
# __________
# [Flow Accumulation (Top-Down)] Parameters:
#
# Grid System: 20; 343x 198y; 10x -3950y
# Elevation: tmpuc479oyy
# Sink Routes: <not set>
# Weights: <not set>
# Flow Accumulation: Flow Accumulation
# Input for Mean over Catchment: <not set>
# Material for Accumulation: <not set>
# Step: 1
# Flow Accumulation Unit: cell area
# Flow Path Length: <not set>
# Channel Direction: <not set>
# Method: Deterministic 8
# Thresholded Linear Flow: false
#
# Create index: tmpuc479oyy
#
# __________
# total execution time: 0 milliseconds (less than 1 millisecond)
#
# [Flow Accumulation (Top-Down)] Execution succeeded (less than 1 millisecond)
# Saving grid: /tmp/tmpuc479oyy_fac...
# okay
# INFO:data_loader: DTM 'flow_accumulation' ← computed
# INFO:raster_calculations: LS-factor computed, mean = 1.85037
# INFO:data_loader: DTM 'LS-factor' ← computed
# INFO:data_loader: WaTEM 'Kfactor' ← default scalar (hybrid)
# WARNING:data_loader: Cfactor hybrid path failed: Missing landuse/catchment/elevation for Cfactor hybrid path — fallback to default
# INFO:data_loader: WaTEM 'Cfactor' ← default scalar (hybrid)
# INFO:data_loader: WaTEM 'Pfactor' ← default scalar (hybrid)
# INFO:data_loader: WaTEM 'ktc' ← default scalar (hybrid)
# INFO:data_loader: 'Rfactor' ← default scalar
# INFO:data_loader: 'bulk-density' ← default scalar
# INFO:lateraldistribution: running erosion routing on a 198x343 grid
# INFO:__main__: wrote SEDI_OUT -> /home/jovyan/work/LISEM/WaTEM-SEDEM-python/results/results_hybrid/SEDI_OUT.tif
# INFO:__main__: wrote CAPACITY -> /home/jovyan/work/LISEM/WaTEM-SEDEM-python/results/results_hybrid/CAPACITY.tif
# INFO:__main__: wrote WATEREROS -> /home/jovyan/work/LISEM/WaTEM-SEDEM-python/results/results_hybrid/WATEREROS.tif
# INFO:__main__: saved plot -> /home/jovyan/work/LISEM/WaTEM-SEDEM-python/results/results_hybrid/maps.png
